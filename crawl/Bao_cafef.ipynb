# %% [markdown]
# # LIBRARY BLOCK

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from bs4 import BeautifulSoup
import pandas as pd
import time 
from datetime import datetime
import re

# %% [markdown]
# # SET UP BLOCK

# %% [markdown]
# # FUNCTION BLOCK

# %%
def load_full_content(max_clicks=10):
    # Cấu hình số lần click tối đa và bộ đếm
    current_click = 0

    while current_click < max_clicks:
        print(f"--- Bắt đầu vòng lặp thứ {current_click + 1} ---")
        
        # === BƯỚC 1: SCROLL CHO ĐẾN KHI KHÔNG TẢI THÊM NỘI DUNG ===
        last_height = driver.execute_script("return document.body.scrollHeight")
        
        while True:
            # Scroll xuống cuối trang
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            
            # Chờ trang tải nội dung (2 giây)
            time.sleep(2)
            
            # Tính toán chiều cao mới của trang sau khi scroll
            new_height = driver.execute_script("return document.body.scrollHeight")
            
            if new_height == last_height:
                # Nếu chiều cao không đổi, nghĩa là đã chạm đáy
                print("Đã scroll đến cuối nội dung hiện tại.")
                break
            
            last_height = new_height

        # === BƯỚC 2: CLICK NÚT NEXT/VIEW MORE ===
        try:
            # Tìm lại nút next mỗi lần lặp để tránh lỗi "Stale Element Reference"
            next_button = driver.find_element(By.CSS_SELECTOR, 'div[class="btn-viewmore"]')
            
            if next_button.is_displayed():
                # Sử dụng Javascript để click (tránh trường hợp nút bị che bởi quảng cáo hoặc header)
                driver.execute_script("arguments[0].click();", next_button)
                
                current_click += 1
                print(f"Đã click nút Next lần thứ: {current_click}")
                
                # Yêu cầu: Chờ 10 giây sau mỗi lần click
                time.sleep(10)
            else:
                print("Nút Next không hiển thị. Dừng vòng lặp.")
                break
                
        except NoSuchElementException:
            print("Không tìm thấy nút Next (có thể đã hết trang). Dừng vòng lặp.")
            break
        except Exception as e:
            print(f"Có lỗi xảy ra: {e}")
            

# def get_generalization_news_data():
#     # === BƯỚC 3: LẤY DỮ LIỆU SAU KHI ĐÃ LOAD HẾT ===
#     print("--- Hoàn tất quá trình load. Bắt đầu lấy dữ liệu ---")

#     box_news = driver.find_elements(By.CSS_SELECTOR, 'div[class="list-news-main top5_news"] div[class="tlitem box-category-item"]')
#     print(f"Tổng số tin tìm thấy: {len(box_news)}")
#     if len(box_news) == 0:
#         box_news = driver.find_elements(By.CSS_SELECTOR, 'div[class="tlitem box-category-item"]')
#     print(f"Tổng số tin tìm thấy sau khi thử selector khác: {len(box_news)}")   
        

#     data = []
#     for idx,box in enumerate(box_news):   
#         title = box.find_element(By.CSS_SELECTOR, 'h3 a').text
#         link = box.find_element(By.CSS_SELECTOR, 'h3 a').get_attribute('href')
#         time_post = box.find_element(By.CSS_SELECTOR, 'span[class="time time-ago"]').get_attribute('title')
#         summary = box.find_element(By.CSS_SELECTOR, 'p[class="sapo box-category-sapo"]').text
#         print(f"Đang xử lý tin thứ {idx + 1}")
#         print(title)
#         data.append({
#             "title": title,
#             "link": link,
#             "time_post": time_post,
#             "summary": summary
#         })
#     return data
def get_generalization_news_data():
    print("--- Hoàn tất quá trình load. Bắt đầu lấy dữ liệu (Batch Mode) ---")

    # 1. Xác định container chính để giới hạn phạm vi tìm kiếm (tránh lấy nhầm tin ở footer/sidebar)
    # Tìm vùng chứa tin
    try:
        container = driver.find_element(By.CSS_SELECTOR, 'div[class="list-news-main top5_news"]')
    except:
        container = driver # Nếu không thấy thì tìm trên toàn trang (fallback)

    # 2. Lấy TOÀN BỘ từng thuộc tính ra các danh sách riêng biệt
    # Lưu ý: Phải dùng selector trỏ thẳng vào element con cuối cùng
    list_titles_els = container.find_elements(By.CSS_SELECTOR, 'div[class="tlitem box-category-item"] h3 a')
    list_time_els = container.find_elements(By.CSS_SELECTOR, 'div[class="tlitem box-category-item"] span[class="time time-ago"]')
    list_summary_els = container.find_elements(By.CSS_SELECTOR, 'div[class="tlitem box-category-item"] p[class="sapo box-category-sapo"]')

    # 3. KIỂM TRA SỐ LƯỢNG (Bước quan trọng bạn đã nhắc đến)
    count_title = len(list_titles_els)
    count_time = len(list_time_els)
    count_summary = len(list_summary_els)

    print(f"Check số lượng: Title={count_title}, Time={count_time}, Summary={count_summary}")

    data = []

    # TRƯỜNG HỢP 1: Dữ liệu hoàn hảo (Số lượng bằng nhau hết) -> Ghép nhanh
    if count_title == count_time == count_summary:
        print("-> Dữ liệu đồng bộ. Đang ghép nhanh...")
        # Hàm zip giúp gộp 3 danh sách lại chạy song song
        count = 0   
        for title_el, time_el, summary_el in zip(list_titles_els, list_time_els, list_summary_els):
            count += 1
            print(f"Đang xử lý tin thứ {count + 1}: {title_el.text}")
            data.append({
                "title": title_el.text,
                "link": title_el.get_attribute('href'),
                "time_post": time_el.get_attribute('title'),
                "summary": summary_el.text
            })

    # TRƯỜNG HỢP 2: Dữ liệu bị lệch (Có tin thiếu time hoặc summary) -> Phải chạy chậm lại để an toàn
    else:
        print("-> CẢNH BÁO: Số lượng không khớp (có tin thiếu nội dung). Chuyển về chế độ quét từng dòng (chậm nhưng an toàn).")
        # Quay lại cách cũ: Tìm box cha rồi tìm con
        boxes = container.find_elements(By.CSS_SELECTOR, 'div[class="tlitem box-category-item"]')
        for box in boxes:
            try:
                # Dùng try-except cho từng element con để nếu thiếu cũng không lỗi code
                t_el = box.find_element(By.CSS_SELECTOR, 'h3 a')
                title = t_el.text
                link = t_el.get_attribute('href')
            except: 
                title = ""; link = ""
            
            try:
                time_post = box.find_element(By.CSS_SELECTOR, 'span[class="time time-ago"]').get_attribute('title')
            except:
                time_post = ""

            try:
                summary = box.find_element(By.CSS_SELECTOR, 'p[class="sapo box-category-sapo"]').text
            except:
                summary = ""

            print(f"Đang xử lý tin: {title}")
            data.append({
                "title": title, "link": link, "time_post": time_post, "summary": summary
            })

    return data

def get_detail_news_data(df):
    data = []
    
    for i in df.index:
        link = df.loc[i, 'link']
        title_ref = df.loc[i, 'title']
        
        # 1. Truy cập trang
        try:
            driver.get(link)
        except Exception as e:
            print(f"Lỗi không truy cập được link bài {i+1}: {e}")
            # Nếu link chết, append data rỗng và continue
            data.append({
                "title": title_ref, "content": "", "link": link,
                "time_post": df.loc[i, 'time_post'], "summary": df.loc[i, 'summary']
            })
            continue

        print(f"--- Đang xử lý bài báo thứ {i + 1} ---")
        
        # 2. Cơ chế chờ thông minh (Tối đa 3 phút)
        start_time = time.time()
        content = "" # Mặc định là rỗng
        got_data = False # Cờ đánh dấu đã lấy được chưa

        while (time.time() - start_time) < 180: # 180 giây = 3 phút
            try:
                # Cố gắng tìm container chứa bài viết trước
                # Lưu ý: Cần kiểm tra kỹ selector 'div[class="w640 fr clear"]' có đúng cho mọi bài không
                main_div = driver.find_element(By.CSS_SELECTOR, 'div[class="w640 fr clear"]')
                
                # Lấy H2 (Sapo/Mô tả)
                # Dùng try-except nhỏ ở đây vì có thể có bài không có h2
                try:
                    h2_text = main_div.find_element(By.TAG_NAME, 'h2').text
                except NoSuchElementException:
                    h2_text = ""

                # Lấy các thẻ P (Nội dung chi tiết)
                content_elements = main_div.find_elements(By.TAG_NAME, 'p')

                # ĐIỀU KIỆN ĐỂ COI LÀ THÀNH CÔNG:
                # Phải tìm thấy ít nhất 1 thẻ P hoặc có H2
                if len(content_elements) > 0 or h2_text != "":
                    # Ghép chuỗi
                    temp_content = h2_text + "\n"
                    for p in content_elements:
                        temp_content += p.text + "\n"
                    
                    content = temp_content
                    got_data = True
                    print(f"    -> Đã lấy xong nội dung ({len(content)} ký tự).")
                    break # Thoát vòng lặp while ngay lập tức
                
            except (NoSuchElementException, StaleElementReferenceException):
                # Nếu chưa tìm thấy element cha, hoặc trang đang reload DOM
                pass
            except Exception as e:
                print(f"    Lỗi không xác định trong lúc chờ: {e}")
            
            # Nếu chưa lấy được, nghỉ 1 giây rồi thử lại
            time.sleep(1)

        # 3. Kiểm tra kết quả sau vòng lặp
        if not got_data:
            print(f"    -> CẢNH BÁO: Quá 3 phút không lấy được nội dung bài {i+1}. Để trống content.")
            content = "" # Đảm bảo rỗng như yêu cầu

        # 4. Lưu vào danh sách
        data.append({
            "title": title_ref,
            "content": content,
            "link": link,
            "time_post": df.loc[i, 'time_post'],
            "summary": df.loc[i, 'summary']
        })
        
    return data

# %% [markdown]
# # EXECUTION BLOCK

# %%
global driver
driver = webdriver.Chrome()
driver.get("https://cafef.vn/thi-truong-chung-khoan.chn")

# %%
load_full_content(max_clicks=100)
# Out:
# --- Bắt đầu vòng lặp thứ 1 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 1
# --- Bắt đầu vòng lặp thứ 2 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 2
# --- Bắt đầu vòng lặp thứ 3 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 3
# --- Bắt đầu vòng lặp thứ 4 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 4
# --- Bắt đầu vòng lặp thứ 5 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 5
# --- Bắt đầu vòng lặp thứ 6 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 6
# --- Bắt đầu vòng lặp thứ 7 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 7
# --- Bắt đầu vòng lặp thứ 8 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 8
# --- Bắt đầu vòng lặp thứ 9 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 9
# --- Bắt đầu vòng lặp thứ 10 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 10
# --- Bắt đầu vòng lặp thứ 11 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 11
# --- Bắt đầu vòng lặp thứ 12 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 12
# --- Bắt đầu vòng lặp thứ 13 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 13
# --- Bắt đầu vòng lặp thứ 14 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 14
# --- Bắt đầu vòng lặp thứ 15 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 15
# --- Bắt đầu vòng lặp thứ 16 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 16
# --- Bắt đầu vòng lặp thứ 17 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 17
# --- Bắt đầu vòng lặp thứ 18 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 18
# --- Bắt đầu vòng lặp thứ 19 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 19
# --- Bắt đầu vòng lặp thứ 20 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 20
# --- Bắt đầu vòng lặp thứ 21 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 21
# --- Bắt đầu vòng lặp thứ 22 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 22
# --- Bắt đầu vòng lặp thứ 23 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 23
# --- Bắt đầu vòng lặp thứ 24 ---
# Đã scroll đến cuối nội dung hiện tại.
# Đã click nút Next lần thứ: 24
# --- Bắt đầu vòng lặp thứ 25 ---
# Đã scroll đến cuối nội dung hiện tại.
# Nút Next không hiển thị. Dừng vòng lặp.

# %%
data = get_generalization_news_data()
df = pd.DataFrame(data)
# Lưu vào file có tên là 'du_lieu_tin_tuc.json'
df.to_json(
    'data/danh_sach_bai_bao.json', 
    orient='records',    # Lưu dưới dạng danh sách các đối tượng: [{}, {}, ...]
    force_ascii=False,   # QUAN TRỌNG: Để giữ nguyên tiếng Việt (không bị chuyển thành mã \uXXXX)
    indent=4             # Thụt đầu dòng để file dễ đọc hơn (pretty print)
)

print("Đã lưu file danh_sach_bai_bao.json thành công!")
# Out:
# --- Hoàn tất quá trình load. Bắt đầu lấy dữ liệu (Batch Mode) ---
# Check số lượng: Title=907, Time=907, Summary=907
# -> Dữ liệu đồng bộ. Đang ghép nhanh...
# Đang xử lý tin thứ 2: NSH Petro có Tổng Giám đốc mới sau gần 2 tháng để ‘trống ghế’
# Đang xử lý tin thứ 3: Quỹ ETF ngoại quy mô 15.000 tỷ thêm mới TCX, dự kiến bán mạnh VIC
# Đang xử lý tin thứ 4: Viglacera miễn nhiệm một Phó Tổng Giám đốc
# Đang xử lý tin thứ 5: Chuyên gia lý giải nguyên nhân chứng khoán Việt Nam "sale off" 52 điểm ngày 12-12
# Đang xử lý tin thứ 6: Một thế lực bất ngờ tung hàng trăm tỷ "gom" cổ phiếu Việt Nam giữa lúc thị trường rơi mạnh trong phiên cuối tuần
# Đang xử lý tin thứ 7: Chứng khoán trượt mạnh
# Đang xử lý tin thứ 8: Vì sao VN-Index “bốc hơi” 52 điểm trong phiên cuối tuần?
# Đang xử lý tin thứ 9: Coteccons chốt ngày phát hành hơn 5 triệu cổ phiếu thưởng cho cổ đông
# Đang xử lý tin thứ 10: Phiên 12/12: Khối ngoại tiếp đà bán ròng hơn 500 tỷ đồng, cổ phiếu nào bị "xả" mạnh nhất?
# Đang xử lý tin thứ 11: Chứng khoán Việt Nam “sale off” hơn 50 điểm ngày Black Friday, đi ngược thị trường Châu Á
# Đang xử lý tin thứ 12: VN-Index giảm mạnh nhất châu Á, một “ông lớn” ngược dòng phá đỉnh lịch sử
# Đang xử lý tin thứ 13: Phó Chủ tịch UBCK nói gì về mức độ biến động lớn của thị trường chứng khoán Việt Nam?
# Đang xử lý tin thứ 14: SHS dự kiến chào bán 5.000 tỷ đồng trái phiếu ra công chúng năm 2026
# Đang xử lý tin thứ 15: CNBC: Chứng khoán Việt Nam bùng nổ, có thể chỉ là sự khởi đầu
# Đang xử lý tin thứ 16: Chứng khoán APG phát hành 300 tỷ đồng trái phiếu để cơ cấu nợ
# Đang xử lý tin thứ 17: Thủy sản Minh Phú chốt ngày trả cổ tức bằng tiền
# Đang xử lý tin thứ 18: Nữ Chủ tịch TVC bán ra 1,45 triệu cổ phiếu
# Đang xử lý tin thứ 19: Lịch sự kiện và tin vắn chứng khoán ngày 12/12/2025
# Đang xử lý tin thứ 20: Thị trường tiền số hôm nay, 11-12: Điều gì đang chặn đứng đà tăng Bitcoin?
# Đang xử lý tin thứ 21: "Đánh rơi" hơn 50 điểm sau 3 phiên rung lắc, VN-Index còn có thể lùi về ngưỡng nào?
# Đang xử lý tin thứ 22: Chứng khoán mất mốc 1.700 điểm, VPX gây thất vọng ngày chào sàn
# Đang xử lý tin thứ 23: Chứng khoán ngày 11/12: VN-Index một lần nữa mất mốc 1.700 điểm
# Đang xử lý tin thứ 24: 6 nhà đầu tư cá nhân chi hơn 900 tỷ đồng mua cổ phần Petrosetco từ PVN
# Đang xử lý tin thứ 25: Ngược dòng, cổ phiếu QCG “tím lịm” phiên thứ 2 giữa lúc VN-Index “lao dốc” mạnh
# Đang xử lý tin thứ 26: Cổ phiếu của tỷ phú Phạm Nhật Vượng được tự doanh CTCK "gom" đột biến trong phiên 11/12
# Đang xử lý tin thứ 27: Đây sẽ là thành phố đầu tiên của Việt Nam bỏ tiền ngân sách mua kết quả nghiên cứu của nhà khoa học để thương mại hóa
# Đang xử lý tin thứ 28: Khối ngoại ngược dòng tung hàng trăm tỷ gom một cổ phiếu bluechip trong phiên VN-Index giảm 20 điểm
# Đang xử lý tin thứ 29: DIC Corp không bán hết lượng cổ phiếu DC4 đã đăng ký
# Đang xử lý tin thứ 30: Lãnh đạo cấp cao một công ty chứng khoán bất ngờ xin từ nhiệm
# Đang xử lý tin thứ 31: Chứng khoán Rồng Việt 6 lần liên tiếp nhận giải thưởng “Tổ chức tư vấn M&A tiêu biểu"
# Đang xử lý tin thứ 32: Cổ phiếu MCH sẽ niêm yết HOSE trong tháng 12/2025
# Đang xử lý tin thứ 33: Yêu bạn trai "doanh nhân" qua mạng, người phụ nữ suýt mất 4 tỷ đồng
# Đang xử lý tin thứ 34: Việt Nam chính thức thành lập Ban Quản lý thị trường giao dịch tài sản mã hóa
# Đang xử lý tin thứ 35: Chưa đầy 10 ngày nữa, chính thức khởi công dự án ray đường sắt và thép đặc biệt, vốn 10.000 tỷ do công ty của tỷ phú Trần Đình Long đầu tư
# Đang xử lý tin thứ 36: Tin vui cho tỷ phú Trần Đình Long: Thép dây mạ kẽm Hòa Phát hưởng mức thuế 5,7% vào Canada, trong khi "đối thủ" khác chịu mức cao tới 158,9%
# Đang xử lý tin thứ 37: SGI Capital: Cơ hội lớn dành cho trường phái đầu tư giá trị có thể sẽ xuất hiện trong những tháng tới
# Đang xử lý tin thứ 38: Cổ phiếu VPX chính thức giao dịch trên HoSE
# Đang xử lý tin thứ 39: Chứng khoán Việt Nam không có bong bóng, xác suất tăng điểm tháng 12 tới 75%
# Đang xử lý tin thứ 40: Lighthouse Capital thông báo chào bán chứng chỉ Quỹ LHFCF ra công chúng
# Đang xử lý tin thứ 41: Lịch sự kiện và tin vắn chứng khoán ngày 11/12/2025
# Đang xử lý tin thứ 42: ‘Khai phá’ tài sản số trở thành một động lực tăng trưởng mới
# Đang xử lý tin thứ 43: "Vua gỗ" một thời bất ngờ hồi sinh giữa lúc VN-Index điều chỉnh mạnh
# Đang xử lý tin thứ 44: Cuối năm, hàng loạt công ty trên sàn chứng khoán thay đổi nhân sự chủ chốt
# Đang xử lý tin thứ 45: Doanh nghiệp của bầu Đức thay đổi
# Đang xử lý tin thứ 46: Cuộc thi RongViet Invest 2025 chính thức tìm ra 2 quán quân
# Đang xử lý tin thứ 47: Một cổ phiếu bất động sản bất ngờ được tự doanh CTCK "gom" trăm tỷ trong phiên thị trường giảm mạnh
# Đang xử lý tin thứ 48: Phiên 10/12: Gần 400 tỷ đồng cổ phiếu Việt Nam bị khối ngoại bán ròng, mã nào bị "nhắm" đến?
# Đang xử lý tin thứ 49: Đế chế Berkshire Hathayway trị giá 1.000 tỷ USD rung lắc dữ dội vài tuần trước khi Warren Buffet chính thức nghỉ hưu sau 60 năm điều hành
# Đang xử lý tin thứ 50: Điều gì khiến chứng khoán Việt Nam giảm mạnh nhất Châu Á?
# Đang xử lý tin thứ 51: CIC Group (CKG) kiện toàn nhân sự, chuyển giao cho thế hệ lãnh đạo tiếp theo
# Đang xử lý tin thứ 52: Hơn 20 ngày nữa, tài sản này sẽ bước ra khỏi "vùng xám", không còn là "sốt ảo": Chuyên gia gợi mở cách kích hoạt dòng vốn tắc nghẽn chỉ bằng ba chữ
# Đang xử lý tin thứ 53: Lãi suất phát hành trái phiếu doanh nghiệp trong tháng 11 vọt lên 10,3%/năm
# Đang xử lý tin thứ 54: Vidipha bị phạt, truy thu hơn 10 tỷ đồng tiền thuế
# Đang xử lý tin thứ 55: Lộ diện 5 doanh nghiệp mua hơn 48 triệu cổ phiếu 'ế' của Chứng khoán Bảo Minh
# Đang xử lý tin thứ 56: 21,5 triệu cổ phiếu VVS chính thức lên sàn HoSE: Mở ra chu kỳ tăng trưởng mới đầy triển vọng
# Đang xử lý tin thứ 57: Danh tính 4 quỹ ngoại mua 93,5 triệu cổ phiếu riêng lẻ của Đất Xanh
# Đang xử lý tin thứ 58: 5 cá nhân dự kiến mua gần 162 triệu cổ phiếu riêng lẻ của Chứng khoán VPS
# Đang xử lý tin thứ 59: Quỹ Bạc lớn nhất thế giới vừa lập kỷ lục chưa từng có giữa con sốt giá
# Đang xử lý tin thứ 60: Ông Trương Gia Bình: TP.HCM có thể trở thành thủ phủ máy bay không người lái, quy mô 10 tỷ USD
# Đang xử lý tin thứ 61: Danh tính 5 doanh nghiệp dự kiến mua hơn 48 triệu cổ phiếu “ế” của BMS
# Đang xử lý tin thứ 62: Lịch sự kiện và tin vắn chứng khoán ngày 10/12/2025
# Đang xử lý tin thứ 63: VN-Index có thể lên 1.920 điểm vào năm 2026, CTCK chỉ ra loạt nhóm ngành kỳ vọng "hút tiền" thời gian tới
# Đang xử lý tin thứ 64: Cú “chơi lớn” ngay dịp đầu năm: Doanh nghiệp chi cổ tức tiền mặt tỷ lệ khủng 51%
# Đang xử lý tin thứ 65: Hai "cá mập" tổng quy mô 24.500 tỷ có thể điều chỉnh tỷ trọng cổ phiếu của tỷ phú Phạm Nhật Vượng, ngược chiều "gom" mã nhà tỷ phú Trần Đình Long
# Đang xử lý tin thứ 66: Vietcap cảnh báo một rủi ro đáng chú ý cho thị trường chứng khoán trong tháng 12
# Đang xử lý tin thứ 67: Một thế lực vừa "tung tiền" gom mạnh cổ phiếu của tỷ phú Phạm Nhật Vượng trong phiên 9/12
# Đang xử lý tin thứ 68: Khối ngoại bán ròng mạnh, cổ phiếu VIC hết "gánh" nổi chỉ số
# Đang xử lý tin thứ 69: Đua nhau phát hành cổ phiếu, lên sàn
# Đang xử lý tin thứ 70: Phiên 9/12: Khối ngoại tiếp đà bán ròng hơn 2.500 tỷ đồng, cổ phiếu nào bị bán mạnh?
# Đang xử lý tin thứ 71: Doanh nghiệp do ông Nguyễn Hoàng Giang sáng lập vừa tất toán lô trái phiếu 100 tỷ đồng
# Đang xử lý tin thứ 72: VNDIRECT: Tích hợp trí tuệ – Vượt mọi giới hạn
# Đang xử lý tin thứ 73: Chứng khoán Việt Nam sẽ nghỉ giao dịch 12 phiên
# Đang xử lý tin thứ 74: Một nhà mạng cán mốc lắp mới 20.000 trạm 5G trong năm 2025, vượt tiến độ hơn ba tuần
# Đang xử lý tin thứ 75: CEO Chứng khoán OCBS: Thị trường Việt Nam sắp bước vào một chu kỳ tăng trưởng mới
# Đang xử lý tin thứ 76: Viconship muốn ‘gom’ 1 triệu cổ phiếu HAH của Xếp dỡ Hải An
# Đang xử lý tin thứ 77: Vietcap chốt thời gian chào bán hơn 127 triệu cổ phiếu riêng lẻ cho 69 nhà đầu tư
# Đang xử lý tin thứ 78: Tập đoàn Thiên Long làm ăn ra sao trước khi 'bán mình'?
# Đang xử lý tin thứ 79: Hơn 51.000 cổ đông “ôm” một cổ phiếu bị đình chỉ, doanh nghiệp lần đầu hé lộ tài chính sau biến cố, dự kiến còn lỗ tới hết năm 2027
# Đang xử lý tin thứ 80: Chủ tịch UBCKNN: Doanh nghiệp FDI chất lượng sẽ cân đối lại cơ cấu ngành nghề trên sàn chứng khoán
# Đang xử lý tin thứ 81: Nóng: Vingroup đề xuất đầu tư 3 tỷ USD phát triển hệ sinh thái đa ngành tại Ấn Độ
# Đang xử lý tin thứ 82: Khi chứng khoán bước vào cuộc chơi mới: CEO OCBS Nguyễn Đức Quân Tùng bật mí mô hình vận hành số và triết lý lãnh đạo chính trực
# Đang xử lý tin thứ 83: Pinetree và thế hệ nhà đầu tư tự chủ
# Đang xử lý tin thứ 84: Vietcap khởi động cuộc thi "Vietcap Invest - Nâng tầm đầu tư, thắng lớn mỗi tuần cùng Warren"
# Đang xử lý tin thứ 85: Lịch sự kiện và tin vắn chứng khoán ngày 9/12/2025
# Đang xử lý tin thứ 86: Chủ tịch FPT Trương Gia Bình thưởng nóng 100 triệu nếu nhân viên làm được một việc trong 12 tháng tới
# Đang xử lý tin thứ 87: CTCK dự báo 3 kịch bản cho VN-Index tháng 12, chỉ tên nhóm cổ phiếu có triển vọng tích cực
# Đang xử lý tin thứ 88: Sau giao dịch với Vingroup, một cổ phiếu tăng dựng đứng gần 200% chỉ trong vòng 1 tháng
# Đang xử lý tin thứ 89: VN-Index tiến sát đỉnh lịch sử nhưng phần lớn cổ phiếu đang "dậm chân" ở vùng 1.580 – 1.600 điểm, CTCK chỉ ra điểm đáng lưu ý
# Đang xử lý tin thứ 90: Một lý do khiến nhà đầu tư thua lỗ dù VN-Index tăng mạnh về gần đỉnh
# Đang xử lý tin thứ 91: Thị trường tiền số hôm nay, 8-12: Bitcoin sắp bước vào cơn địa chấn?
# Đang xử lý tin thứ 92: 'Nữ tướng' NovaGroup rời ghế tổng giám đốc
# Đang xử lý tin thứ 93: VN-Index vượt 1.750 điểm nhờ VIC tăng trần, danh mục nhà đầu tư vẫn "đỏ lửa"
# Đang xử lý tin thứ 94: Một cổ phiếu bất động sản bất ngờ bị tự doanh CTCK bán ròng trong phiên đầu tuần
# Đang xử lý tin thứ 95: Chứng khoán hướng lên đỉnh cũ, nhà đầu tư vẫn 'ngậm ngùi'
# Đang xử lý tin thứ 96: FPT tạo ứng dụng kiểu “Tinder” để se duyên nhân viên của mình với người của Vietnam Airlines
# Đang xử lý tin thứ 97: NÓNG: “Bom tấn” VPS chốt ngày đưa mã VCK lên sàn chứng khoán
# Đang xử lý tin thứ 98: Phiên 8/12: Khối ngoại bán ròng gần 2.000 tỷ trên HoSE
# Đang xử lý tin thứ 99: Một chỉ số của FTSE Russell vừa loại 2 cổ phiếu Việt Nam khỏi danh mục
# Đang xử lý tin thứ 100: Phân lân Văn Điển không còn đáp ứng điều kiện công ty đại chúng
# Đang xử lý tin thứ 101: Tại sao giá cổ phiếu Netflix giảm 3% khi công bố mua lại một phần Warner Bros?
# Đang xử lý tin thứ 102: FPT Play tuyên bố độc quyền phát sóng Ngoại Hạng Anh, tung gói cước ưu đãi chỉ từ 59.000 đồng/tháng
# Đang xử lý tin thứ 103: Đạm Cà Mau tăng mục tiêu lợi nhuận năm 2025 lên 1.448 tỷ đồng
# Đang xử lý tin thứ 104: Kỷ lục 1,2 triệu tỷ đồng của tỷ phú Phạm Nhật Vượng
# Đang xử lý tin thứ 105: Chuyện khó tin trong gia đình Warren Buffett: Con gái duy nhất hơn 20 tuổi mới biết cha là tỷ phú, từng phải giao đồ ăn, bán báo để kiếm tiền
# Đang xử lý tin thứ 106: Ông Trương Gia Bình bất ngờ treo thưởng "nóng" tới 100 triệu để nhân viên cưới và sinh con trong 1 năm tới
# Đang xử lý tin thứ 107: Chứng khoán Bảo Minh không còn là cổ đông tại Bidiphar
# Đang xử lý tin thứ 108: Đại gia phố núi "có biến" khi muốn đặt dấu chấm hết cho khoản nợ nghìn tỷ với bà Trương Mỹ Lan
# Đang xử lý tin thứ 109: AgriS (SBT) trình làng chiến lược tăng trưởng mới 2025-2030 tại Đại hội đồng Cổ đông
# Đang xử lý tin thứ 110: KBSV - Mùa giao dịch bứt phá: Giải thưởng 729 triệu đồng
# Đang xử lý tin thứ 111: Nhiều chủ tịch, tổng giám đốc từ nhiệm
# Đang xử lý tin thứ 112: Quỹ ngoại “hô” VN-Index lên 3.200 điểm lỗ 3 tháng liên tiếp
# Đang xử lý tin thứ 113: CTCK điểm tên loạt doanh nghiệp định giá thấp, triển vọng quý 4 tích cực
# Đang xử lý tin thứ 114: Lịch sự kiện và tin vắn chứng khoán ngày 8/12/2025
# Đang xử lý tin thứ 115: Một cổ phiếu tăng gần 500% sau chưa đầy 1 tháng
# Đang xử lý tin thứ 116: Loạt dự án lớn triển khai, cơ hội đầu tư trên TTCK ra sao?
# Đang xử lý tin thứ 117: “Sóng mới” đang hình thành, chuyên gia chỉ điểm 4 nhóm cổ phiếu sẽ là tâm điểm hút tiền mạnh
# Đang xử lý tin thứ 118: Thông tin khẩn về tin nhắn trên Zalo, tất cả người dân cần biết càng sớm càng tốt
# Đang xử lý tin thứ 119: Lideco sắp chi gần 122 tỷ đồng tạm ứng cổ tức năm 2025
# Đang xử lý tin thứ 120: Chỉ dấu gì đang chờ đợi nhà đầu tư chứng khoán?
# Đang xử lý tin thứ 121: Điểm tên các siêu dự án giao thông sắp 'trình làng'
# Đang xử lý tin thứ 122: Góc nhìn chuyên gia: Thị trường đang ở giai đoạn đầu của con sóng mới, VN-Index có thể rung lắc trước khi hướng tới mốc 1.800 điểm
# Đang xử lý tin thứ 123: Vingroup công bố rót 28 triệu USD lập công ty con tại Congo, tìm kiếm cơ hội kinh doanh bất động sản, ô tô điện
# Đang xử lý tin thứ 124: Tin mới về doanh nghiệp được Vingroup cho vay tiền với lãi suất 0%
# Đang xử lý tin thứ 125: Lịch chốt quyền cổ tức 8/12– 12/12: "Vua bút bi" Thiên Long, SSI chuẩn bị lăn chốt
# Đang xử lý tin thứ 126: Số lượng tài khoản chứng khoán mở mới xuống thấp nhất trong vòng 4 tháng
# Đang xử lý tin thứ 127: Trước mặt tỷ phú Phạm Nhật Vượng, nữ GS nhiều lần đến VN đề xuất bất ngờ tại Lễ trao giải VinFuture 2025
# Đang xử lý tin thứ 128: Quỹ ETF KraneShares Dragon Capital Vietnam Growth Index chính thức niêm yết trên NYSE
# Đang xử lý tin thứ 129: Hơn 19.600 tỷ đồng trái phiếu doanh nghiệp phát hành trong tháng 11/2025
# Đang xử lý tin thứ 130: Một quỹ ngoại giảm sở hữu tại Văn Phú
# Đang xử lý tin thứ 131: Cảnh báo sàn giao dịch tiền mã hóa giả mạo, dẫn dụ nhà đầu tư
# Đang xử lý tin thứ 132: Cổ phiếu của tỷ phú Phạm Nhật Vượng bất ngờ được khối ngoại mua ròng đột biến trong tuần đầu tháng 12
# Đang xử lý tin thứ 133: Quốc Cường Gia Lai muốn bán tài sản để trả món nợ liên quan bà Trương Mỹ Lan
# Đang xử lý tin thứ 134: Thị trường tiền số hôm nay, 5-12: Bitcoin vẫn là ẩn số với nhà đầu tư
# Đang xử lý tin thứ 135: Fecon chốt ngày thanh toán cổ tức lần 2 năm 2022 bằng tiền
# Đang xử lý tin thứ 136: Thành viên SCIC đăng ký mua 2 triệu cổ phiếu FPT
# Đang xử lý tin thứ 137: Cổ phiếu VIC và phần còn lại của thị trường chứng khoán
# Đang xử lý tin thứ 138: Chứng khoán nghịch lý 'lãi chỉ số, lỗ tài khoản'
# Đang xử lý tin thứ 139: Thần tốc: "Bom tấn" VPBankS chốt ngày lên sàn chứng khoán chỉ sau IPO 30 ngày, định giá 2,4 tỷ USD
# Đang xử lý tin thứ 140: Đại gia phố núi muốn “đặt dấu chấm hết” cho số nợ nghìn tỷ với bà Trương Mỹ Lan
# Đang xử lý tin thứ 141: Phiên 5/12: Khối ngoại "quay xe" bán ròng gần 700 tỷ đồng, cổ phiếu nào bị "xả" mạnh nhất?
# Đang xử lý tin thứ 142: Yeah1 sắp giải thể một công ty công nghệ do không còn phù hợp chiến lược
# Đang xử lý tin thứ 143: Nhà bán lẻ nội địa chiếm trọn "sân nhà": Sở hữu 81% số cửa hàng bán lẻ hiện đại, lấn át nhóm "đại gia" Nhật, Thái, Hàn
# Đang xử lý tin thứ 144: SHS lần thứ 6 được vinh danh trong Top 10 Báo cáo thường niên tốt nhất VLCA
# Đang xử lý tin thứ 145: Chứng khoán Tiên Phong sắp phát hành lô trái phiếu thứ 2 trong năm 2025
# Đang xử lý tin thứ 146: Phát Đạt sẽ phát hành 18 triệu cổ phiếu cho 177 nhân viên
# Đang xử lý tin thứ 147: Xử phạt một công ty chứng khoán
# Đang xử lý tin thứ 148: Sở Giao dịch Chứng khoán TPHCM thay biểu tượng "bò tót tấn công" sau 25 năm?
# Đang xử lý tin thứ 149: Tỉ phú Nguyễn Đăng Quang ví Masan Consumer là "viên kim cương gia bảo"
# Đang xử lý tin thứ 150: Hướng dẫn tham gia đấu giá cổ phiếu CTCP Hạ tầng GELEX
# Đang xử lý tin thứ 151: Lịch sự kiện và tin vắn chứng khoán ngày 5/12/2025
# Đang xử lý tin thứ 152: Thị trường chứng khoán sẽ ra sao khi lãi suất huy động rục rịch tăng?
# Đang xử lý tin thứ 153: Ấn Độ giao 200ha đất cho VinFast mở rộng nhà máy
# Đang xử lý tin thứ 154: Cực căng: Ổ nhóm tại Campuchia giả mạo công ty của ông Phạm Nhật Vượng, Đỗ Minh Phú lừa 500 người Việt
# Đang xử lý tin thứ 155: Chứng khoán Rồng Việt nhận cú đúp giải thưởng tại VLCA 2025
# Đang xử lý tin thứ 156: Chứng khoán tăng 7 phiên liên tiếp
# Đang xử lý tin thứ 157: Quy trình 4 bước của đường dây lừa đảo nghìn tỷ có bản doanh tại Campuchia
# Đang xử lý tin thứ 158: Hôm nay, 3 công ty tỷ USD trên sàn chứng khoán vừa được một thế lực tung hàng trăm tỷ "gom" ồ ạt
# Đang xử lý tin thứ 159: Cổ phiếu tăng trần 12 phiên liên tiếp, Giầy Thượng Đình lên tiếng giải trình
# Đang xử lý tin thứ 160: Chứng khoán ngày 4-12: Dòng tiền "xoay tua" sang cổ phiếu bất động sản
# Đang xử lý tin thứ 161: Doanh nghiệp ở Hà Nội đầu tư hơn 400 tỉ đồng chuyển 100% sang xe buýt điện
# Đang xử lý tin thứ 162: Khối ngoại tung hơn 1.000 tỷ đồng "gom" một cổ phiếu ngân hàng trong phiên 4/12
# Đang xử lý tin thứ 163: Đại gia thịt cạnh tranh với Masan, C.P báo lãi tăng vọt
# Đang xử lý tin thứ 164: Sau cái bắt tay với VinMetal, Pomina chuẩn bị họp tái cấu trúc
# Đang xử lý tin thứ 165: Chính thức: VPS được cấp mã chứng khoán VCK
# Đang xử lý tin thứ 166: Nhóm quỹ ngoại giảm sở hữu tại Tập đoàn Đất Xanh xuống dưới 9%
# Đang xử lý tin thứ 167: Chủ tịch UBCKNN Vũ Thị Chân Phương: Nâng hạng thị trường là khởi đầu cho giai đoạn phát triển mới
# Đang xử lý tin thứ 168: Đại diện FTSE chỉ ra yếu tố then chốt để dòng vốn tỷ USD đổ vào Việt Nam khi đã chính thức nâng hạng
# Đang xử lý tin thứ 169: Vì sao nhà đầu tư đang chú ý đến một cổ phiếu tiêu dùng sắp niêm yết HOSE?
# Đang xử lý tin thứ 170: Vietcap ra mắt Warren - Chuyên gia tư vấn tài chính AI
# Đang xử lý tin thứ 171: Lịch sự kiện và tin vắn chứng khoán ngày 4/12/2025
# Đang xử lý tin thứ 172: HOSE công bố 66 mã cổ phiếu bị cắt margin trong tháng 12
# Đang xử lý tin thứ 173: Thị trường sắp có thêm công ty chứng khoán vốn hóa tỷ USD
# Đang xử lý tin thứ 174: Một doanh nghiệp niêm yết "chơi lớn" trả cổ tức khủng hơn 16.600 đồng/cp dịp cuối năm
# Đang xử lý tin thứ 175: Chứng khoán SSI nâng dự báo cho Thế giới di động, lợi nhuận quý 4 dự kiến tăng gấp đôi lên 1.700 tỷ đồng
# Đang xử lý tin thứ 176: Thị trường tiền số hôm nay, 3-12: Biến động mạnh của Bitcoin giống hệt cổ phiếu Google
# Đang xử lý tin thứ 177: Cổ phiếu ngân hàng ‘lên tiếng’
# Đang xử lý tin thứ 178: Hai mã chứng khoán bị tự doanh CTCK bán ròng đột biến hàng trăm tỷ trong phiên 3/12
# Đang xử lý tin thứ 179: Tôn Đông Á kinh doanh ra sao trước khi nộp hồ sơ niêm yết trên HoSE?
# Đang xử lý tin thứ 180: Phiên 3/12: Khối ngoại mua ròng kỷ lục, tung 3.400 tỷ "gom" cổ phiếu của tỷ phú Phạm Nhật Vượng
# Đang xử lý tin thứ 181: Nóng: Dragon Capital sắp lên sàn chứng khoán
# Đang xử lý tin thứ 182: Cổ đông lớn của Gemadept muốn ‘xả hàng’ 10 triệu cổ phiếu GMD
# Đang xử lý tin thứ 183: Chưa từng có: FPT bắt tay Vietnam Airlines mở "chuyến bay hẹn hò" mai mối cho nhân viên còn độc thân
# Đang xử lý tin thứ 184: Xử phạt hành chính 2 doanh nghiệp vi phạm trong lĩnh vực chứng khoán
# Đang xử lý tin thứ 185: "Cá mập" quy mô gần 600 triệu USD dự kiến bán mạnh cổ phiếu của tỷ phú Phạm Nhật Vượng
# Đang xử lý tin thứ 186: MBS hợp tác cùng Dragon Capital phân phối chứng chỉ quỹ mở trên nền tảng MFUND
# Đang xử lý tin thứ 187: VISC dự chi 120 tỷ đồng mua trụ sở mới tại dự án của thành viên cùng nhóm
# Đang xử lý tin thứ 188: Lịch sự kiện và tin vắn chứng khoán ngày 3/12/2025
# Đang xử lý tin thứ 189: Một thế lực nắm hơn 22.000 tấn Bạc giữa cơn sốt giá
# Đang xử lý tin thứ 190: Xu hướng đi ngang ngắn hạn chưa bị phá vỡ, kịch bản nào cho VN-Index trong tháng cuối năm?
# Đang xử lý tin thứ 191: CTCK điểm tên loạt "siêu cổ phiếu" tiềm năng với biên lãi gộp tăng trưởng liên tục
# Đang xử lý tin thứ 192: Một mã Bluechips bất ngờ bị tự doanh CTCK bán ròng mạnh trong phiên 2/12
# Đang xử lý tin thứ 193: Sức nóng thoái vốn tác động gì tới cổ phiếu?
# Đang xử lý tin thứ 194: Nhựa Tiền Phong bị phạt và truy thu thuế hơn 10 tỷ đồng
# Đang xử lý tin thứ 195: Tổng Giám đốc ABS: So với các thị trường trong khu vực, Việt Nam vẫn nổi bật nhờ mức tăng trưởng cao và định giá hợp lý
# Đang xử lý tin thứ 196: Khối ngoại trở lại "gom" hơn 650 tỷ đồng cổ phiếu Việt Nam trong phiên VN-Index tăng mạnh, đâu là tâm điểm?
# Đang xử lý tin thứ 197: Quỹ đầu tư liên quan đến Chủ tịch Nguyễn Hải Châu muốn gom 3,3 triệu cổ phiếu EVS
# Đang xử lý tin thứ 198: Vì sao Masan Consumer chọn thời điểm này để công bố kế hoạch niêm yết HOSE?
# Đang xử lý tin thứ 199: Vingroup phát hành 1.000 tỷ đồng trái phiếu, lãi suất 12%/năm
# Đang xử lý tin thứ 200: "Chủ nhân giải thưởng hơn 100 tỷ của ông Phạm Nhật Vượng sẽ có tầm ảnh hưởng quy mô dân số rất lớn"
# Đang xử lý tin thứ 201: Ai là cổ đông lớn nhất của Thủy điện Sông Ba Hạ?
# Đang xử lý tin thứ 202: Quỹ ngoại Phần Lan tăng sở hữu tại Tập đoàn Hà Đô lên hơn 10%
# Đang xử lý tin thứ 203: Lịch sự kiện và tin vắn chứng khoán ngày 2/12/2025
# Đang xử lý tin thứ 204: Chứng khoán VPS được chấp thuận niêm yết trên HoSE
# Đang xử lý tin thứ 205: Chứng khoán bước vào tháng có xác suất tăng điểm cao, CTCK điểm tên loạt nhóm ngành hút dòng tiền và "khỏe" hơn thị trường
# Đang xử lý tin thứ 206: Chuyên gia dự báo nhóm cổ phiếu sẽ "dẫn sóng" thị trường năm 2026
# Đang xử lý tin thứ 207: Cá mập “hô” VN-Index lên 3.200 điểm vừa chi hàng chục tỷ gom cùng lúc 2 mã cổ phiếu
# Đang xử lý tin thứ 208: Góc khuất ít người biết khi tỉ phú Trần Đình Long bước chân vào nông nghiệp
# Đang xử lý tin thứ 209: Thị trường tiền số hôm nay, 1-12: Nhà đầu tư lo Bitcoin rớt xuống 40.000 USD
# Đang xử lý tin thứ 210: VN-Index vượt 1.700 điểm, tài khoản nhà đầu tư vẫn "bốc hơi"
# Đang xử lý tin thứ 211: Một thế lực tung hơn trăm tỷ "gom" cổ phiếu của tỷ phú Phạm Nhật Vượng
# Đang xử lý tin thứ 212: Gia đình ông Bùi Thành Nhơn còn bao nhiêu cổ phần tại Novaland?
# Đang xử lý tin thứ 213: Công ty Thủy điện Sông Ba Hạ tạm thay đổi nhân sự điều hành
# Đang xử lý tin thứ 214: VN-Index vượt 1.700 điểm trong phiên đầu tháng
# Đang xử lý tin thứ 215: Phiên 1/12: Khối ngoại quay đầu bán ròng hàng trăm tỷ đồng, cổ phiếu nào bị "xả" mạnh nhất?
# Đang xử lý tin thứ 216: 11 cá nhân dự mua 125 triệu cổ phiếu riêng lẻ của Cảng Phước An
# Đang xử lý tin thứ 217: Angimex bị xử phạt do vi phạm công bố thông tin
# Đang xử lý tin thứ 218: Một công ty chứng khoán lên tiếng về sự cố kết nối với HOSE và HNX
# Đang xử lý tin thứ 219: VPBankS chính thức nộp hồ sơ niêm yết gần 1,9 tỷ cổ phiếu VPX lên HOSE
# Đang xử lý tin thứ 220: Sắc xanh mã VIC và VJC đưa 2 tỷ phú Việt thăng hạng trên danh sách người giàu nhất thế giới
# Đang xử lý tin thứ 221: VN-Index vượt 1.700 điểm
# Đang xử lý tin thứ 222: Biến động lớn ở Tập đoàn KIDO
# Đang xử lý tin thứ 223: KIS Việt Nam chốt ngày chào bán 78,9 triệu cổ phiếu cho cổ đông
# Đang xử lý tin thứ 224: VPS muốn vay tối đa 6.900 tỷ đồng từ Techcombank
# Đang xử lý tin thứ 225: Cháy tại nhà máy bia Hà Nội
# Đang xử lý tin thứ 226: Lịch sự kiện và tin vắn chứng khoán ngày 1/12/2025
# Đang xử lý tin thứ 227: 5 nhân tố này có thể dẫn dắt đà bứt phá của chứng khoán Việt Nam năm 2026
# Đang xử lý tin thứ 228: Đầu tư công tăng tốc cuối năm, CTCK chỉ ra loạt nhóm cổ phiếu hưởng lợi trực tiếp
# Đang xử lý tin thứ 229: VN-Index tiến sát vùng 1.700 điểm nhưng thanh khoản liên tục "tụt áp", điều gì đang diễn ra?
# Đang xử lý tin thứ 230: Thị trường tiền số hôm nay, 30-11: Cảnh báo cú ngoặt bất ngờ với Bitcoin
# Đang xử lý tin thứ 231: Những doanh nghiệp lớn nào sắp phải di dời khỏi trung tâm Hà Nội?
# Đang xử lý tin thứ 232: Bước vào tháng cuối năm, chứng khoán có 'dễ thở'?
# Đang xử lý tin thứ 233: Góc nhìn chuyên gia: VN-Index hướng tới mốc 1.700 điểm, "săn" cơ hội tại một số nhóm cổ phiếu dẫn dắt đang được chiết khấu tốt
# Đang xử lý tin thứ 234: Con gái Chủ tịch Tập đoàn PC1 hoàn tất mua vào 4 triệu cổ phiếu PC1 đã đăng ký
# Đang xử lý tin thứ 235: VIDEO: Chủ tịch Dragon Capital nói về lợi ích khi 5 triệu hộ kinh doanh lên doanh nghiệp
# Đang xử lý tin thứ 236: Lãnh đạo Bệnh viện TNH ‘gom’ thành công 6 triệu cổ phiếu TNH
# Đang xử lý tin thứ 237: Dừng thương vụ hoán đổi nợ của 2 'ông lớn' bất động sản
# Đang xử lý tin thứ 238: Hiểu đúng về pha loãng cổ phiếu khi doanh nghiệp chia cổ tức
# Đang xử lý tin thứ 239: 'Niềm tin đã quay trở lại, doanh nghiệp nhìn thấy thị trường sáng hơn'
# Đang xử lý tin thứ 240: Lịch chốt quyền cổ tức 1/12– 5/12: FPT, CTD, MSH đồng loạt "lăn chốt", cổ tức tiền mặt cao nhất 40%
# Đang xử lý tin thứ 241: Vietjet đã cập nhật phần mềm 45/69 máy bay sau thông báo khẩn của Airbus
# Đang xử lý tin thứ 242: Chứng khoán Bảo Minh muốn thoái sạch vốn tại một công ty dược
# Đang xử lý tin thứ 243: Xử phạt loạt doanh nghiệp vi phạm liên quan trái phiếu
# Đang xử lý tin thứ 244: Các tổ chức hàng đầu thế giới “ồ ạt” gom Bạc khi giá được dự báo có thể lên 100 USD
# Đang xử lý tin thứ 245: Dabaco bị xử phạt gần 400 triệu đồng
# Đang xử lý tin thứ 246: Haxaco bị xử phạt do vi phạm liên quan đến thuế
# Đang xử lý tin thứ 247: Một hiện tượng mới đang kích hoạt sóng tăng giá mạnh ở loạt cổ phiếu
# Đang xử lý tin thứ 248: Một cổ phiếu tăng dựng đứng 350% trong 1 tháng sau khi thoái vốn giá cao, chuẩn bị họp ĐHĐCĐ bất thường
# Đang xử lý tin thứ 249: Khối ngoại hạ nhiệt bán ròng trong tuần cuối tháng 11, ngược chiều mạnh tay chi hơn 600 tỷ "gom" một mã cổ phiếu
# Đang xử lý tin thứ 250: Thị trường tiền số hôm nay, 28-11: Một quyết định khó khăn đang chờ Bitcoin
# Đang xử lý tin thứ 251: Kinh doanh bứt phá ngoạn mục, OCBS tăng vốn liên tiếp lên 3.200 tỷ cùng hàng loạt chuyển động lớn
# Đang xử lý tin thứ 252: Hai cổ phiếu nhà tỷ phú đồng loạt bị tự doanh CTCK "xả" mạnh trong phiên cuối tuần
# Đang xử lý tin thứ 253: Doanh nghiệp Việt đầu tiên vốn hóa vượt 1 triệu tỷ đồng
# Đang xử lý tin thứ 254: VN-Index lên sát 1.700 điểm, tỉ phú Phạm Nhật Vượng vào tốp 98 người giàu nhất thế giới
# Đang xử lý tin thứ 255: Thấy gì từ việc doanh nghiệp thoái vốn dồn dập?
# Đang xử lý tin thứ 256: Phiên 28/11: Khối ngoại đảo chiều mua ròng, chi hàng trăm tỷ đồng gom loạt cổ phiếu VN30
# Đang xử lý tin thứ 257: Vốn hóa Vingroup vượt 1 triệu tỷ đồng, bằng Vietcombank, VietinBank và BIDV cộng lại
# Đang xử lý tin thứ 258: TNG dùng dự án, hợp đồng tiền gửi làm tài sản thế chấp tại ngân hàng
# Đang xử lý tin thứ 259: Hé lộ địa điểm sàn tiền số lớn nhất thế giới dự kiến đặt trụ sở tại TPHCM
# Đang xử lý tin thứ 260: 30 tỷ USD sắp 'rót’ vào chứng khoán Việt Nam?
# Đang xử lý tin thứ 261: Ba doanh nghiệp bất động sản bị xử phạt vi phạm hành chính
# Đang xử lý tin thứ 262: Lịch sự kiện và tin vắn chứng khoán ngày 28/11/2025
# Đang xử lý tin thứ 263: HOSE công bố 65 mã cổ phiếu bị cắt margin
# Đang xử lý tin thứ 264: PYN Elite Fund "hô" VN-Index lên 3.200 điểm
# Đang xử lý tin thứ 265: Tổng Giám đốc Vingroup đề nghị được vay 80% vốn đầu tư dự án Đường sắt cao tốc, hoàn trả trong vòng 30 năm
# Đang xử lý tin thứ 266: Vietravel và Vietravel Airlines 'đường ai nấy đi'
# Đang xử lý tin thứ 267: F88 lần đầu tiên phát hành trái phiếu ra công chúng với lãi suất 10%/năm
# Đang xử lý tin thứ 268: Chứng khoán ngày 27-11: Cổ phiếu giảm áp đảo, một mã ngân hàng bất ngờ "tím ngắt"
# Đang xử lý tin thứ 269: HDBank thoái vốn tại Vietjet
# Đang xử lý tin thứ 270: Chính thức mở cổng bình chọn "Ngân hàng Kim Chủ của năm" và "Cổ phiếu ngân hàng được nhà đầu tư yêu thích của năm"
# Đang xử lý tin thứ 271: Một cổ phiếu bất ngờ được tự doanh CTCK "gom" đột biến nghìn tỷ trong phiên 27/11
# Đang xử lý tin thứ 272: Phiên 27/11: Khối ngoại mạnh tay chi hơn 300 tỷ "gom" một mã cổ phiếu
# Đang xử lý tin thứ 273: Cổ phiếu doanh nghiệp gần 70 năm tuổi bất ngờ "tím lịm" 7 phiên liên tiếp, điều gì đang diễn ra?
# Đang xử lý tin thứ 274: Kido muốn trả lại thương hiệu Merino và Celano cho Nutifood, lùi thời gian trả cổ tức
# Đang xử lý tin thứ 275: Động thái mới của tỉ phú Phạm Nhật Vượng tại công ty đường sắt cao tốc VinSpeed
# Đang xử lý tin thứ 276: Lãnh đạo HSC đăng ký bán 350.000 cổ phiếu HCM
# Đang xử lý tin thứ 277: UBCKNN xử phạt loạt doanh nghiệp do vi phạm công bố thông tin
# Đang xử lý tin thứ 278: Chứng khoán Kafi bầu bổ sung 2 thành viên HĐQT
# Đang xử lý tin thứ 279: BlackRock mạnh tay gom Bạc, chuyên gia dự báo giá còn có thể tăng gấp đôi
# Đang xử lý tin thứ 280: ‘Đại gia’ đánh bạc 10 triệu USD trong khách sạn Pullman bị truy tố trong đường dây lừa đảo tiền ảo đa cấp
# Đang xử lý tin thứ 281: Vụ án Trương Mỹ Lan: Chi tiền đợt 5 cho 42.000 trái chủ
# Đang xử lý tin thứ 282: Ủy ban Chứng khoán Nhà nước phát cảnh báo
# Đang xử lý tin thứ 283: Lịch sự kiện và tin vắn chứng khoán ngày 27/11/2025
# Đang xử lý tin thứ 284: Chứng khoán Hòa Bình bị đình chỉ một phần hoạt động giao dịch
# Đang xử lý tin thứ 285: Gần nửa sắc tím HOSE đến từ nhóm cổ phiếu này, 3.000 tỷ "sang tay" chỉ trong 1 phiên
# Đang xử lý tin thứ 286: Công ty đại gia Đặng Thành Tâm được dự báo lợi nhuận tăng vọt trong năm 2026, dự án tỷ USD với Tập đoàn Trump sắp có bước tiến mới
# Đang xử lý tin thứ 287: 100.000 m2 tôn được gửi khẩn cấp tới người dân Đắk Lắk để sửa nhà sau mưa lũ
# Đang xử lý tin thứ 288: Thị trường tiền số hôm nay, 26-11: Diễn biến hiếm gặp bất ngờ xuất hiện
# Đang xử lý tin thứ 289: Triệt phá đường dây lừa đảo dựng “dự án ma” trên Binance Smart Chain, phong tỏa gần 100.000 USDT
# Đang xử lý tin thứ 290: Hàng loạt công ty bất động sản bị xử phạt
# Đang xử lý tin thứ 291: Công ty con của Novaland lại gặp khó
# Đang xử lý tin thứ 292: Cổ phiếu Gelex tăng trần sau công bố quan trọng
# Đang xử lý tin thứ 293: Một cổ phiếu ngân hàng bất ngờ được tự doanh CTCK "gom" mạnh trong phiên 26/11
# Đang xử lý tin thứ 294: Chứng khoán ngày 26-11: VN-Index bật mạnh hơn 20 điểm
# Đang xử lý tin thứ 295: Ông Phạm Nhật Quân Anh làm Tổng Giám đốc VinMetal
# Đang xử lý tin thứ 296: Khối ngoại bất ngờ mua ròng gần 600 tỷ đồng trong phiên VN-Index bứt phá, cổ phiếu nào được gom mạnh nhất?
# Đang xử lý tin thứ 297: Ông Nguyễn Quốc Kỳ nói về việc bán hết cổ phần Vietravel Airlines và rút khỏi mảng hàng không
# Đang xử lý tin thứ 298: Một công ty chứng khoán bị đình chỉ hoạt động mua chứng khoán trên sàn từ ngày 28/11
# Đang xử lý tin thứ 299: Con trai ông Phạm Nhật Vượng giữ chức vụ mới
# Đang xử lý tin thứ 300: Trung Quốc: Đào bitcoin bất chấp lệnh cấm
# Đang xử lý tin thứ 301: PVX bị phạt do vi phạm quy định về giao dịch với bên liên quan và công bố thông tin không đầy đủ
# Đang xử lý tin thứ 302: Thực hư chuyện quỹ ngoại quy mô 500 triệu USD phải bán toàn bộ danh mục cổ phiếu Việt Nam khi nâng hạng
# Đang xử lý tin thứ 303: Điều chỉnh quy định xử phạt vi phạm hành chính về chào bán, phát hành cổ phiếu riêng lẻ từ 9/1/2026
# Đang xử lý tin thứ 304: Bầu Đức giải mã cơn sốt cà phê
# Đang xử lý tin thứ 305: "Cú đấm thép" 85.000 tỷ phả hơi nóng, CTCK dự báo lợi nhuận Hòa Phát có thể tăng trưởng mạnh trong quý 4/2025
# Đang xử lý tin thứ 306: Chủ tịch và Tổng Giám đốc thoái gần hết vốn, cổ phiếu "bốc đầu" tăng kịch trần
# Đang xử lý tin thứ 307: Chuyện gì đây: Tổng giám đốc và dàn lãnh đạo một công ty đồng loạt bán sạch cổ phiếu
# Đang xử lý tin thứ 308: Chủ tịch một tập đoàn công nghệ "gom" thêm gần 5,5 triệu cổ phiếu Vinasun
# Đang xử lý tin thứ 309: Nâng hạng là bước khởi đầu, Chủ tịch FiinGroup hé lộ chìa khoá giúp thị trường vốn Việt Nam thực sự "cất cánh"
# Đang xử lý tin thứ 310: Con trai tỉ phú Phạm Nhật Vượng làm Tổng giám đốc VinMetal
# Đang xử lý tin thứ 311: Tỷ phú Phạm Nhật Vượng vừa lập kỷ lục mới chưa từng có ở Việt Nam trong "ngày đỏ lửa"
# Đang xử lý tin thứ 312: Hạ tầng GELEX chính thức được chấp thuận IPO 100 triệu cổ phiếu
# Đang xử lý tin thứ 313: Tỷ phú Việt 'bỏ túi' tỷ USD trong phiên chứng khoán đỏ lửa
# Đang xử lý tin thứ 314: Tự doanh CTCK bất ngờ "tung tiền" gom một cổ phiếu giảm mạnh trong phiên 25/11
# Đang xử lý tin thứ 315: Dragon Capital tăng sở hữu tại Tập đoàn Đất Xanh lên hơn 9%
# Đang xử lý tin thứ 316: Nóng: Vingroup cho Pomina vay vốn lưu động lãi suất 0%, ưu tiên làm nhà cung cấp thép cho VinFast, Vinhomes, VinSpeed
# Đang xử lý tin thứ 317: Chứng khoán giảm, tài sản tỉ phú Phạm Nhật Vượng vẫn tăng mạnh, vào tốp 100 thế giới
# Đang xử lý tin thứ 318: Cổ phiếu bầu Đức có “biến”
# Đang xử lý tin thứ 319: Phiên 25/11: Khối ngoại giảm bán ròng, ngược chiều tung hàng trăm tỷ gom một cổ phiếu ngân hàng
# Đang xử lý tin thứ 320: MST chào bán thành công 30 triệu cổ phiếu cho 9 nhà đầu tư trong nước
# Đang xử lý tin thứ 321: SSI sắp chào bán hơn 415 triệu cổ phiếu rẻ bằng một nửa thị giá
# Đang xử lý tin thứ 322: Vietravel sẽ rút hết vốn tại Vietravel Airlines
# Đang xử lý tin thứ 323: Binance Charity ủng hộ đồng bào lũ lụt miền Trung 5 tỷ đồng
# Đang xử lý tin thứ 324: Đầu tư Thương mại SMC muốn chuyển nhượng loạt tài sản tại hai công ty con
# Đang xử lý tin thứ 325: Xử phạt hai doanh nghiệp do vi phạm công bố thông tin
# Đang xử lý tin thứ 326: Nhà cung cấp bao bì cho Unilever, Pepsico dự kiến hủy tư cách công ty đại chúng, kết thúc 13 năm niêm yết HoSE
# Đang xử lý tin thứ 327: Biến động cổ đông tại Chứng khoán DSC sau đợt chào bán cổ phiếu
# Đang xử lý tin thứ 328: Vinhomes tất toán lô trái phiếu 2.000 tỷ đồng
# Đang xử lý tin thứ 329: Chuyên gia chỉ ra điều quan trọng nhất với thị trường chứng khoán ngay lúc này
# Đang xử lý tin thứ 330: Idico chấm dứt hoạt động chi nhánh tại Hà Nội
# Đang xử lý tin thứ 331: FPT sẵn sàng làm 'tổng công trình sư' phát triển KHCN, đổi mới sáng tạo ở Quảng Ninh
# Đang xử lý tin thứ 332: FPTS bán thành công gần 1,2 triệu cổ phiếu MSH
# Đang xử lý tin thứ 333: Vingroup lên kế hoạch phát hành 1.000 tỷ đồng trái phiếu nhằm mục đích cơ cấu nợ
# Đang xử lý tin thứ 334: Lịch sự kiện và tin vắn chứng khoán ngày 25/11/2025
# Đang xử lý tin thứ 335: CTCK cập nhật một số nội dung quan trọng trong tiến trình nâng hạng chứng khoán Việt Nam
# Đang xử lý tin thứ 336: VN-Index dự báo sẽ vượt 1.700 điểm, CTCK gọi tên nhóm cổ phiếu kỳ vọng hút tiền mạnh
# Đang xử lý tin thứ 337: Thị trường tiền số hôm nay, 24-11: Bitcoin đang giấu điều gì trước giờ G cuối tháng 11?
# Đang xử lý tin thứ 338: Đề xuất xử phạt giao dịch tài sản mã hóa qua sàn không phép
# Đang xử lý tin thứ 339: Chứng khoán 24-11: VN-Index tăng mạnh nhưng sắc đỏ vẫn áp đảo thị trường
# Đang xử lý tin thứ 340: Tung gần 400 tỷ "gom" cổ phiếu Việt Nam trong phiên đầu tuần, tự doanh CTCK săn lùng mã nào nhiều nhất?
# Đang xử lý tin thứ 341: Khối ngoại thẳng tay bán ròng hơn 1.200 tỷ phiên đầu tuần, cổ phiếu nào bị "xả" mạnh nhất?
# Đang xử lý tin thứ 342: Hiện tượng bất thường tại một văn phòng lừa đảo: 438 tỷ đồng vừa bị triệt phá, điều tra 10.000 tài khoản ngân hàng, số tiền thiệt hại có thể còn tăng
# Đang xử lý tin thứ 343: 6 nhà đầu tư nhóm ROX Group dự mua 166 triệu cổ phiếu riêng lẻ của SBSI
# Đang xử lý tin thứ 344: Vingroup gửi công văn hỏa tốc đề xuất hỗ trợ khẩn cấp thêm 500 tỷ đồng cứu trợ miền Trung
# Đang xử lý tin thứ 345: FPT thiết lập quan hệ hợp tác với ITIDA, thúc đẩy chuyển đổi số tại Ai Cập
# Đang xử lý tin thứ 346: Nhà đầu tư rần rần “xin vía” top Chứng Trường Bạc Tỷ mùa 2: Sau 1 tuần biến động, hiệu suất vượt 16%
# Đang xử lý tin thứ 347: Lịch sự kiện và tin vắn chứng khoán ngày 24/11/2025
# Đang xử lý tin thứ 348: Năm 2025 bùng nổ của ngành chứng khoán Việt Nam: Hàng loạt kỷ lục mới được thiết lập
# Đang xử lý tin thứ 349: Ngành chứng khoán củng cố vị thế trước kỳ vọng nâng hạng lên "Thị trường mới nổi thứ cấp"
# Đang xử lý tin thứ 350: Chuyên gia chỉ ra một tín hiệu quan trọng cho thấy VN-Index sắp bước vào sóng mới, loạt nhóm cổ phiếu kỳ vọng hút tiền
# Đang xử lý tin thứ 351: Chứng khoán "tăng trong nghi ngờ", dự báo mới nhất cho tuần tới
# Đang xử lý tin thứ 352: Xanh SM của tỷ phú Phạm Nhật Vượng bắt đầu triển khai dịch vụ xe ghép 7 chỗ liên tỉnh bằng Limo Green, chạy từ 4h sáng, tần suất 60 phút/chuyến
# Đang xử lý tin thứ 353: Truy tố 15 người trong đường dây tiền ảo kiểu đa cấp tại các công ty BBI và BBA
# Đang xử lý tin thứ 354: Tập đoàn Hoa Sen cứu trợ nhu yếu phẩm cho bà con vùng lũ xuyên đêm
# Đang xử lý tin thứ 355: PVT Logistics chốt ngày phát hành hơn 13 triệu cổ phiếu trả cổ tức
# Đang xử lý tin thứ 356: Tâm điểm giao dịch chứng khoán đang hướng vào nhóm nào?
# Đang xử lý tin thứ 357: Góc nhìn chuyên gia: Nhịp điều chỉnh bất ngờ có thể xuất hiện, khả năng test lại đáy 1.580 cần được tính đến
# Đang xử lý tin thứ 358: Chứng khoán Quốc Gia không mua hết 10 triệu cổ phiếu SAM đã đăng ký
# Đang xử lý tin thứ 359: VNDirect chào bán 2.000 tỷ đồng trái phiếu ra công chúng
# Đang xử lý tin thứ 360: Lịch chốt quyền cổ tức 24/11– 28/11: Cổ tức tiền mặt cao nhất 8.500 đồng/cp
# Đang xử lý tin thứ 361: Những câu hỏi thường gặp về ETF nhà đầu tư mới cần biết
# Đang xử lý tin thứ 362: Bitcoin lao dốc kỷ lục, thị trường tiền số đứng trước 'ranh giới nguy hiểm'
# Đang xử lý tin thứ 363: Người thân thành viên HĐQT VIB muốn chuyển nhượng 10 triệu cổ phiếu
# Đang xử lý tin thứ 364: Một công ty chứng khoán liên tục bị UBCKNN xử phạt hành chính
# Đang xử lý tin thứ 365: Vì sao Chứng khoán Thủ Đô bị xử phạt hành chính?
# Đang xử lý tin thứ 366: Nông nghiệp Hoà Phát (HPA): IPO 30 triệu cổ phiếu giá 41.900 đồng/cp
# Đang xử lý tin thứ 367: VinFast bán hơn 110.000 xe chỉ trong 9 tháng, doanh thu tăng vọt
# Đang xử lý tin thứ 368: Cổ phiếu Giầy Thượng Đình (GTD) tăng trần 3 phiên liền, sau tin Hà Nội thoái vốn
# Đang xử lý tin thứ 369: Công ty con của CII sở hữu gần 55% vốn Năm Bảy Bảy
# Đang xử lý tin thứ 370: MBS muốn tiếp tục phát hành hơn 342 triệu cổ phiếu để tăng vốn
# Đang xử lý tin thứ 371: Khi dữ liệu và thuật toán dẫn nhịp thị trường: Góc nhìn từ DNSE Future Tech Summit
# Đang xử lý tin thứ 372: Khối ngoại bán ròng hàng nghìn tỷ trong tuần 17-21/11, ngược chiều tung 1.000 tỷ đồng "gom" một cổ phiếu Bluechip
# Đang xử lý tin thứ 373: Chứng khoán sắp được mua bán trong ngày, nhà đầu tư làm gì để tránh lỗ?
# Đang xử lý tin thứ 374: Chuyên gia Agriseco điểm tên 2 cổ phiếu thủy sản có lợi thế vượt trội, dự báo duy trì tăng trưởng cao thời gian tới
# Đang xử lý tin thứ 375: Dầu khí Nam Sông Hậu bị 'bêu tên' nợ thuế lớn nhất Cần Thơ
# Đang xử lý tin thứ 376: Cổ phiếu công ty bán xe điện "có biến"
# Đang xử lý tin thứ 377: Bầu Đức bất ngờ mang sầu riêng bán trong nước
# Đang xử lý tin thứ 378: HOSE nhận hồ sơ niêm yết, Antesco tiến gần mục tiêu 300 triệu USD
# Đang xử lý tin thứ 379: Điều gì đang khiến Bitcoin mất giá dữ dội?
# Đang xử lý tin thứ 380: Một thế lực bất ngờ “gom hàng" trở lại sau chuỗi bán ròng, ngược chiều "xả" 100 tỷ cổ phiếu bất động sản
# Đang xử lý tin thứ 381: Thủ tướng kết nối hợp tác giữa hai tập đoàn dầu khí quốc gia của Việt Nam, Nam Phi
# Đang xử lý tin thứ 382: UBND TP Hà Nội thoái vốn khỏi một doanh nghiệp gần 70 năm tuổi
# Đang xử lý tin thứ 383: Lộ diện nhóm cổ phiếu vừa 'cứu' thị trường chứng khoán
# Đang xử lý tin thứ 384: Thủ tướng thăm, làm việc tại thị trường chứng khoán lớn nhất châu Phi
# Đang xử lý tin thứ 385: Ladophar muốn dùng quỹ đầu tư phát triển và thặng dư vốn để khắc phục lỗ lũy kế
# Đang xử lý tin thứ 386: Thành viên HĐQT PGBank thay đổi kế hoạch mua cổ phiếu
# Đang xử lý tin thứ 387: Phiên 21/11: Khối ngoại bán ròng trở lại, một cổ phiếu chứng khoán bị "xả" hơn 700 tỷ đồng
# Đang xử lý tin thứ 388: Một cổ phiếu bất động sản bất ngờ tăng kịch trần, khớp lệnh đột biến: Điều gì đang diễn ra?
# Đang xử lý tin thứ 389: Lãnh đạo DIG không thực hiện toàn bộ quyền mua cổ phiếu chào bán thêm
# Đang xử lý tin thứ 390: Lãnh đạo MobiFone: Chúng tôi đang đầu tư mạnh vào 5G, AI
# Đang xử lý tin thứ 391: Idico sắp chi hơn 569 tỷ đồng tạm ứng cổ tức đợt 1/2025
# Đang xử lý tin thứ 392: PC1 hoàn tất phát hành hơn 53 triệu cổ phiếu thưởng cho hơn 14.000 cổ đông
# Đang xử lý tin thứ 393: Đề xuất mức phạt tối đa 200 triệu đồng vi phạm trong lĩnh vực tài sản mã hóa
# Đang xử lý tin thứ 394: ABS nhận giải thưởng Công ty Chứng khoán sáng tạo nhất Việt Nam về Phân tích Đầu tư 2025
# Đang xử lý tin thứ 395: Lịch sự kiện và tin vắn chứng khoán ngày 21/11/2025
# Đang xử lý tin thứ 396: UBND Hà Nội thoái toàn bộ vốn Giày Thượng Đình, dự thu ít nhất 130 tỷ đồng
# Đang xử lý tin thứ 397: Doanh nghiệp bất động sản KCN đang có 61.000 tỷ "của để dành": "Đại gia" nào đứng đầu?
# Đang xử lý tin thứ 398: Thị trường tiền số hôm nay, 20-11: Chuyên gia hé lộ tín hiệu có thể khiến nhà đầu tư bất ngờ
# Đang xử lý tin thứ 399: Mọi sự chú ý đổ dồn vào cổ phiếu một hãng hàng không
# Đang xử lý tin thứ 400: Hai cổ phiếu ngân hàng bị tự doanh CTCK bán ròng mạnh trong phiên 20/11
# Đang xử lý tin thứ 401: Chứng khoán lấy lại sắc xanh, cổ phiếu hàng không của tỉ phú Nguyễn Phương Thảo tăng kịch trần
# Đang xử lý tin thứ 402: Chủ tịch một doanh nghiệp trên HOSE hoàn tất gom cổ phiếu ngay trước đợt trả cổ tức tiền mặt 30%
# Đang xử lý tin thứ 403: Ông Phạm Nhật Vượng đón tin vui từ quê nhà
# Đang xử lý tin thứ 404: Phiên 20/11: Khối ngoại bất ngờ “gom hàng" trở lại sau chuỗi bán ròng, một cổ phiếu ngân hàng được mua mạnh
# Đang xử lý tin thứ 405: Chứng khoán Mỹ tăng điểm trước báo cáo lợi nhuận của Nvidia
# Đang xử lý tin thứ 406: Chàng trai bỏ dở đại học vừa trở thành tỷ phú trẻ nhất Ấn Độ, công ty riêng sắp IPO, ghi nhận doanh thu bùng nổ
# Đang xử lý tin thứ 407: VPI không còn là công ty mẹ của Văn Phú - B&C
# Đang xử lý tin thứ 408: Thế Giới Di Động sắp thực hiện 2 thương vụ chuyển nhượng trị giá hơn 2.100 tỷ đồng
# Đang xử lý tin thứ 409: Chứng khoán EVS trình phương án thu hồi công nợ quá hạn, miễn nhiệm 2 thành viên HĐQT
# Đang xử lý tin thứ 410: Niềm vui của tỷ phú Nguyễn Thị Phương Thảo trong ngày Nhà giáo Việt Nam
# Đang xử lý tin thứ 411: HOSE công bố 66 mã cổ phiếu bị cắt margin tháng 11
# Đang xử lý tin thứ 412: IPA phát hành thành công lô trái phiếu hơn 1.400 tỷ đồng
# Đang xử lý tin thứ 413: Hodeco tăng vốn lên gần 2.000 tỷ đồng sau đợt phát hành cổ phiếu thưởng
# Đang xử lý tin thứ 414: Doanh nhân Việt và hành trình kiến tạo nền giáo dục
# Đang xử lý tin thứ 415: Shark Thủy chi gần 32 tỷ đồng hối lộ để tạo doanh thu ảo
# Đang xử lý tin thứ 416: Lịch sự kiện và tin vắn chứng khoán ngày 20/11/2025
# Đang xử lý tin thứ 417: Lợi nhuận 9 tháng vượt gấp đôi kế hoạch, một doanh nghiệp đá được dự báo tiếp tục hưởng lợi lớn từ "cú hích" đầu tư công
# Đang xử lý tin thứ 418: Cổ phiếu tăng nóng bị bán mạnh
# Đang xử lý tin thứ 419: CTCK chỉ ra 4 doanh nghiệp ngành vật liệu xây dựng có thị phần nội địa lớn, kỳ vọng hưởng lợi nhờ giá đầu vào hạ nhiệt
# Đang xử lý tin thứ 420: Thị trường tiền số hôm nay, 19-11: Nhà đầu tư đang thấp thỏm
# Đang xử lý tin thứ 421: Sự trở lại của HAGL và dấu ấn “kiến trúc sư” OCBS trong bức tranh chiến lược mới
# Đang xử lý tin thứ 422: Tự doanh CTCK giảm đà bán ròng trong phiên 19/11, ngược chiều gom mạnh một cổ phiếu xây dựng
# Đang xử lý tin thứ 423: VNECO bị nhắc nhở do chậm công bố thông tin
# Đang xử lý tin thứ 424: Chứng khoán giảm mạnh do áp lực chốt lời
# Đang xử lý tin thứ 425: KIS Việt Nam chốt phương án chào bán cổ phiếu để tăng vốn vượt 4.500 tỷ đồng
# Đang xử lý tin thứ 426: Phiên 19/11: Khối ngoại tiếp tục bán ròng hơn 700 tỷ đồng, loạt cổ phiếu bluechips bị "xả" mạnh
# Đang xử lý tin thứ 427: Chứng khoán VPS có Tổng Giám đốc mới thay thế ông Nguyễn Lâm Dũng
# Đang xử lý tin thứ 428: Lãi kỷ lục trong quý 3, một doanh nghiệp trên HOSE muốn nâng kế hoạch kinh doanh, sắp trả cổ tức tiền mặt 80%
# Đang xử lý tin thứ 429: Một thành viên HĐQT Chứng khoán EVS xin từ nhiệm
# Đang xử lý tin thứ 430: Masan Consumer muốn phát hành gần 238 triệu cổ phiếu
# Đang xử lý tin thứ 431: VietinBank bán đấu giá 19,6 triệu cổ phiếu SGP, dự kiến thu tối thiểu gần 573 tỷ đồng
# Đang xử lý tin thứ 432: Chủ tịch Nam Long chuyển nhượng hơn 15 triệu quyền mua cổ phiếu NLG cho 2 con trai
# Đang xử lý tin thứ 433: Chứng khoán MB rầm rộ ưu đãi cuối năm, nhà đầu tư được gì?
# Đang xử lý tin thứ 434: Lịch sự kiện và tin vắn chứng khoán ngày 19/11/2025
# Đang xử lý tin thứ 435: Lần đầu tiên TTCK Việt Nam có bộ chỉ số gồm các cổ phiếu tăng cường lợi ích cổ đông
# Đang xử lý tin thứ 436: Một doanh nghiệp đầu ngành được dự báo lợi nhuận 2026 lập đỉnh mới, cổ tức có thể đạt 17.000 đồng/cp
# Đang xử lý tin thứ 437: CTCK gọi tên 5 cổ phiếu bất động sản có triển vọng tốt, quỹ đất lớn và định giá phù hợp để "xuống tiền"
# Đang xử lý tin thứ 438: Một cổ phiếu trên sàn HoSE "tím lịm", thị giá tăng bằng lần chỉ sau nửa năm
# Đang xử lý tin thứ 439: Tập đoàn Novaland khất nợ
# Đang xử lý tin thứ 440: Tổng Giám đốc Dragon Capital: Tiêu dùng chưa đi lên thì lấy gì để lạm phát
# Đang xử lý tin thứ 441: MBAMC thông báo mời quan tâm – Cổ phần tại CTCP Tân Cảng – Cái Mép
# Đang xử lý tin thứ 442: Chứng khoán tăng 3 phiên liên tiếp, dòng tiền vẫn thận trọng
# Đang xử lý tin thứ 443: Tự doanh CTCK quay đầu "xả" hàng trăm tỷ đồng cổ phiếu Việt Nam trong phiên 18/11, mã nào là tâm điểm?
# Đang xử lý tin thứ 444: VietinBank Securities muốn đổi tên và nhận diện thương hiệu
# Đang xử lý tin thứ 445: Chứng khoán Việt Nam ngày 18-11 ngược dòng thế giới, cổ phiếu Vingroup tiếp tục tăng
# Đang xử lý tin thứ 446: Phiên 18/11: Khối ngoại giảm đà bán ròng, ngược chiều "tung" gần 400 tỷ gom một cổ phiếu Bluechips
# Đang xử lý tin thứ 447: Trạm sạc ô tô điện VinFast xuất hiện ngày càng nhiều ở trung tâm TP HCM
# Đang xử lý tin thứ 448: Tâm lý 'cực kỳ sợ hãi' bao trùm khiến giá Bitcoin xuống dưới 90.000 USD, 'mùa đông tiền số' đang tới gần?
# Đang xử lý tin thứ 449: Trưa 18-11, nỗi sợ của giới đầu tư Bitcoin đã thành hiện thực
# Đang xử lý tin thứ 450: Một thế lực âm thầm “xả” gần 1,7 tỷ USD Bitcoin ngay trước thời điểm Bitcoin thủng mốc 90.000 USD
# Đang xử lý tin thứ 451: Chiến lược "90% giá trị" của tỷ phú Phạm Nhật Vượng tại thị trường 460 tỷ USD
# Đang xử lý tin thứ 452: Doanh nghiệp sắp “lăn chốt” cổ tức 2.000 đồng/cp, cổ phiếu lập tức bật tăng mạnh
# Đang xử lý tin thứ 453: Xanh SM tăng vốn lên 25.000 tỷ đồng
# Đang xử lý tin thứ 454: Chứng sĩ tranh tài “Chứng trường bạc tỷ” giữa lúc VN-Index vượt 1.650 điểm
# Đang xử lý tin thứ 455: Xếp dỡ Hải An muốn tăng kế hoạch lợi nhuận năm lên 1.140 tỷ đồng
# Đang xử lý tin thứ 456: Một doanh nghiệp thép tiếp tục “thay máu” loạt lãnh đạo cấp cao sau khi có Chủ tịch HĐQT mới
# Đang xử lý tin thứ 457: Vụ án xảy ra tại Egroup: Đề nghị truy tố shark Thủy và 28 bị can
# Đang xử lý tin thứ 458: 3 cổ đông lớn nắm hơn 52% vốn Chứng khoán Thiên Việt sau đợt chào bán cổ phiếu
# Đang xử lý tin thứ 459: Lịch sự kiện và tin vắn chứng khoán ngày 18/11/2025
# Đang xử lý tin thứ 460: Chỉ báo kỹ thuật đọc vị dòng tiền giúp nhà đầu tư phát hiện cổ phiếu được gom hay xả
# Đang xử lý tin thứ 461: CTCK dự báo kế hoạch giải ngân của quỹ Vanguard sau khi thị trường Việt Nam nâng hạng
# Đang xử lý tin thứ 462: Hơn 15 triệu cổ phiếu phòng thủ bất ngờ nhận tin vui
# Đang xử lý tin thứ 463: Lọc hóa dầu Bình Sơn bị cảnh cáo vì chậm nộp hồ sơ khai thuế
# Đang xử lý tin thứ 464: Thị trường tiền số hôm nay, 17-11: Nhà đầu tư hoảng loạn
# Đang xử lý tin thứ 465: Một cổ phiếu ngân hàng bất ngờ được tự doanh CTCK gom mạnh trong phiên đầu tuần 17/11
# Đang xử lý tin thứ 466: Novaland tiếp tục ‘khất nợ’ trái phiếu
# Đang xử lý tin thứ 467: Cổ phiếu Novaland, Hoàng Anh Gia Lai gây chú ý
# Đang xử lý tin thứ 468: Chứng khoán ngày 18-11: Cơ hội chuyển vốn sang cổ phiếu thu hút dòng tiền
# Đang xử lý tin thứ 469: "Shark Thủy" bị đề nghị truy tố cùng 28 bị can khác
# Đang xử lý tin thứ 470: Phát Đạt nhận chuyển nhượng dự án ngàn tỉ tại trung tâm TP HCM
# Đang xử lý tin thứ 471: Khối ngoại tiếp đà bán ròng gần 1.000 tỷ đồng trong phiên VN-Index bứt phá, "xả" mạnh một cổ phiếu ngân hàng
# Đang xử lý tin thứ 472: Một thế lực đang âm thầm "gom hàng" loạt nhóm cổ phiếu ở vùng giá thấp
# Đang xử lý tin thứ 473: TNG tăng vốn điều lệ lên hơn 1.300 tỷ đồng
# Đang xử lý tin thứ 474: VN-Index hồi phục nhưng thận trọng, ưu tiên quản trị danh mục thay vì bắt đáy
# Đang xử lý tin thứ 475: SHS – 18 năm kiến tạo hành trình dịch vụ và niềm tin
# Đang xử lý tin thứ 476: Một doanh nghiệp sắp "lăn chốt" cổ tức, tổng tỷ lệ 35%, soi lịch sử chia cổ tức tiền mặt "đều như vắt tranh"
# Đang xử lý tin thứ 477: 2.500 lao động ở quê tỷ phú Phạm Nhật Vượng có thể nhận lương đến 18 triệu/tháng khi làm việc cho VinFast
# Đang xử lý tin thứ 478: Danh tính cổ đông ngoại sở hữu 5% vốn điều lệ VinEnergo
# Đang xử lý tin thứ 479: Agimexpharm dự kiến phát hành gần 4 triệu cổ phiếu AGP
# Đang xử lý tin thứ 480: Diễn biến mới nhất vụ lừa đảo do Mr Pips Phó Đức Nam và Mr Hunter Lê Khắc Ngọ cầm đầu
# Đang xử lý tin thứ 481: Đại gia Thái Lan bội thu cổ tức từ doanh nghiệp Việt
# Đang xử lý tin thứ 482: Chứng khoán DSC bị HoSE nhắc nhở do chậm công bố thông tin
# Đang xử lý tin thứ 483: Lịch sự kiện và tin vắn chứng khoán ngày 17/11/2025
# Đang xử lý tin thứ 484: VN-Index bất ngờ đảo chiều hồi phục với thanh khoản thấp: Đáy quanh đây hay chỉ là nhịp "bull trap"?
# Đang xử lý tin thứ 485: FiinGroup hé lộ nhóm cổ phiếu định giá thấp hơn trung bình 5 năm
# Đang xử lý tin thứ 486: Chuyên gia: Đây là thời điểm chuẩn bị đón "sóng" năm 2026, 3 nhóm cổ phiếu sẽ hút tiền mạnh
# Đang xử lý tin thứ 487: Chứng khoán tuần tới có 'đón gió đổi chiều'?
# Đang xử lý tin thứ 488: Ngắt mạch giảm sâu, chứng khoán liệu có phiên bùng nổ tuần tới?
# Đang xử lý tin thứ 489: Góc nhìn chuyên gia: Chưa có tín hiệu đảo chiều, VN-Index cần thêm phiên bùng nổ theo đà để xác nhận nhịp tăng mới
# Đang xử lý tin thứ 490: Lộ diện đường dây lừa tiền ảo: Đa cấp 16 tầng, cuỗm sạch hàng chục tỷ đồng của nhà đầu tư
# Đang xử lý tin thứ 491: Chứng khoán VPS tiếp tục phân phối cổ phiếu còn lại trong đợt IPO
# Đang xử lý tin thứ 492: Châu Á trong “cơn khát vàng”: Một loạt quỹ lớn gấp đôi lượng nắm giữ từ đầu năm
# ...
# Đang xử lý tin thứ 751: Xử phạt loạt doanh nghiệp vi phạm trong lĩnh vực chứng khoán
# Đang xử lý tin thứ 752: Doanh nghiệp bất động sản 'hái ra tiền'
# Đang xử lý tin thứ 753: Bật mí thời điểm "vàng" để giải ngân mua cổ phiếu an toàn và hiệu quả
# Đang xử lý tin thứ 754: Hàng loạt công ty phải giải trình sau kết quả kinh doanh quý III/2025
# Đang xử lý tin thứ 755: Chứng khoán VIX lên tiếng về tin đồn thất thiệt lan truyền trên mạng xã hội
# Đang xử lý tin thứ 756: Một cổ phiếu ngân hàng bị khối ngoại bán ròng đột biến trong tuần cuối tháng 10
# Đang xử lý tin thứ 757: Thị trường tiền số hôm nay, 31-10: Chuyện lạ xảy ra với Bitcoin
# Đang xử lý tin thứ 758: Bắt Phó Tổng Giám đốc Công ty Dầu khí Nam Sông Hậu
# Đang xử lý tin thứ 759: Một thế lực bất ngờ tung hơn 1.100 tỷ "gom" cổ phiếu Việt Nam trong phiên cuối tuần 31/10
# Đang xử lý tin thứ 760: Bắt tạm giam Ngọ Quang Sơn
# Đang xử lý tin thứ 761: Vietjet và Rolls-Royce ký kết hợp đồng 3,8 tỉ USD trong chuyến thăm Vương quốc Anh của Tổng bí thư
# Đang xử lý tin thứ 762: Động thái chính sách mới nhất của Bộ Tài chính sau khi FTSE Russell nâng hạng thị trường chứng khoán Việt Nam
# Đang xử lý tin thứ 763: Phiên 31/10: Khối ngoại tiếp đà bán ròng hơn nửa nghìn tỷ, ngược chiều "gom" mạnh một mã chứng khoán
# Đang xử lý tin thứ 764: Nhà đầu tư chờ phút chót để xuống tiền: Cuộc đua giành suất IPO VPS tiếp tục nóng
# Đang xử lý tin thứ 765: AgriS khởi động niên độ 2025-2026 với định hướng tăng tốc đổi mới và mở rộng toàn cầu
# Đang xử lý tin thứ 766: FLC giải trình phương án khắc phục cổ phiếu bị hạn chế giao dịch
# Đang xử lý tin thứ 767: Tài sản Vingroup chính thức vượt 1 triệu tỷ đồng
# Đang xử lý tin thứ 768: Vietjet tăng trưởng mạnh trong Quý III/2025 – chia cổ tức 20% bằng cổ phiếu
# Đang xử lý tin thứ 769: Công ty chứng khoán Hòa Bình bị kiểm soát đặc biệt
# Đang xử lý tin thứ 770: Doanh nghiệp của tỷ phú Phạm Nhật Vượng đang làm ăn ra sao?
# Đang xử lý tin thứ 771: Tổng Bí thư chứng kiến trao hơn 20 thỏa thuận hợp tác Việt Nam - Anh trị giá hàng chục tỉ USD
# Đang xử lý tin thứ 772: Một tập đoàn tư nhân của Việt Nam có tài sản vượt 1 triệu tỉ đồng
# Đang xử lý tin thứ 773: Tổng Giám đốc Dragon Capital: 2-3 năm gần đây nhà đầu tư không còn xem chứng khoán như “sòng bạc”, lái xe của tôi cũng bỏ vài trăm USD mỗi tháng mua cổ phiếu
# Đang xử lý tin thứ 774: Thêm nhiều công ty chứng khoán triệu tập ĐHĐCĐ bất thường
# Đang xử lý tin thứ 775: Ông Tô Hải xin từ nhiệm, Chứng khoán Vietcap có Tổng Giám đốc mới
# Đang xử lý tin thứ 776: Loạt chỉ số chứng khoán quan trọng: VN-Index, HNX-Index và UPCoM có ý nghĩa gì?
# Đang xử lý tin thứ 777: Lịch sự kiện và tin vắn chứng khoán ngày 31/10/2025
# Đang xử lý tin thứ 778: Vietjet đặt mua 100 tàu bay Airbus A321neo
# Đang xử lý tin thứ 779: Thị trường tiền số hôm nay, 30-10: Chuyện gì sẽ xảy ra với Bitcoin khi giá vàng lao dốc?
# Đang xử lý tin thứ 780: Chứng khoán ngày 31-10: Biến động khó lường?
# Đang xử lý tin thứ 781: Một mã Bluechips được tự doanh CTCK "gom" đột biến hơn trăm tỷ trong phiên 30/10
# Đang xử lý tin thứ 782: Hà Tĩnh thúc đẩy tiến độ triển khai các dự án của Vingroup
# Đang xử lý tin thứ 783: Chứng khoán UP chào bán hơn 32 triệu cổ phiếu để tăng gấp đôi vốn điều lệ
# Đang xử lý tin thứ 784: Á hậu Phương Nhi trở thành cổ đông tại DN quản lý mô hình đô thị hưu trí đầu tiên ở Việt Nam
# Đang xử lý tin thứ 785: Phiên 30/10: Khối ngoại thẳng tay bán hơn 1.200 tỷ đồng, cổ phiếu nào bị “xả” mạnh nhất?
# Đang xử lý tin thứ 786: Chuyên gia: Vingroup đang ghi dấu mốc lịch sử tại “mảnh đất vàng” Congo
# Đang xử lý tin thứ 787: Nâng hạng thị trường chứng khoán là cơ hội lớn để Việt Nam khẳng định vị thế trên bản đồ tài chính thế giới
# Đang xử lý tin thứ 788: Tổng Giám đốc Nguyễn Ngọc Linh: "Tuổi 18, DNSE tràn đầy sức trẻ, dám làm và dám dấn thân”
# Đang xử lý tin thứ 789: DIC Corp báo lãi ròng quý III/2025 tăng mạnh nhờ chuyển nhượng dự án Lam Hạ Center Point
# Đang xử lý tin thứ 790: Tổng Giám đốc một công ty chứng khoán bất ngờ xin thôi việc
# Đang xử lý tin thứ 791: IPO tại Việt Nam: Từ hành trình chiến lược đến niêm yết hiệu quả
# Đang xử lý tin thứ 792: VietinBank Securities muốn đổi tên thành Chứng khoán VietinBank
# Đang xử lý tin thứ 793: Quỹ ngoại Phần Lan gom thêm cổ phiếu HDG của Tập đoàn Hà Đô
# Đang xử lý tin thứ 794: CRC phát triển trung tâm dữ liệu AI với đối tác Mỹ và tập đoàn GDH
# Đang xử lý tin thứ 795: VinSpeed đề xuất kéo dài tuyến metro Cần Giờ kết nối thẳng ga Bến Thành
# Đang xử lý tin thứ 796: Tài sản mã hóa: Cuộc chơi tỷ USD trước 'giờ G'
# Đang xử lý tin thứ 797: Một công ty chứng khoán bất ngờ bị kiểm soát đặc biệt, dừng hoạt động cho vay margin
# Đang xử lý tin thứ 798: 10 triệu đồng: Gửi tiết kiệm, mua vàng hay sắm ô tô?
# Đang xử lý tin thứ 799: Becamex IJC báo lãi cao nhất 18 quý, doanh nghiệp tăng tốc hậu tăng vốn
# Đang xử lý tin thứ 800: Lịch sự kiện và tin vắn chứng khoán ngày 30/10/2025
# Đang xử lý tin thứ 801: Chứng khoán ngày 30-10: Tiền có thể dồn vào cổ phiếu có thông tin tốt
# Đang xử lý tin thứ 802: Định giá cổ phiếu các công ty chứng khoán ra sao giữa làn sóng IPO?
# Đang xử lý tin thứ 803: CTCK điểm tên 5 cổ phiếu bất động sản nền tảng tốt, tiềm năng hưởng lợi từ đầu tư công và định giá hấp dẫn để "xuống tiền"
# Đang xử lý tin thứ 804: Điều gì đang xảy ra với cổ phiếu Hoàng Anh Gia Lai của Bầu Đức?
# Đang xử lý tin thứ 805: Nvidia trở thành công ty 5.000 tỷ USD đầu tiên trên thế giới
# Đang xử lý tin thứ 806: Vietjet và Đại học Oxford công bố kết quả nghiên cứu giải pháp Net Zero cho hàng không toàn cầu
# Đang xử lý tin thứ 807: Doanh nghiệp báo lãi, vì sao nhà đầu tư chứng khoán rụt rè?
# Đang xử lý tin thứ 808: Tự doanh CTCK "xả" hàng trăm tỷ đồng cổ phiếu Việt Nam trong phiên 29/10, cổ phiếu nào là tâm điểm bán ròng?
# Đang xử lý tin thứ 809: IPO VPBankS: Tiếp nối thành công từ chuỗi thương vụ tỷ USD của VPBank
# Đang xử lý tin thứ 810: Doanh nghiệp gửi 'núi tiền' ở ngân hàng bất chấp lãi suất thấp
# Đang xử lý tin thứ 811: Phó Thủ tướng có loạt chỉ đạo quan trọng liên quan đến các dự án đường sắt mà VinSpeed, Thaco, Hòa Phát đang quan tâm
# Đang xử lý tin thứ 812: Phiên 29/10: Khối ngoại mạnh tay bán ròng gần 1.600 tỷ, “xả” đột biến tại một mã ngân hàng
# Đang xử lý tin thứ 813: Thế lực nghìn tỷ “chống lưng” cho Tiên Nguyễn
# Đang xử lý tin thứ 814: Khách đến TTTM tăng mạnh, Vincom Retail lãi gần 3.800 tỷ đồng sau 9 tháng
# Đang xử lý tin thứ 815: Doanh nghiệp của tỷ phú Phạm Nhật Vượng vừa lập kỷ lục top 1 Đông Nam Á
# Đang xử lý tin thứ 816: Một công ty chứng khoán bất ngờ dừng phương án chào bán 365 triệu cổ phiếu
# Đang xử lý tin thứ 817: SCIC đăng ký chuyển nhượng hơn 370 triệu cổ phiếu FPT Telecom về Bộ Công an
# Đang xử lý tin thứ 818: LPBS triệu tập ĐHĐCĐ bất thường lần thứ 4 bầu thành viên HĐQT
# Đang xử lý tin thứ 819: 'Chân dung' doanh nghiệp kín tiếng vừa huy động thành công gần 3.000 tỷ đồng
# Đang xử lý tin thứ 820: Thấy gì từ Báo cáo tài chính quý III/2025 của Novaland?
# Đang xử lý tin thứ 821: Lịch sự kiện và tin vắn chứng khoán ngày 29/10/2025
# Đang xử lý tin thứ 822: 2.000 tỷ đồng lãi gộp mảng môi giới chứng khoán quý 3: Biên lợi nhuận bật lên mức cao nhất 4 năm
# Đang xử lý tin thứ 823: VN-Index bất ngờ "rút chân" ngoạn mục gần 60 điểm, điều gì đang diễn ra?
# Đang xử lý tin thứ 824: Thị trường tiền số hôm nay, 28-10: Bất ngờ về công ty lập sàn tài sản số 10.000 tỉ đồng
# Đang xử lý tin thứ 825: Chứng khoán ngày 29-10: Chờ nhịp tăng điểm để sở hữu cổ phiếu
# Đang xử lý tin thứ 826: Chứng khoán kịch tính như... tàu lượn
# Đang xử lý tin thứ 827: Cổ phiếu ngân hàng dẫn dắt đà hồi phục, VN-Index tăng “bốc đầu” gần 60 điểm từ đáy
# Đang xử lý tin thứ 828: Một mã Bluechips bất ngờ bị tự doanh CTCK "xả" đột biến nửa nghìn tỷ trong phiên 28/10
# Đang xử lý tin thứ 829: Phiên 28/10: Khối ngoại đảo chiều mua ròng, "tung" gần 1.300 tỷ đồng gom một cổ phiếu Bluechip
# Đang xử lý tin thứ 830: Hãng hàng không của tỷ phú Nguyễn Thị Phương Thảo vừa làm điều chưa từng có trong lịch sử
# Đang xử lý tin thứ 831: Chứng khoán DNSE hoàn tất chào bán 1.000 tỷ đồng trái phiếu ra công chúng
# Đang xử lý tin thứ 832: Tập đoàn Điện Quang khắc phục tình trạng cổ phiếu bị cảnh báo và kiểm soát
# Đang xử lý tin thứ 833: Doanh thu 9 tháng của Novaland (NVL) đạt gần 5.400 tỷ, lỗ luỹ kế giảm hơn một nửa so với cùng kỳ
# Đang xử lý tin thứ 834: Giám đốc phân tích BSC lý giải nguyên nhân dòng vốn ngoại "miệt mài" rút khỏi thị trường chứng khoán Việt Nam
# Đang xử lý tin thứ 835: Chuyên gia SHS: Thị trường chứng khoán đang trong giai đoạn tích lũy "lành mạnh" sau chu kỳ tăng dài
# Đang xử lý tin thứ 836: Tập đoàn hàng đầu Nhật Bản bị loại khỏi Nikkei 225 vì bê bối kế toán nghiêm trọng, cổ phiếu rơi tự do 20%/ngày
# Đang xử lý tin thứ 837: Giải mã sức hút “Chứng Trường Bạc Tỷ” mùa 2: Gần 1.000 nhà đầu tư đăng ký chỉ sau một đêm
# Đang xử lý tin thứ 838: Vì sao An Thịnh bị xử phạt?
# Đang xử lý tin thứ 839: Fundmart “đón đầu” làn sóng 5 triệu người Việt Nam đầu tư chứng chỉ quỹ
# Đang xử lý tin thứ 840: Lịch sự kiện và tin vắn chứng khoán ngày 28/10/2025
# Đang xử lý tin thứ 841: Pyn Elite Fund: Điều chỉnh chỉ là tạm thời, xu hướng chính trên thị trường chứng khoán là tăng
# Đang xử lý tin thứ 842: Doanh nghiệp muốn lập sàn giao dịch tài sản số báo lãi quý 3 "mỏng như tờ", đem hơn chục tỷ đầu tư chứng khoán đang tạm lỗ
# Đang xử lý tin thứ 843: Một công ty chứng khoán muốn tăng kế hoạch lãi năm 2025 lên gấp 4 lần, dự kiến nâng vốn vượt 24.000 tỷ đồng
# Đang xử lý tin thứ 844: Chuyên gia bất ngờ với nhịp giảm sâu của VN-Index, khuyến nghị nhà đầu tư nên ưu tiên phòng thủ
# Đang xử lý tin thứ 845: Vợ Giám đốc chi nhánh Chứng khoán TCBS muốn bán toàn bộ cổ phiếu TCX
# Đang xử lý tin thứ 846: Các CTCK thu kỷ lục từ lãi cho vay, TCBS và SSI "bỏ túi" nghìn tỷ
# Đang xử lý tin thứ 847: Thị trường tiền số hôm nay, 27-10: Điều gì xảy ra nếu Bitcoin mất mốc 109.000 USD?
# Đang xử lý tin thứ 848: Không có thông tin việc chấp hành án phạt tù của ông Trịnh Văn Quyết
# Đang xử lý tin thứ 849: Chứng khoán ngày 28-10: Áp lực bán tiếp tục chiếm ưu thế?
# Đang xử lý tin thứ 850: Tự doanh CTCK quay đầu bán ròng gần 700 tỷ trong phiên đầu tuần, "xả" mạnh một mã Bluechips
# Đang xử lý tin thứ 851: Những lần cầm mic gây bão của các sếp lớn: Chủ tịch KienlongBank "đu dây" biểu diễn, Chủ tịch ACB, CEO 8X MB hát loạt hit của Tăng Duy Tân, Hồ Ngọc Hà
# Đang xử lý tin thứ 852: Điều gì khiến VN-Index bất ngờ bị "đánh úp" giảm 30 điểm vào cuối phiên?
# Đang xử lý tin thứ 853: Đại gia bán lẻ Masan mở thêm gần 500 cửa hàng WinMart+
# Đang xử lý tin thứ 854: Cổ phiếu bất động sản gây thất vọng
# Đang xử lý tin thứ 855: Khối ngoại tiếp đà bán ròng 1.200 tỷ trong phiên VN-Index giảm sâu, tâm điểm xả mạnh bộ đôi cổ phiếu "bank, chứng"
# Đang xử lý tin thứ 856: Điểm đặc biệt của quốc gia mà Vingroup sắp sang làm đại dự án: Chiếm 74% sản lượng khai thác toàn cầu của 1 kim loại cực kỳ quan trọng với xe điện
# Đang xử lý tin thứ 857: Cổ đông Vietjet sắp nhận cổ tức 20% bằng cổ phiếu
# Đang xử lý tin thứ 858: Thành Nam Group giải trình về việc cổ phiếu TNI tăng trần 5 phiên liên tiếp
# Đang xử lý tin thứ 859: Thành viên HĐQT và cổ đông lớn không muốn tham gia đợt chào bán cổ phiếu của DSC
# Đang xử lý tin thứ 860: Hơn 66 triệu cổ phiếu PDV của PVT Logistics được chấp thuận niêm yết trên HoSE
# Đang xử lý tin thứ 861: Chuyện gì đây: Một cổ phiếu trên HOSE tăng dựng đứng, kịch trần 8 phiên liên tiếp
# Đang xử lý tin thứ 862: Cổ phiếu FPT và một mã ngân hàng có thể được loạt cá mập tổng quy mô 14.000 tỷ "săn lùng" trong kỳ cơ cấu quý 4
# Đang xử lý tin thứ 863: Doanh nghiệp bất động sản lãi đậm nhờ đầu tư chứng khoán
# Đang xử lý tin thứ 864: “Chứng Trường Bạc Tỷ” mùa 2 – Đấu trường đầu tư đỉnh cao với tổng giải thưởng 500 triệu đồng
# Đang xử lý tin thứ 865: FChoice 2025 chính thức khởi động: Định hình những điểm nhấn đầu tiên của Việt Nam trong Kỷ nguyên vươn mình
# Đang xử lý tin thứ 866: Lịch sự kiện và tin vắn chứng khoán ngày 27/10/2025
# Đang xử lý tin thứ 867: Có tin báo cáo tài chính doanh nghiệp, chứng khoán sẽ 'thoát hiểm'?
# Đang xử lý tin thứ 868: Bất ngờ top 10 công ty chứng khoán có doanh thu môi giới lớn nhất quý 3/2025
# Đang xử lý tin thứ 869: TCBS, VPBankS, VPS IPO kích hoạt làn sóng tái định giá nhóm chứng khoán, VNDirect chỉ tên những mã hưởng lợi nhất
# Đang xử lý tin thứ 870: Chứng khoán tuần tới: Nhà đầu tư lưu ý điều này sau tuần "sóng gió" của VN-Index
# Đang xử lý tin thứ 871: Hóa chất Đức Giang ‘ôm’ hơn 12.700 tỷ đồng tiền gửi ngân hàng, quý III/2025 lãi ròng 804 tỷ đồng
# Đang xử lý tin thứ 872: Petrovietnam bán đấu giá cổ phần tại GID và PVTS
# Đang xử lý tin thứ 873: Chuyên gia SSID: Định danh phi tập trung, lá chắn bảo mật cho kỷ nguyên tài chính số
# Đang xử lý tin thứ 874: Hàng loạt công ty điện báo lãi lớn
# Đang xử lý tin thứ 875: Góc nhìn chuyên gia: Chứng khoán có thể rung lắc trước khi vào sóng mới, tận dụng cơ hội "săn" nhóm cổ phiếu có triển vọng tích cực trong quý 4
# Đang xử lý tin thứ 876: Tập đoàn Geleximco trúng đấu giá hơn 38,5 triệu cổ phần của Viettronics
# Đang xử lý tin thứ 877: Phó Tổng giám đốc SSID: “Thị trường tài sản mã hóa rất tiềm năng, là cơ hội hiếm có cho Việt Nam”
# Đang xử lý tin thứ 878: Thị trường chứng khoán Việt Nam có phù hợp để đầu tư dài hạn?
# Đang xử lý tin thứ 879: Chứng khoán Phố Wall muốn cắt lỗ cổ phiếu HAF
# Đang xử lý tin thứ 880: Thép Vicasa - VNSteel đón cổ đông lớn mới
# Đang xử lý tin thứ 881: Lịch chốt quyền cổ tức 27/10– 31/10: Một ngân hàng sắp "lăn chốt", cổ tức cao nhất 61,5%
# Đang xử lý tin thứ 882: VNDirect: Làn sóng IPO chuẩn bị bùng nổ với loạt "bom tấn" Highlands, Golden Gate, Điện máy xanh, Long Châu
# Đang xử lý tin thứ 883: Thị trường tiền số hôm nay, 25-10: Công ước Hà Nội đặt dấu chấm hết cho lừa đảo tài sản số
# Đang xử lý tin thứ 884: Vingroup được Congo giao 6.300 ha đất ven sông để triển khai dự án đô thị xanh
# Đang xử lý tin thứ 885: Cổ đông Vietjet sắp nhận cổ tức 20% bằng cổ phiếu
# Đang xử lý tin thứ 886: Cổ phiếu doanh nghiệp bất động sản bán mạnh
# Đang xử lý tin thứ 887: FPT của ông Trương Gia Bình mỗi ngày thu 4,5 tỉ đồng tiền lãi ngân hàng
# Đang xử lý tin thứ 888: FLC triệu tập đại hội bất thường sau khi tiếp quản Bamboo Airways
# Đang xử lý tin thứ 889: Thế Giới Di Động như một 'ngân hàng ngầm'
# Đang xử lý tin thứ 890: Bitagco báo lỗ sau 9 tháng đầu năm 2025
# Đang xử lý tin thứ 891: Doanh nghiệp lớn nhất Việt Nam muốn bán hết cổ phần tại 2 công ty, thu về gần 200 tỷ đồng để 'tập trung cho hoạt động cốt lõi'
# Đang xử lý tin thứ 892: Khối ngoại thẳng tay bán ròng 4.700 tỷ trong tuần 20-24/10, ngược chiều tung hơn nghìn tỷ "gom" một cổ phiếu Bluechip
# Đang xử lý tin thứ 893: Điều gì khiến chứng quyền thu hút nhà đầu tư?
# Đang xử lý tin thứ 894: Một doanh nghiệp "chơi lớn" trả cổ tức 25.000 đồng/cp ngay trong tháng 11
# Đang xử lý tin thứ 895: Dragon Capital đưa ra 3 khuyến nghị quan trọng cho nhà đầu tư giữa sóng gió thị trường
# Đang xử lý tin thứ 896: Damsan báo lãi 78 tỷ đồng sau 9 tháng, tự tin hoàn thành kế hoạch năm
# Đang xử lý tin thứ 897: Một thế lực bất ngờ tung hơn 900 tỷ "gom" cổ phiếu Việt Nam trong phiên cuối tuần
# Đang xử lý tin thứ 898: Lý do tài khoản nhiều người chơi chứng khoán 'đỏ rực'
# Đang xử lý tin thứ 899: Cổ phiếu “họ” Viettel rực sáng trong phiên cuối tuần, VN-Index rơi gần 4 điểm
# Đang xử lý tin thứ 900: FLC sắp họp bất thường vào ngày 11/11 tới đây
# Đang xử lý tin thứ 901: Khối ngoại tiếp đà bán mạnh trong phiên cuối tuần, một mã chứng khoán bị "xả" gần 800 tỷ đồng
# Đang xử lý tin thứ 902: Khoảng 6.800 tỷ đồng trái phiếu bất động sản đáo hạn trong tháng 10, tập trung ở Vinhomes, Phú Mỹ Hưng, Cen Land
# Đang xử lý tin thứ 903: Chứng khoán Việt Nam sau nâng hạng: Cơ hội mới, thách thức mới
# Đang xử lý tin thứ 904: Chứng khoán HD đón cổ đông lớn mới
# Đang xử lý tin thứ 905: “Đại gia” dầu khí hưởng lợi từ siêu dự án 12 tỷ USD: Vượt kế hoạch năm sau 9 tháng, nắm kho tiền mặt 1,6 vạn tỷ đồng
# Đang xử lý tin thứ 906: Loạt cổ phiếu ngân hàng có thể bị các cá mập tổng quy mô 24.000 tỷ bán mạnh ngay trong tháng 10
# Đang xử lý tin thứ 907: Novaland tiếp tục chậm thanh toán gần 113 tỷ đồng gốc trái phiếu
# Đang xử lý tin thứ 908: Sá xị Chương Dương đứng trước nguy cơ phá sản
# Đã lưu file danh_sach_bai_bao.json thành công!

# %%
df = pd.read_json('data/danh_sach_bai_bao.json')
data = get_detail_news_data(df)
df_data = pd.DataFrame(data)
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
df_data.to_json(
    f'data/newspaper_data/chi_tiet_bai_bao_{current_time}.json',
    orient='records',
    force_ascii=False,
    indent=4
)
# Out:
# --- Đang xử lý bài báo thứ 1 ---
#     -> Đã lấy xong nội dung (2309 ký tự).
# --- Đang xử lý bài báo thứ 2 ---
#     -> Đã lấy xong nội dung (2230 ký tự).
# --- Đang xử lý bài báo thứ 3 ---
#     -> Đã lấy xong nội dung (2580 ký tự).
# --- Đang xử lý bài báo thứ 4 ---
#     -> Đã lấy xong nội dung (5859 ký tự).
# --- Đang xử lý bài báo thứ 5 ---
#     -> Đã lấy xong nội dung (1211 ký tự).
# --- Đang xử lý bài báo thứ 6 ---
#     -> Đã lấy xong nội dung (2386 ký tự).
# --- Đang xử lý bài báo thứ 7 ---
#     -> Đã lấy xong nội dung (3681 ký tự).
# --- Đang xử lý bài báo thứ 8 ---
#     -> Đã lấy xong nội dung (3038 ký tự).
# --- Đang xử lý bài báo thứ 9 ---
#     -> Đã lấy xong nội dung (2333 ký tự).
# --- Đang xử lý bài báo thứ 10 ---
#     -> Đã lấy xong nội dung (3775 ký tự).
# --- Đang xử lý bài báo thứ 11 ---
#     -> Đã lấy xong nội dung (4482 ký tự).
# --- Đang xử lý bài báo thứ 12 ---
#     -> Đã lấy xong nội dung (5116 ký tự).
# --- Đang xử lý bài báo thứ 13 ---
#     -> Đã lấy xong nội dung (2236 ký tự).
# --- Đang xử lý bài báo thứ 14 ---
#     -> Đã lấy xong nội dung (3062 ký tự).
# --- Đang xử lý bài báo thứ 15 ---
#     -> Đã lấy xong nội dung (1546 ký tự).
# --- Đang xử lý bài báo thứ 16 ---
#     -> Đã lấy xong nội dung (1575 ký tự).
# --- Đang xử lý bài báo thứ 17 ---
#     -> Đã lấy xong nội dung (1777 ký tự).
# --- Đang xử lý bài báo thứ 18 ---
#     -> Đã lấy xong nội dung (2148 ký tự).
# --- Đang xử lý bài báo thứ 19 ---
#     -> Đã lấy xong nội dung (1917 ký tự).
# --- Đang xử lý bài báo thứ 20 ---
#     -> Đã lấy xong nội dung (4526 ký tự).
# --- Đang xử lý bài báo thứ 21 ---
#     -> Đã lấy xong nội dung (3444 ký tự).
# --- Đang xử lý bài báo thứ 22 ---
#     -> Đã lấy xong nội dung (2235 ký tự).
# --- Đang xử lý bài báo thứ 23 ---
#     -> Đã lấy xong nội dung (1795 ký tự).
# --- Đang xử lý bài báo thứ 24 ---
#     -> Đã lấy xong nội dung (3978 ký tự).
# --- Đang xử lý bài báo thứ 25 ---
#     -> Đã lấy xong nội dung (982 ký tự).
# --- Đang xử lý bài báo thứ 26 ---
#     -> Đã lấy xong nội dung (4119 ký tự).
# --- Đang xử lý bài báo thứ 27 ---
#     -> Đã lấy xong nội dung (1499 ký tự).
# --- Đang xử lý bài báo thứ 28 ---
#     -> Đã lấy xong nội dung (2468 ký tự).
# --- Đang xử lý bài báo thứ 29 ---
#     -> Đã lấy xong nội dung (911 ký tự).
# --- Đang xử lý bài báo thứ 30 ---
#     -> Đã lấy xong nội dung (4180 ký tự).
# --- Đang xử lý bài báo thứ 31 ---
#     -> Đã lấy xong nội dung (6950 ký tự).
# --- Đang xử lý bài báo thứ 32 ---
#     -> Đã lấy xong nội dung (2040 ký tự).
# --- Đang xử lý bài báo thứ 33 ---
#     -> Đã lấy xong nội dung (3718 ký tự).
# --- Đang xử lý bài báo thứ 34 ---
#     -> Đã lấy xong nội dung (2037 ký tự).
# --- Đang xử lý bài báo thứ 35 ---
#     -> Đã lấy xong nội dung (2632 ký tự).
# --- Đang xử lý bài báo thứ 36 ---
#     -> Đã lấy xong nội dung (4818 ký tự).
# --- Đang xử lý bài báo thứ 37 ---
#     -> Đã lấy xong nội dung (4335 ký tự).
# --- Đang xử lý bài báo thứ 38 ---
#     -> Đã lấy xong nội dung (3175 ký tự).
# --- Đang xử lý bài báo thứ 39 ---
#     -> Đã lấy xong nội dung (1803 ký tự).
# --- Đang xử lý bài báo thứ 40 ---
#     -> Đã lấy xong nội dung (4208 ký tự).
# --- Đang xử lý bài báo thứ 41 ---
#     -> Đã lấy xong nội dung (4817 ký tự).
# --- Đang xử lý bài báo thứ 42 ---
#     -> Đã lấy xong nội dung (2804 ký tự).
# --- Đang xử lý bài báo thứ 43 ---
#     -> Đã lấy xong nội dung (1275 ký tự).
# --- Đang xử lý bài báo thứ 44 ---
#     -> Đã lấy xong nội dung (3270 ký tự).
# --- Đang xử lý bài báo thứ 45 ---
#     -> Đã lấy xong nội dung (5377 ký tự).
# --- Đang xử lý bài báo thứ 46 ---
#     -> Đã lấy xong nội dung (993 ký tự).
# --- Đang xử lý bài báo thứ 47 ---
#     -> Đã lấy xong nội dung (2136 ký tự).
# --- Đang xử lý bài báo thứ 48 ---
#     -> Đã lấy xong nội dung (5686 ký tự).
# --- Đang xử lý bài báo thứ 49 ---
#     -> Đã lấy xong nội dung (4126 ký tự).
# --- Đang xử lý bài báo thứ 50 ---
#     -> Đã lấy xong nội dung (4196 ký tự).
# --- Đang xử lý bài báo thứ 51 ---
#     -> Đã lấy xong nội dung (4736 ký tự).
# --- Đang xử lý bài báo thứ 52 ---
#     -> Đã lấy xong nội dung (2467 ký tự).
# --- Đang xử lý bài báo thứ 53 ---
#     -> Đã lấy xong nội dung (2123 ký tự).
# --- Đang xử lý bài báo thứ 54 ---
#     -> Đã lấy xong nội dung (4516 ký tự).
# --- Đang xử lý bài báo thứ 55 ---
#     -> Đã lấy xong nội dung (4492 ký tự).
# --- Đang xử lý bài báo thứ 56 ---
#     -> Đã lấy xong nội dung (2432 ký tự).
# --- Đang xử lý bài báo thứ 57 ---
#     -> Đã lấy xong nội dung (2620 ký tự).
# --- Đang xử lý bài báo thứ 58 ---
#     -> Đã lấy xong nội dung (3875 ký tự).
# --- Đang xử lý bài báo thứ 59 ---
#     -> Đã lấy xong nội dung (4930 ký tự).
# --- Đang xử lý bài báo thứ 60 ---
#     -> Đã lấy xong nội dung (4535 ký tự).
# --- Đang xử lý bài báo thứ 61 ---
#     -> Đã lấy xong nội dung (2496 ký tự).
# --- Đang xử lý bài báo thứ 62 ---
#     -> Đã lấy xong nội dung (5292 ký tự).
# --- Đang xử lý bài báo thứ 63 ---
#     -> Đã lấy xong nội dung (1298 ký tự).
# --- Đang xử lý bài báo thứ 64 ---
#     -> Đã lấy xong nội dung (2628 ký tự).
# --- Đang xử lý bài báo thứ 65 ---
#     -> Đã lấy xong nội dung (2467 ký tự).
# --- Đang xử lý bài báo thứ 66 ---
#     -> Đã lấy xong nội dung (952 ký tự).
# --- Đang xử lý bài báo thứ 67 ---
#     -> Đã lấy xong nội dung (2781 ký tự).
# --- Đang xử lý bài báo thứ 68 ---
#     -> Đã lấy xong nội dung (3741 ký tự).
# --- Đang xử lý bài báo thứ 69 ---
#     -> Đã lấy xong nội dung (1551 ký tự).
# --- Đang xử lý bài báo thứ 70 ---
#     -> Đã lấy xong nội dung (2551 ký tự).
# --- Đang xử lý bài báo thứ 71 ---
#     -> Đã lấy xong nội dung (5473 ký tự).
# --- Đang xử lý bài báo thứ 72 ---
#     -> Đã lấy xong nội dung (849 ký tự).
# --- Đang xử lý bài báo thứ 73 ---
#     -> Đã lấy xong nội dung (2242 ký tự).
# --- Đang xử lý bài báo thứ 74 ---
#     -> Đã lấy xong nội dung (12097 ký tự).
# --- Đang xử lý bài báo thứ 75 ---
#     -> Đã lấy xong nội dung (2528 ký tự).
# --- Đang xử lý bài báo thứ 76 ---
#     -> Đã lấy xong nội dung (3402 ký tự).
# --- Đang xử lý bài báo thứ 77 ---
#     -> Đã lấy xong nội dung (5064 ký tự).
# --- Đang xử lý bài báo thứ 78 ---
#     -> Đã lấy xong nội dung (4416 ký tự).
# --- Đang xử lý bài báo thứ 79 ---
#     -> Đã lấy xong nội dung (3439 ký tự).
# --- Đang xử lý bài báo thứ 80 ---
#     -> Đã lấy xong nội dung (7083 ký tự).
# --- Đang xử lý bài báo thứ 81 ---
#     -> Đã lấy xong nội dung (4871 ký tự).
# --- Đang xử lý bài báo thứ 82 ---
#     -> Đã lấy xong nội dung (6520 ký tự).
# --- Đang xử lý bài báo thứ 83 ---
#     -> Đã lấy xong nội dung (7505 ký tự).
# --- Đang xử lý bài báo thứ 84 ---
#     -> Đã lấy xong nội dung (2309 ký tự).
# --- Đang xử lý bài báo thứ 85 ---
#     -> Đã lấy xong nội dung (2828 ký tự).
# --- Đang xử lý bài báo thứ 86 ---
#     -> Đã lấy xong nội dung (4377 ký tự).
# --- Đang xử lý bài báo thứ 87 ---
#     -> Đã lấy xong nội dung (3298 ký tự).
# --- Đang xử lý bài báo thứ 88 ---
#     -> Đã lấy xong nội dung (4613 ký tự).
# --- Đang xử lý bài báo thứ 89 ---
#     -> Đã lấy xong nội dung (4055 ký tự).
# --- Đang xử lý bài báo thứ 90 ---
#     -> Đã lấy xong nội dung (1789 ký tự).
# --- Đang xử lý bài báo thứ 91 ---
#     -> Đã lấy xong nội dung (2186 ký tự).
# --- Đang xử lý bài báo thứ 92 ---
#     -> Đã lấy xong nội dung (2478 ký tự).
# --- Đang xử lý bài báo thứ 93 ---
#     -> Đã lấy xong nội dung (923 ký tự).
# --- Đang xử lý bài báo thứ 94 ---
#     -> Đã lấy xong nội dung (2374 ký tự).
# --- Đang xử lý bài báo thứ 95 ---
#     -> Đã lấy xong nội dung (2774 ký tự).
# --- Đang xử lý bài báo thứ 96 ---
#     -> Đã lấy xong nội dung (1342 ký tự).
# --- Đang xử lý bài báo thứ 97 ---
#     -> Đã lấy xong nội dung (2241 ký tự).
# --- Đang xử lý bài báo thứ 98 ---
#     -> Đã lấy xong nội dung (1990 ký tự).
# --- Đang xử lý bài báo thứ 99 ---
#     -> Đã lấy xong nội dung (2298 ký tự).
# --- Đang xử lý bài báo thứ 100 ---
#     -> Đã lấy xong nội dung (4532 ký tự).
# --- Đang xử lý bài báo thứ 101 ---
#     -> Đã lấy xong nội dung (5874 ký tự).
# --- Đang xử lý bài báo thứ 102 ---
#     -> Đã lấy xong nội dung (2125 ký tự).
# --- Đang xử lý bài báo thứ 103 ---
#     -> Đã lấy xong nội dung (3354 ký tự).
# --- Đang xử lý bài báo thứ 104 ---
#     -> Đã lấy xong nội dung (4677 ký tự).
# --- Đang xử lý bài báo thứ 105 ---
#     -> Đã lấy xong nội dung (3191 ký tự).
# --- Đang xử lý bài báo thứ 106 ---
#     -> Đã lấy xong nội dung (2187 ký tự).
# --- Đang xử lý bài báo thứ 107 ---
#     -> Đã lấy xong nội dung (3455 ký tự).
# --- Đang xử lý bài báo thứ 108 ---
#     -> Đã lấy xong nội dung (7714 ký tự).
# --- Đang xử lý bài báo thứ 109 ---
#     -> Đã lấy xong nội dung (3076 ký tự).
# --- Đang xử lý bài báo thứ 110 ---
#     -> Đã lấy xong nội dung (5126 ký tự).
# --- Đang xử lý bài báo thứ 111 ---
#     -> Đã lấy xong nội dung (2993 ký tự).
# --- Đang xử lý bài báo thứ 112 ---
#     -> Đã lấy xong nội dung (4162 ký tự).
# --- Đang xử lý bài báo thứ 113 ---
#     -> Đã lấy xong nội dung (2815 ký tự).
# --- Đang xử lý bài báo thứ 114 ---
#     -> Đã lấy xong nội dung (2184 ký tự).
# --- Đang xử lý bài báo thứ 115 ---
#     -> Đã lấy xong nội dung (2953 ký tự).
# --- Đang xử lý bài báo thứ 116 ---
#     -> Đã lấy xong nội dung (3659 ký tự).
# --- Đang xử lý bài báo thứ 117 ---
#     -> Đã lấy xong nội dung (2474 ký tự).
# --- Đang xử lý bài báo thứ 118 ---
#     -> Đã lấy xong nội dung (2549 ký tự).
# --- Đang xử lý bài báo thứ 119 ---
#     -> Đã lấy xong nội dung (4517 ký tự).
# --- Đang xử lý bài báo thứ 120 ---
#     -> Đã lấy xong nội dung (4473 ký tự).
# --- Đang xử lý bài báo thứ 121 ---
#     -> Đã lấy xong nội dung (6975 ký tự).
# --- Đang xử lý bài báo thứ 122 ---
#     -> Đã lấy xong nội dung (2519 ký tự).
# --- Đang xử lý bài báo thứ 123 ---
#     -> Đã lấy xong nội dung (3899 ký tự).
# --- Đang xử lý bài báo thứ 124 ---
#     -> Đã lấy xong nội dung (2665 ký tự).
# --- Đang xử lý bài báo thứ 125 ---
#     -> Đã lấy xong nội dung (1869 ký tự).
# --- Đang xử lý bài báo thứ 126 ---
#     -> Đã lấy xong nội dung (3861 ký tự).
# --- Đang xử lý bài báo thứ 127 ---
#     -> Đã lấy xong nội dung (4112 ký tự).
# --- Đang xử lý bài báo thứ 128 ---
#     -> Đã lấy xong nội dung (2985 ký tự).
# --- Đang xử lý bài báo thứ 129 ---
#     -> Đã lấy xong nội dung (2498 ký tự).
# --- Đang xử lý bài báo thứ 130 ---
#     -> Đã lấy xong nội dung (1871 ký tự).
# --- Đang xử lý bài báo thứ 131 ---
#     -> Đã lấy xong nội dung (1705 ký tự).
# --- Đang xử lý bài báo thứ 132 ---
#     -> Đã lấy xong nội dung (2392 ký tự).
# --- Đang xử lý bài báo thứ 133 ---
#     -> Đã lấy xong nội dung (1734 ký tự).
# --- Đang xử lý bài báo thứ 134 ---
#     -> Đã lấy xong nội dung (2111 ký tự).
# --- Đang xử lý bài báo thứ 135 ---
#     -> Đã lấy xong nội dung (2698 ký tự).
# --- Đang xử lý bài báo thứ 136 ---
#     -> Đã lấy xong nội dung (3273 ký tự).
# --- Đang xử lý bài báo thứ 137 ---
#     -> Đã lấy xong nội dung (2064 ký tự).
# --- Đang xử lý bài báo thứ 138 ---
#     -> Đã lấy xong nội dung (2372 ký tự).
# --- Đang xử lý bài báo thứ 139 ---
#     -> Đã lấy xong nội dung (2228 ký tự).
# --- Đang xử lý bài báo thứ 140 ---
#     -> Đã lấy xong nội dung (1457 ký tự).
# --- Đang xử lý bài báo thứ 141 ---
#     -> Đã lấy xong nội dung (2597 ký tự).
# --- Đang xử lý bài báo thứ 142 ---
#     -> Đã lấy xong nội dung (3765 ký tự).
# --- Đang xử lý bài báo thứ 143 ---
#     -> Đã lấy xong nội dung (4177 ký tự).
# --- Đang xử lý bài báo thứ 144 ---
#     -> Đã lấy xong nội dung (1628 ký tự).
# --- Đang xử lý bài báo thứ 145 ---
#     -> Đã lấy xong nội dung (2262 ký tự).
# --- Đang xử lý bài báo thứ 146 ---
#     -> Đã lấy xong nội dung (1949 ký tự).
# --- Đang xử lý bài báo thứ 147 ---
#     -> Đã lấy xong nội dung (2809 ký tự).
# --- Đang xử lý bài báo thứ 148 ---
#     -> Đã lấy xong nội dung (2301 ký tự).
# --- Đang xử lý bài báo thứ 149 ---
#     -> Đã lấy xong nội dung (256 ký tự).
# --- Đang xử lý bài báo thứ 150 ---
#     -> Đã lấy xong nội dung (2362 ký tự).
# --- Đang xử lý bài báo thứ 151 ---
#     -> Đã lấy xong nội dung (6171 ký tự).
# --- Đang xử lý bài báo thứ 152 ---
#     -> Đã lấy xong nội dung (3993 ký tự).
# --- Đang xử lý bài báo thứ 153 ---
#     -> Đã lấy xong nội dung (9074 ký tự).
# --- Đang xử lý bài báo thứ 154 ---
#     -> Đã lấy xong nội dung (6401 ký tự).
# --- Đang xử lý bài báo thứ 155 ---
#     -> Đã lấy xong nội dung (2192 ký tự).
# --- Đang xử lý bài báo thứ 156 ---
#     -> Đã lấy xong nội dung (3891 ký tự).
# --- Đang xử lý bài báo thứ 157 ---
#     -> Đã lấy xong nội dung (1006 ký tự).
# --- Đang xử lý bài báo thứ 158 ---
#     -> Đã lấy xong nội dung (3025 ký tự).
# --- Đang xử lý bài báo thứ 159 ---
#     -> Đã lấy xong nội dung (3758 ký tự).
# --- Đang xử lý bài báo thứ 160 ---
#     -> Đã lấy xong nội dung (3786 ký tự).
# --- Đang xử lý bài báo thứ 161 ---
#     -> Đã lấy xong nội dung (1444 ký tự).
# --- Đang xử lý bài báo thứ 162 ---
#     -> Đã lấy xong nội dung (2523 ký tự).
# --- Đang xử lý bài báo thứ 163 ---
#     -> Đã lấy xong nội dung (3460 ký tự).
# --- Đang xử lý bài báo thứ 164 ---
#     -> Đã lấy xong nội dung (1886 ký tự).
# --- Đang xử lý bài báo thứ 165 ---
#     -> Đã lấy xong nội dung (2280 ký tự).
# --- Đang xử lý bài báo thứ 166 ---
#     -> Đã lấy xong nội dung (5203 ký tự).
# --- Đang xử lý bài báo thứ 167 ---
#     -> Đã lấy xong nội dung (3260 ký tự).
# --- Đang xử lý bài báo thứ 168 ---
#     -> Đã lấy xong nội dung (7448 ký tự).
# --- Đang xử lý bài báo thứ 169 ---
#     -> Đã lấy xong nội dung (5432 ký tự).
# --- Đang xử lý bài báo thứ 170 ---
#     -> Đã lấy xong nội dung (2754 ký tự).
# --- Đang xử lý bài báo thứ 171 ---
#     -> Đã lấy xong nội dung (1182 ký tự).
# --- Đang xử lý bài báo thứ 172 ---
#     -> Đã lấy xong nội dung (3261 ký tự).
# --- Đang xử lý bài báo thứ 173 ---
#     -> Đã lấy xong nội dung (3097 ký tự).
# --- Đang xử lý bài báo thứ 174 ---
#     -> Đã lấy xong nội dung (3859 ký tự).
# --- Đang xử lý bài báo thứ 175 ---
#     -> Đã lấy xong nội dung (2445 ký tự).
# --- Đang xử lý bài báo thứ 176 ---
#     -> Đã lấy xong nội dung (2086 ký tự).
# --- Đang xử lý bài báo thứ 177 ---
#     -> Đã lấy xong nội dung (802 ký tự).
# --- Đang xử lý bài báo thứ 178 ---
#     -> Đã lấy xong nội dung (2397 ký tự).
# --- Đang xử lý bài báo thứ 179 ---
#     -> Đã lấy xong nội dung (1459 ký tự).
# --- Đang xử lý bài báo thứ 180 ---
#     -> Đã lấy xong nội dung (2067 ký tự).
# --- Đang xử lý bài báo thứ 181 ---
#     -> Đã lấy xong nội dung (2054 ký tự).
# --- Đang xử lý bài báo thứ 182 ---
#     -> Đã lấy xong nội dung (1551 ký tự).
# --- Đang xử lý bài báo thứ 183 ---
#     -> Đã lấy xong nội dung (2371 ký tự).
# --- Đang xử lý bài báo thứ 184 ---
#     -> Đã lấy xong nội dung (1535 ký tự).
# --- Đang xử lý bài báo thứ 185 ---
#     -> Đã lấy xong nội dung (6696 ký tự).
# --- Đang xử lý bài báo thứ 186 ---
#     -> Đã lấy xong nội dung (4448 ký tự).
# --- Đang xử lý bài báo thứ 187 ---
#     -> Đã lấy xong nội dung (3487 ký tự).
# --- Đang xử lý bài báo thứ 188 ---
#     -> Đã lấy xong nội dung (3698 ký tự).
# --- Đang xử lý bài báo thứ 189 ---
#     -> Đã lấy xong nội dung (2858 ký tự).
# --- Đang xử lý bài báo thứ 190 ---
#     -> Đã lấy xong nội dung (3550 ký tự).
# --- Đang xử lý bài báo thứ 191 ---
#     -> Đã lấy xong nội dung (972 ký tự).
# --- Đang xử lý bài báo thứ 192 ---
#     -> Đã lấy xong nội dung (3996 ký tự).
# --- Đang xử lý bài báo thứ 193 ---
#     -> Đã lấy xong nội dung (2651 ký tự).
# --- Đang xử lý bài báo thứ 194 ---
#     -> Đã lấy xong nội dung (9039 ký tự).
# --- Đang xử lý bài báo thứ 195 ---
#     -> Đã lấy xong nội dung (1895 ký tự).
# --- Đang xử lý bài báo thứ 196 ---
#     -> Đã lấy xong nội dung (2706 ký tự).
# --- Đang xử lý bài báo thứ 197 ---
#     -> Đã lấy xong nội dung (6020 ký tự).
# --- Đang xử lý bài báo thứ 198 ---
#     -> Đã lấy xong nội dung (2705 ký tự).
# --- Đang xử lý bài báo thứ 199 ---
#     -> Đã lấy xong nội dung (11133 ký tự).
# --- Đang xử lý bài báo thứ 200 ---
#     -> Đã lấy xong nội dung (3251 ký tự).
# --- Đang xử lý bài báo thứ 201 ---
#     -> Đã lấy xong nội dung (1834 ký tự).
# --- Đang xử lý bài báo thứ 202 ---
#     -> Đã lấy xong nội dung (2577 ký tự).
# --- Đang xử lý bài báo thứ 203 ---
#     -> Đã lấy xong nội dung (1924 ký tự).
# --- Đang xử lý bài báo thứ 204 ---
#     -> Đã lấy xong nội dung (3340 ký tự).
# --- Đang xử lý bài báo thứ 205 ---
#     -> Đã lấy xong nội dung (3551 ký tự).
# --- Đang xử lý bài báo thứ 206 ---
#     -> Đã lấy xong nội dung (2396 ký tự).
# --- Đang xử lý bài báo thứ 207 ---
#     -> Đã lấy xong nội dung (2998 ký tự).
# --- Đang xử lý bài báo thứ 208 ---
#     -> Đã lấy xong nội dung (1966 ký tự).
# --- Đang xử lý bài báo thứ 209 ---
#     -> Đã lấy xong nội dung (2758 ký tự).
# --- Đang xử lý bài báo thứ 210 ---
#     -> Đã lấy xong nội dung (987 ký tự).
# --- Đang xử lý bài báo thứ 211 ---
#     -> Đã lấy xong nội dung (2597 ký tự).
# --- Đang xử lý bài báo thứ 212 ---
#     -> Đã lấy xong nội dung (3763 ký tự).
# --- Đang xử lý bài báo thứ 213 ---
#     -> Đã lấy xong nội dung (3357 ký tự).
# --- Đang xử lý bài báo thứ 214 ---
#     -> Đã lấy xong nội dung (2065 ký tự).
# --- Đang xử lý bài báo thứ 215 ---
#     -> Đã lấy xong nội dung (2163 ký tự).
# --- Đang xử lý bài báo thứ 216 ---
#     -> Đã lấy xong nội dung (2266 ký tự).
# --- Đang xử lý bài báo thứ 217 ---
#     -> Đã lấy xong nội dung (1797 ký tự).
# --- Đang xử lý bài báo thứ 218 ---
#     -> Đã lấy xong nội dung (1480 ký tự).
# --- Đang xử lý bài báo thứ 219 ---
#     -> Đã lấy xong nội dung (3379 ký tự).
# --- Đang xử lý bài báo thứ 220 ---
#     -> Đã lấy xong nội dung (2745 ký tự).
# --- Đang xử lý bài báo thứ 221 ---
#     -> Đã lấy xong nội dung (4506 ký tự).
# --- Đang xử lý bài báo thứ 222 ---
#     -> Đã lấy xong nội dung (2634 ký tự).
# --- Đang xử lý bài báo thứ 223 ---
#     -> Đã lấy xong nội dung (3032 ký tự).
# --- Đang xử lý bài báo thứ 224 ---
#     -> Đã lấy xong nội dung (813 ký tự).
# --- Đang xử lý bài báo thứ 225 ---
#     -> Đã lấy xong nội dung (2403 ký tự).
# --- Đang xử lý bài báo thứ 226 ---
#     -> Đã lấy xong nội dung (4947 ký tự).
# --- Đang xử lý bài báo thứ 227 ---
#     -> Đã lấy xong nội dung (3685 ký tự).
# --- Đang xử lý bài báo thứ 228 ---
#     -> Đã lấy xong nội dung (4762 ký tự).
# --- Đang xử lý bài báo thứ 229 ---
#     -> Đã lấy xong nội dung (2164 ký tự).
# --- Đang xử lý bài báo thứ 230 ---
#     -> Đã lấy xong nội dung (3099 ký tự).
# --- Đang xử lý bài báo thứ 231 ---
#     -> Đã lấy xong nội dung (3927 ký tự).
# --- Đang xử lý bài báo thứ 232 ---
#     -> Đã lấy xong nội dung (8012 ký tự).
# --- Đang xử lý bài báo thứ 233 ---
#     -> Đã lấy xong nội dung (2741 ký tự).
# --- Đang xử lý bài báo thứ 234 ---
#     -> Đã lấy xong nội dung (2310 ký tự).
# --- Đang xử lý bài báo thứ 235 ---
#     -> Đã lấy xong nội dung (2596 ký tự).
# --- Đang xử lý bài báo thứ 236 ---
#     -> Đã lấy xong nội dung (4688 ký tự).
# --- Đang xử lý bài báo thứ 237 ---
#     -> Đã lấy xong nội dung (4795 ký tự).
# --- Đang xử lý bài báo thứ 238 ---
#     -> Đã lấy xong nội dung (3778 ký tự).
# --- Đang xử lý bài báo thứ 239 ---
#     -> Đã lấy xong nội dung (2304 ký tự).
# --- Đang xử lý bài báo thứ 240 ---
#     -> Đã lấy xong nội dung (3765 ký tự).
# --- Đang xử lý bài báo thứ 241 ---
#     -> Đã lấy xong nội dung (2199 ký tự).
# --- Đang xử lý bài báo thứ 242 ---
#     -> Đã lấy xong nội dung (4588 ký tự).
# --- Đang xử lý bài báo thứ 243 ---
#     -> Đã lấy xong nội dung (4078 ký tự).
# --- Đang xử lý bài báo thứ 244 ---
#     -> Đã lấy xong nội dung (2387 ký tự).
# --- Đang xử lý bài báo thứ 245 ---
#     -> Đã lấy xong nội dung (2134 ký tự).
# --- Đang xử lý bài báo thứ 246 ---
#     -> Đã lấy xong nội dung (4932 ký tự).
# --- Đang xử lý bài báo thứ 247 ---
#     -> Đã lấy xong nội dung (2862 ký tự).
# --- Đang xử lý bài báo thứ 248 ---
#     -> Đã lấy xong nội dung (2249 ký tự).
# --- Đang xử lý bài báo thứ 249 ---
#     -> Đã lấy xong nội dung (1985 ký tự).
# --- Đang xử lý bài báo thứ 250 ---
#     -> Đã lấy xong nội dung (3935 ký tự).
# --- Đang xử lý bài báo thứ 251 ---
#     -> Đã lấy xong nội dung (937 ký tự).
# --- Đang xử lý bài báo thứ 252 ---
#     -> Đã lấy xong nội dung (2213 ký tự).
# --- Đang xử lý bài báo thứ 253 ---
#     -> Đã lấy xong nội dung (3558 ký tự).
# --- Đang xử lý bài báo thứ 254 ---
#     -> Đã lấy xong nội dung (5718 ký tự).
# --- Đang xử lý bài báo thứ 255 ---
#     -> Đã lấy xong nội dung (1897 ký tự).
# --- Đang xử lý bài báo thứ 256 ---
#     -> Đã lấy xong nội dung (3943 ký tự).
# --- Đang xử lý bài báo thứ 257 ---
#     -> Đã lấy xong nội dung (3244 ký tự).
# --- Đang xử lý bài báo thứ 258 ---
#     -> Đã lấy xong nội dung (2120 ký tự).
# --- Đang xử lý bài báo thứ 259 ---
#     -> Đã lấy xong nội dung (3388 ký tự).
# --- Đang xử lý bài báo thứ 260 ---
#     -> Đã lấy xong nội dung (2244 ký tự).
# --- Đang xử lý bài báo thứ 261 ---
#     -> Đã lấy xong nội dung (3020 ký tự).
# --- Đang xử lý bài báo thứ 262 ---
#     -> Đã lấy xong nội dung (1273 ký tự).
# --- Đang xử lý bài báo thứ 263 ---
#     -> Đã lấy xong nội dung (2325 ký tự).
# --- Đang xử lý bài báo thứ 264 ---
#     -> Đã lấy xong nội dung (4469 ký tự).
# --- Đang xử lý bài báo thứ 265 ---
#     -> Đã lấy xong nội dung (3160 ký tự).
# --- Đang xử lý bài báo thứ 266 ---
#     -> Đã lấy xong nội dung (5518 ký tự).
# --- Đang xử lý bài báo thứ 267 ---
#     -> Đã lấy xong nội dung (2794 ký tự).
# --- Đang xử lý bài báo thứ 268 ---
#     -> Đã lấy xong nội dung (1374 ký tự).
# --- Đang xử lý bài báo thứ 269 ---
#     -> Đã lấy xong nội dung (5550 ký tự).
# --- Đang xử lý bài báo thứ 270 ---
#     -> Đã lấy xong nội dung (1057 ký tự).
# --- Đang xử lý bài báo thứ 271 ---
#     -> Đã lấy xong nội dung (1954 ký tự).
# --- Đang xử lý bài báo thứ 272 ---
#     -> Đã lấy xong nội dung (3667 ký tự).
# --- Đang xử lý bài báo thứ 273 ---
#     -> Đã lấy xong nội dung (3558 ký tự).
# --- Đang xử lý bài báo thứ 274 ---
#     -> Đã lấy xong nội dung (2120 ký tự).
# --- Đang xử lý bài báo thứ 275 ---
#     -> Đã lấy xong nội dung (2842 ký tự).
# --- Đang xử lý bài báo thứ 276 ---
#     -> Đã lấy xong nội dung (4218 ký tự).
# --- Đang xử lý bài báo thứ 277 ---
#     -> Đã lấy xong nội dung (1855 ký tự).
# --- Đang xử lý bài báo thứ 278 ---
#     -> Đã lấy xong nội dung (3994 ký tự).
# --- Đang xử lý bài báo thứ 279 ---
#     -> Đã lấy xong nội dung (3944 ký tự).
# --- Đang xử lý bài báo thứ 280 ---
#     -> Đã lấy xong nội dung (3090 ký tự).
# --- Đang xử lý bài báo thứ 281 ---
#     -> Đã lấy xong nội dung (2311 ký tự).
# --- Đang xử lý bài báo thứ 282 ---
#     -> Đã lấy xong nội dung (3012 ký tự).
# --- Đang xử lý bài báo thứ 283 ---
#     -> Đã lấy xong nội dung (2801 ký tự).
# --- Đang xử lý bài báo thứ 284 ---
#     -> Đã lấy xong nội dung (3277 ký tự).
# --- Đang xử lý bài báo thứ 285 ---
#     -> Đã lấy xong nội dung (3909 ký tự).
# --- Đang xử lý bài báo thứ 286 ---
#     -> Đã lấy xong nội dung (3269 ký tự).
# --- Đang xử lý bài báo thứ 287 ---
#     -> Đã lấy xong nội dung (1915 ký tự).
# --- Đang xử lý bài báo thứ 288 ---
#     -> Đã lấy xong nội dung (2890 ký tự).
# --- Đang xử lý bài báo thứ 289 ---
#     -> Đã lấy xong nội dung (1605 ký tự).
# --- Đang xử lý bài báo thứ 290 ---
#     -> Đã lấy xong nội dung (3707 ký tự).
# --- Đang xử lý bài báo thứ 291 ---
#     -> Đã lấy xong nội dung (2451 ký tự).
# --- Đang xử lý bài báo thứ 292 ---
#     -> Đã lấy xong nội dung (938 ký tự).
# --- Đang xử lý bài báo thứ 293 ---
#     -> Đã lấy xong nội dung (2568 ký tự).
# --- Đang xử lý bài báo thứ 294 ---
#     -> Đã lấy xong nội dung (4668 ký tự).
# --- Đang xử lý bài báo thứ 295 ---
#     -> Đã lấy xong nội dung (1447 ký tự).
# --- Đang xử lý bài báo thứ 296 ---
#     -> Đã lấy xong nội dung (2209 ký tự).
# --- Đang xử lý bài báo thứ 297 ---
#     -> Đã lấy xong nội dung (1859 ký tự).
# --- Đang xử lý bài báo thứ 298 ---
#     -> Đã lấy xong nội dung (2700 ký tự).
# --- Đang xử lý bài báo thứ 299 ---
#     -> Đã lấy xong nội dung (4106 ký tự).
# --- Đang xử lý bài báo thứ 300 ---
#     -> Đã lấy xong nội dung (3884 ký tự).
# --- Đang xử lý bài báo thứ 301 ---
#     -> Đã lấy xong nội dung (3181 ký tự).
# --- Đang xử lý bài báo thứ 302 ---
#     -> Đã lấy xong nội dung (12595 ký tự).
# --- Đang xử lý bài báo thứ 303 ---
#     -> Đã lấy xong nội dung (3171 ký tự).
# --- Đang xử lý bài báo thứ 304 ---
#     -> Đã lấy xong nội dung (3608 ký tự).
# --- Đang xử lý bài báo thứ 305 ---
#     -> Đã lấy xong nội dung (2976 ký tự).
# --- Đang xử lý bài báo thứ 306 ---
#     -> Đã lấy xong nội dung (2528 ký tự).
# --- Đang xử lý bài báo thứ 307 ---
#     -> Đã lấy xong nội dung (1882 ký tự).
# --- Đang xử lý bài báo thứ 308 ---
#     -> CẢNH BÁO: Quá 3 phút không lấy được nội dung bài 308. Để trống content.
# --- Đang xử lý bài báo thứ 309 ---
#     -> Đã lấy xong nội dung (3174 ký tự).
# --- Đang xử lý bài báo thứ 310 ---
#     -> Đã lấy xong nội dung (3973 ký tự).
# --- Đang xử lý bài báo thứ 311 ---
#     -> Đã lấy xong nội dung (4006 ký tự).
# --- Đang xử lý bài báo thứ 312 ---
#     -> Đã lấy xong nội dung (2814 ký tự).
# --- Đang xử lý bài báo thứ 313 ---
#     -> Đã lấy xong nội dung (849 ký tự).
# --- Đang xử lý bài báo thứ 314 ---
#     -> Đã lấy xong nội dung (2863 ký tự).
# --- Đang xử lý bài báo thứ 315 ---
#     -> Đã lấy xong nội dung (2706 ký tự).
# --- Đang xử lý bài báo thứ 316 ---
#     -> Đã lấy xong nội dung (3194 ký tự).
# --- Đang xử lý bài báo thứ 317 ---
#     -> Đã lấy xong nội dung (3163 ký tự).
# --- Đang xử lý bài báo thứ 318 ---
#     -> Đã lấy xong nội dung (1741 ký tự).
# --- Đang xử lý bài báo thứ 319 ---
#     -> Đã lấy xong nội dung (2270 ký tự).
# --- Đang xử lý bài báo thứ 320 ---
#     -> Đã lấy xong nội dung (3461 ký tự).
# --- Đang xử lý bài báo thứ 321 ---
#     -> Đã lấy xong nội dung (2767 ký tự).
# --- Đang xử lý bài báo thứ 322 ---
#     -> Đã lấy xong nội dung (2532 ký tự).
# --- Đang xử lý bài báo thứ 323 ---
#     -> Đã lấy xong nội dung (2391 ký tự).
# --- Đang xử lý bài báo thứ 324 ---
#     -> Đã lấy xong nội dung (3435 ký tự).
# --- Đang xử lý bài báo thứ 325 ---
#     -> Đã lấy xong nội dung (4398 ký tự).
# --- Đang xử lý bài báo thứ 326 ---
#     -> Đã lấy xong nội dung (2592 ký tự).
# --- Đang xử lý bài báo thứ 327 ---
#     -> Đã lấy xong nội dung (2363 ký tự).
# --- Đang xử lý bài báo thứ 328 ---
#     -> Đã lấy xong nội dung (11803 ký tự).
# --- Đang xử lý bài báo thứ 329 ---
#     -> Đã lấy xong nội dung (2799 ký tự).
# --- Đang xử lý bài báo thứ 330 ---
#     -> Đã lấy xong nội dung (6163 ký tự).
# --- Đang xử lý bài báo thứ 331 ---
#     -> Đã lấy xong nội dung (1930 ký tự).
# --- Đang xử lý bài báo thứ 332 ---
#     -> Đã lấy xong nội dung (2157 ký tự).
# --- Đang xử lý bài báo thứ 333 ---
#     -> Đã lấy xong nội dung (2619 ký tự).
# --- Đang xử lý bài báo thứ 334 ---
#     -> Đã lấy xong nội dung (5334 ký tự).
# --- Đang xử lý bài báo thứ 335 ---
#     -> Đã lấy xong nội dung (4340 ký tự).
# --- Đang xử lý bài báo thứ 336 ---
#     -> Đã lấy xong nội dung (2127 ký tự).
# --- Đang xử lý bài báo thứ 337 ---
#     -> Đã lấy xong nội dung (3181 ký tự).
# --- Đang xử lý bài báo thứ 338 ---
#     -> Đã lấy xong nội dung (2928 ký tự).
# --- Đang xử lý bài báo thứ 339 ---
#     -> Đã lấy xong nội dung (958 ký tự).
# --- Đang xử lý bài báo thứ 340 ---
#     -> Đã lấy xong nội dung (1837 ký tự).
# --- Đang xử lý bài báo thứ 341 ---
#     -> Đã lấy xong nội dung (3319 ký tự).
# --- Đang xử lý bài báo thứ 342 ---
#     -> Đã lấy xong nội dung (6271 ký tự).
# --- Đang xử lý bài báo thứ 343 ---
#     -> Đã lấy xong nội dung (4294 ký tự).
# --- Đang xử lý bài báo thứ 344 ---
#     -> Đã lấy xong nội dung (1936 ký tự).
# --- Đang xử lý bài báo thứ 345 ---
#     -> Đã lấy xong nội dung (1764 ký tự).
# --- Đang xử lý bài báo thứ 346 ---
#     -> Đã lấy xong nội dung (2663 ký tự).
# --- Đang xử lý bài báo thứ 347 ---
#     -> Đã lấy xong nội dung (10790 ký tự).
# --- Đang xử lý bài báo thứ 348 ---
#     -> Đã lấy xong nội dung (4695 ký tự).
# --- Đang xử lý bài báo thứ 349 ---
#     -> Đã lấy xong nội dung (4971 ký tự).
# --- Đang xử lý bài báo thứ 350 ---
#     -> Đã lấy xong nội dung (3473 ký tự).
# --- Đang xử lý bài báo thứ 351 ---
#     -> Đã lấy xong nội dung (1551 ký tự).
# --- Đang xử lý bài báo thứ 352 ---
#     -> Đã lấy xong nội dung (2899 ký tự).
# --- Đang xử lý bài báo thứ 353 ---
#     -> Đã lấy xong nội dung (2823 ký tự).
# --- Đang xử lý bài báo thứ 354 ---
#     -> Đã lấy xong nội dung (2299 ký tự).
# --- Đang xử lý bài báo thứ 355 ---
#     -> Đã lấy xong nội dung (3920 ký tự).
# --- Đang xử lý bài báo thứ 356 ---
#     -> Đã lấy xong nội dung (8870 ký tự).
# --- Đang xử lý bài báo thứ 357 ---
#     -> Đã lấy xong nội dung (2175 ký tự).
# --- Đang xử lý bài báo thứ 358 ---
#     -> Đã lấy xong nội dung (2987 ký tự).
# --- Đang xử lý bài báo thứ 359 ---
#     -> Đã lấy xong nội dung (2227 ký tự).
# --- Đang xử lý bài báo thứ 360 ---
#     -> Đã lấy xong nội dung (4935 ký tự).
# --- Đang xử lý bài báo thứ 361 ---
#     -> Đã lấy xong nội dung (3950 ký tự).
# --- Đang xử lý bài báo thứ 362 ---
#     -> Đã lấy xong nội dung (2073 ký tự).
# --- Đang xử lý bài báo thứ 363 ---
#     -> Đã lấy xong nội dung (3087 ký tự).
# --- Đang xử lý bài báo thứ 364 ---
#     -> Đã lấy xong nội dung (2447 ký tự).
# --- Đang xử lý bài báo thứ 365 ---
#     -> Đã lấy xong nội dung (3359 ký tự).
# --- Đang xử lý bài báo thứ 366 ---
#     -> Đã lấy xong nội dung (4188 ký tự).
# --- Đang xử lý bài báo thứ 367 ---
#     -> Đã lấy xong nội dung (2318 ký tự).
# --- Đang xử lý bài báo thứ 368 ---
#     -> Đã lấy xong nội dung (1903 ký tự).
# --- Đang xử lý bài báo thứ 369 ---
#     -> Đã lấy xong nội dung (3970 ký tự).
# --- Đang xử lý bài báo thứ 370 ---
#     -> Đã lấy xong nội dung (5189 ký tự).
# --- Đang xử lý bài báo thứ 371 ---
#     -> Đã lấy xong nội dung (2030 ký tự).
# --- Đang xử lý bài báo thứ 372 ---
#     -> Đã lấy xong nội dung (3601 ký tự).
# --- Đang xử lý bài báo thứ 373 ---
#     -> Đã lấy xong nội dung (6979 ký tự).
# --- Đang xử lý bài báo thứ 374 ---
#     -> Đã lấy xong nội dung (3998 ký tự).
# --- Đang xử lý bài báo thứ 375 ---
#     -> Đã lấy xong nội dung (2637 ký tự).
# --- Đang xử lý bài báo thứ 376 ---
#     -> Đã lấy xong nội dung (1905 ký tự).
# --- Đang xử lý bài báo thứ 377 ---
#     -> Đã lấy xong nội dung (5345 ký tự).
# --- Đang xử lý bài báo thứ 378 ---
#     -> Đã lấy xong nội dung (2201 ký tự).
# --- Đang xử lý bài báo thứ 379 ---
#     -> Đã lấy xong nội dung (1107 ký tự).
# --- Đang xử lý bài báo thứ 380 ---
#     -> Đã lấy xong nội dung (2709 ký tự).
# --- Đang xử lý bài báo thứ 381 ---
#     -> Đã lấy xong nội dung (3904 ký tự).
# --- Đang xử lý bài báo thứ 382 ---
#     -> Đã lấy xong nội dung (1877 ký tự).
# --- Đang xử lý bài báo thứ 383 ---
#     -> Đã lấy xong nội dung (3686 ký tự).
# --- Đang xử lý bài báo thứ 384 ---
#     -> Đã lấy xong nội dung (2372 ký tự).
# --- Đang xử lý bài báo thứ 385 ---
#     -> Đã lấy xong nội dung (3114 ký tự).
# --- Đang xử lý bài báo thứ 386 ---
#     -> Đã lấy xong nội dung (1574 ký tự).
# --- Đang xử lý bài báo thứ 387 ---
#     -> Đã lấy xong nội dung (2505 ký tự).
# --- Đang xử lý bài báo thứ 388 ---
#     -> Đã lấy xong nội dung (2400 ký tự).
# --- Đang xử lý bài báo thứ 389 ---
#     -> Đã lấy xong nội dung (3075 ký tự).
# --- Đang xử lý bài báo thứ 390 ---
#     -> Đã lấy xong nội dung (2363 ký tự).
# --- Đang xử lý bài báo thứ 391 ---
#     -> Đã lấy xong nội dung (2493 ký tự).
# --- Đang xử lý bài báo thứ 392 ---
#     -> Đã lấy xong nội dung (6452 ký tự).
# --- Đang xử lý bài báo thứ 393 ---
#     -> Đã lấy xong nội dung (5613 ký tự).
# --- Đang xử lý bài báo thứ 394 ---
#     -> Đã lấy xong nội dung (2344 ký tự).
# --- Đang xử lý bài báo thứ 395 ---
#     -> Đã lấy xong nội dung (3265 ký tự).
# --- Đang xử lý bài báo thứ 396 ---
#     -> Đã lấy xong nội dung (3603 ký tự).
# --- Đang xử lý bài báo thứ 397 ---
#     -> Đã lấy xong nội dung (2206 ký tự).
# --- Đang xử lý bài báo thứ 398 ---
#     -> Đã lấy xong nội dung (1980 ký tự).
# --- Đang xử lý bài báo thứ 399 ---
#     -> Đã lấy xong nội dung (1001 ký tự).
# --- Đang xử lý bài báo thứ 400 ---
#     -> Đã lấy xong nội dung (2431 ký tự).
# --- Đang xử lý bài báo thứ 401 ---
#     -> Đã lấy xong nội dung (2021 ký tự).
# --- Đang xử lý bài báo thứ 402 ---
#     -> Đã lấy xong nội dung (1981 ký tự).
# --- Đang xử lý bài báo thứ 403 ---
#     -> Đã lấy xong nội dung (1998 ký tự).
# --- Đang xử lý bài báo thứ 404 ---
#     -> Đã lấy xong nội dung (2600 ký tự).
# --- Đang xử lý bài báo thứ 405 ---
#     -> Đã lấy xong nội dung (3303 ký tự).
# --- Đang xử lý bài báo thứ 406 ---
#     -> Đã lấy xong nội dung (3149 ký tự).
# --- Đang xử lý bài báo thứ 407 ---
#     -> Đã lấy xong nội dung (2382 ký tự).
# --- Đang xử lý bài báo thứ 408 ---
#     -> Đã lấy xong nội dung (3563 ký tự).
# --- Đang xử lý bài báo thứ 409 ---
#     -> Đã lấy xong nội dung (3272 ký tự).
# --- Đang xử lý bài báo thứ 410 ---
#     -> Đã lấy xong nội dung (1494 ký tự).
# --- Đang xử lý bài báo thứ 411 ---
#     -> Đã lấy xong nội dung (2784 ký tự).
# --- Đang xử lý bài báo thứ 412 ---
#     -> Đã lấy xong nội dung (3515 ký tự).
# --- Đang xử lý bài báo thứ 413 ---
#     -> Đã lấy xong nội dung (7795 ký tự).
# --- Đang xử lý bài báo thứ 414 ---
#     -> Đã lấy xong nội dung (2908 ký tự).
# --- Đang xử lý bài báo thứ 415 ---
#     -> Đã lấy xong nội dung (2569 ký tự).
# --- Đang xử lý bài báo thứ 416 ---
#     -> Đã lấy xong nội dung (2178 ký tự).
# --- Đang xử lý bài báo thứ 417 ---
#     -> Đã lấy xong nội dung (1936 ký tự).
# --- Đang xử lý bài báo thứ 418 ---
#     -> Đã lấy xong nội dung (4077 ký tự).
# --- Đang xử lý bài báo thứ 419 ---
#     -> Đã lấy xong nội dung (1915 ký tự).
# --- Đang xử lý bài báo thứ 420 ---
#     -> Đã lấy xong nội dung (5674 ký tự).
# --- Đang xử lý bài báo thứ 421 ---
#     -> Đã lấy xong nội dung (914 ký tự).
# --- Đang xử lý bài báo thứ 422 ---
#     -> Đã lấy xong nội dung (1974 ký tự).
# --- Đang xử lý bài báo thứ 423 ---
#     -> Đã lấy xong nội dung (2043 ký tự).
# --- Đang xử lý bài báo thứ 424 ---
#     -> Đã lấy xong nội dung (2305 ký tự).
# --- Đang xử lý bài báo thứ 425 ---
#     -> Đã lấy xong nội dung (1519 ký tự).
# --- Đang xử lý bài báo thứ 426 ---
#     -> Đã lấy xong nội dung (1928 ký tự).
# --- Đang xử lý bài báo thứ 427 ---
#     -> Đã lấy xong nội dung (1941 ký tự).
# --- Đang xử lý bài báo thứ 428 ---
#     -> Đã lấy xong nội dung (1923 ký tự).
# --- Đang xử lý bài báo thứ 429 ---
#     -> Đã lấy xong nội dung (2562 ký tự).
# --- Đang xử lý bài báo thứ 430 ---
#     -> Đã lấy xong nội dung (2181 ký tự).
# --- Đang xử lý bài báo thứ 431 ---
#     -> Đã lấy xong nội dung (3438 ký tự).
# --- Đang xử lý bài báo thứ 432 ---
#     -> Đã lấy xong nội dung (4393 ký tự).
# --- Đang xử lý bài báo thứ 433 ---
#     -> Đã lấy xong nội dung (2887 ký tự).
# --- Đang xử lý bài báo thứ 434 ---
#     -> Đã lấy xong nội dung (2520 ký tự).
# --- Đang xử lý bài báo thứ 435 ---
#     -> Đã lấy xong nội dung (3324 ký tự).
# --- Đang xử lý bài báo thứ 436 ---
#     -> Đã lấy xong nội dung (5029 ký tự).
# --- Đang xử lý bài báo thứ 437 ---
#     -> Đã lấy xong nội dung (3467 ký tự).
# --- Đang xử lý bài báo thứ 438 ---
#     -> Đã lấy xong nội dung (3758 ký tự).
# --- Đang xử lý bài báo thứ 439 ---
#     -> Đã lấy xong nội dung (3669 ký tự).
# --- Đang xử lý bài báo thứ 440 ---
#     -> Đã lấy xong nội dung (1866 ký tự).
# --- Đang xử lý bài báo thứ 441 ---
#     -> Đã lấy xong nội dung (2436 ký tự).
# --- Đang xử lý bài báo thứ 442 ---
#     -> Đã lấy xong nội dung (1087 ký tự).
# --- Đang xử lý bài báo thứ 443 ---
#     -> Đã lấy xong nội dung (2921 ký tự).
# --- Đang xử lý bài báo thứ 444 ---
#     -> Đã lấy xong nội dung (2380 ký tự).
# --- Đang xử lý bài báo thứ 445 ---
#     -> Đã lấy xong nội dung (1933 ký tự).
# --- Đang xử lý bài báo thứ 446 ---
#     -> Đã lấy xong nội dung (2630 ký tự).
# --- Đang xử lý bài báo thứ 447 ---
#     -> Đã lấy xong nội dung (3940 ký tự).
# --- Đang xử lý bài báo thứ 448 ---
#     -> Đã lấy xong nội dung (2154 ký tự).
# --- Đang xử lý bài báo thứ 449 ---
#     -> Đã lấy xong nội dung (2590 ký tự).
# --- Đang xử lý bài báo thứ 450 ---
#     -> Đã lấy xong nội dung (2899 ký tự).
# --- Đang xử lý bài báo thứ 451 ---
#     -> Đã lấy xong nội dung (2435 ký tự).
# --- Đang xử lý bài báo thứ 452 ---
#     -> Đã lấy xong nội dung (2715 ký tự).
# --- Đang xử lý bài báo thứ 453 ---
#     -> Đã lấy xong nội dung (2251 ký tự).
# --- Đang xử lý bài báo thứ 454 ---
#     -> Đã lấy xong nội dung (2172 ký tự).
# --- Đang xử lý bài báo thứ 455 ---
#     -> Đã lấy xong nội dung (2780 ký tự).
# --- Đang xử lý bài báo thứ 456 ---
#     -> Đã lấy xong nội dung (5161 ký tự).
# --- Đang xử lý bài báo thứ 457 ---
#     -> Đã lấy xong nội dung (1918 ký tự).
# --- Đang xử lý bài báo thứ 458 ---
#     -> Đã lấy xong nội dung (2685 ký tự).
# --- Đang xử lý bài báo thứ 459 ---
#     -> Đã lấy xong nội dung (2418 ký tự).
# --- Đang xử lý bài báo thứ 460 ---
#     -> Đã lấy xong nội dung (2682 ký tự).
# --- Đang xử lý bài báo thứ 461 ---
#     -> Đã lấy xong nội dung (1935 ký tự).
# --- Đang xử lý bài báo thứ 462 ---
#     -> Đã lấy xong nội dung (2067 ký tự).
# --- Đang xử lý bài báo thứ 463 ---
#     -> Đã lấy xong nội dung (2533 ký tự).
# --- Đang xử lý bài báo thứ 464 ---
#     -> Đã lấy xong nội dung (953 ký tự).
# --- Đang xử lý bài báo thứ 465 ---
#     -> Đã lấy xong nội dung (3092 ký tự).
# --- Đang xử lý bài báo thứ 466 ---
#     -> Đã lấy xong nội dung (2374 ký tự).
# --- Đang xử lý bài báo thứ 467 ---
#     -> Đã lấy xong nội dung (1737 ký tự).
# --- Đang xử lý bài báo thứ 468 ---
#     -> Đã lấy xong nội dung (1202 ký tự).
# --- Đang xử lý bài báo thứ 469 ---
#     -> Đã lấy xong nội dung (2286 ký tự).
# --- Đang xử lý bài báo thứ 470 ---
#     -> Đã lấy xong nội dung (1475 ký tự).
# --- Đang xử lý bài báo thứ 471 ---
#     -> Đã lấy xong nội dung (3425 ký tự).
# --- Đang xử lý bài báo thứ 472 ---
#     -> Đã lấy xong nội dung (2520 ký tự).
# --- Đang xử lý bài báo thứ 473 ---
#     -> Đã lấy xong nội dung (3693 ký tự).
# --- Đang xử lý bài báo thứ 474 ---
#     -> Đã lấy xong nội dung (7614 ký tự).
# --- Đang xử lý bài báo thứ 475 ---
#     -> Đã lấy xong nội dung (1685 ký tự).
# --- Đang xử lý bài báo thứ 476 ---
#     -> Đã lấy xong nội dung (2972 ký tự).
# --- Đang xử lý bài báo thứ 477 ---
#     -> Đã lấy xong nội dung (3502 ký tự).
# --- Đang xử lý bài báo thứ 478 ---
#     -> Đã lấy xong nội dung (2256 ký tự).
# --- Đang xử lý bài báo thứ 479 ---
#     -> Đã lấy xong nội dung (4100 ký tự).
# --- Đang xử lý bài báo thứ 480 ---
#     -> Đã lấy xong nội dung (4819 ký tự).
# --- Đang xử lý bài báo thứ 481 ---
#     -> Đã lấy xong nội dung (4553 ký tự).
# --- Đang xử lý bài báo thứ 482 ---
#     -> Đã lấy xong nội dung (3353 ký tự).
# --- Đang xử lý bài báo thứ 483 ---
#     -> Đã lấy xong nội dung (3025 ký tự).
# --- Đang xử lý bài báo thứ 484 ---
#     -> Đã lấy xong nội dung (3786 ký tự).
# --- Đang xử lý bài báo thứ 485 ---
#     -> Đã lấy xong nội dung (5173 ký tự).
# --- Đang xử lý bài báo thứ 486 ---
#     -> Đã lấy xong nội dung (3333 ký tự).
# --- Đang xử lý bài báo thứ 487 ---
#     -> Đã lấy xong nội dung (3145 ký tự).
# --- Đang xử lý bài báo thứ 488 ---
#     -> Đã lấy xong nội dung (4947 ký tự).
# --- Đang xử lý bài báo thứ 489 ---
#     -> Đã lấy xong nội dung (2131 ký tự).
# --- Đang xử lý bài báo thứ 490 ---
#     -> Đã lấy xong nội dung (3380 ký tự).
# --- Đang xử lý bài báo thứ 491 ---
#     -> Đã lấy xong nội dung (2896 ký tự).
# --- Đang xử lý bài báo thứ 492 ---
#     -> Đã lấy xong nội dung (4884 ký tự).
# --- Đang xử lý bài báo thứ 493 ---
#     -> Đã lấy xong nội dung (2963 ký tự).
# --- Đang xử lý bài báo thứ 494 ---
#     -> Đã lấy xong nội dung (3857 ký tự).
# --- Đang xử lý bài báo thứ 495 ---
#     -> Đã lấy xong nội dung (1821 ký tự).
# --- Đang xử lý bài báo thứ 496 ---
#     -> Đã lấy xong nội dung (2813 ký tự).
# --- Đang xử lý bài báo thứ 497 ---
#     -> Đã lấy xong nội dung (4859 ký tự).
# --- Đang xử lý bài báo thứ 498 ---
#     -> Đã lấy xong nội dung (1466 ký tự).
# --- Đang xử lý bài báo thứ 499 ---
#     -> Đã lấy xong nội dung (2643 ký tự).
# --- Đang xử lý bài báo thứ 500 ---
#     -> Đã lấy xong nội dung (2769 ký tự).
# --- Đang xử lý bài báo thứ 501 ---
#     -> Đã lấy xong nội dung (3951 ký tự).
# --- Đang xử lý bài báo thứ 502 ---
#     -> Đã lấy xong nội dung (3165 ký tự).
# --- Đang xử lý bài báo thứ 503 ---
#     -> Đã lấy xong nội dung (2288 ký tự).
# --- Đang xử lý bài báo thứ 504 ---
#     -> Đã lấy xong nội dung (3093 ký tự).
# --- Đang xử lý bài báo thứ 505 ---
#     -> Đã lấy xong nội dung (1226 ký tự).
# --- Đang xử lý bài báo thứ 506 ---
#     -> Đã lấy xong nội dung (2647 ký tự).
# --- Đang xử lý bài báo thứ 507 ---
#     -> Đã lấy xong nội dung (3330 ký tự).
# --- Đang xử lý bài báo thứ 508 ---
#     -> Đã lấy xong nội dung (2658 ký tự).
# --- Đang xử lý bài báo thứ 509 ---
#     -> Đã lấy xong nội dung (3984 ký tự).
# --- Đang xử lý bài báo thứ 510 ---
#     -> Đã lấy xong nội dung (2776 ký tự).
# --- Đang xử lý bài báo thứ 511 ---
#     -> Đã lấy xong nội dung (2305 ký tự).
# --- Đang xử lý bài báo thứ 512 ---
#     -> Đã lấy xong nội dung (4396 ký tự).
# --- Đang xử lý bài báo thứ 513 ---
#     -> Đã lấy xong nội dung (2587 ký tự).
# --- Đang xử lý bài báo thứ 514 ---
#     -> Đã lấy xong nội dung (3175 ký tự).
# --- Đang xử lý bài báo thứ 515 ---
#     -> Đã lấy xong nội dung (2752 ký tự).
# --- Đang xử lý bài báo thứ 516 ---
#     -> Đã lấy xong nội dung (3751 ký tự).
# --- Đang xử lý bài báo thứ 517 ---
#     -> Đã lấy xong nội dung (2910 ký tự).
# --- Đang xử lý bài báo thứ 518 ---
#     -> Đã lấy xong nội dung (2432 ký tự).
# --- Đang xử lý bài báo thứ 519 ---
#     -> Đã lấy xong nội dung (2395 ký tự).
# --- Đang xử lý bài báo thứ 520 ---
#     -> Đã lấy xong nội dung (1953 ký tự).
# --- Đang xử lý bài báo thứ 521 ---
#     -> Đã lấy xong nội dung (1759 ký tự).
# --- Đang xử lý bài báo thứ 522 ---
#     -> Đã lấy xong nội dung (2215 ký tự).
# --- Đang xử lý bài báo thứ 523 ---
#     -> Đã lấy xong nội dung (2870 ký tự).
# --- Đang xử lý bài báo thứ 524 ---
#     -> Đã lấy xong nội dung (3497 ký tự).
# --- Đang xử lý bài báo thứ 525 ---
#     -> Đã lấy xong nội dung (3232 ký tự).
# --- Đang xử lý bài báo thứ 526 ---
#     -> Đã lấy xong nội dung (3414 ký tự).
# --- Đang xử lý bài báo thứ 527 ---
#     -> Đã lấy xong nội dung (1807 ký tự).
# --- Đang xử lý bài báo thứ 528 ---
#     -> Đã lấy xong nội dung (2218 ký tự).
# --- Đang xử lý bài báo thứ 529 ---
#     -> Đã lấy xong nội dung (2907 ký tự).
# --- Đang xử lý bài báo thứ 530 ---
#     -> Đã lấy xong nội dung (3853 ký tự).
# --- Đang xử lý bài báo thứ 531 ---
#     -> Đã lấy xong nội dung (2619 ký tự).
# --- Đang xử lý bài báo thứ 532 ---
#     -> Đã lấy xong nội dung (1961 ký tự).
# --- Đang xử lý bài báo thứ 533 ---
#     -> Đã lấy xong nội dung (5858 ký tự).
# --- Đang xử lý bài báo thứ 534 ---
#     -> Đã lấy xong nội dung (2473 ký tự).
# --- Đang xử lý bài báo thứ 535 ---
#     -> Đã lấy xong nội dung (2158 ký tự).
# --- Đang xử lý bài báo thứ 536 ---
#     -> Đã lấy xong nội dung (4318 ký tự).
# --- Đang xử lý bài báo thứ 537 ---
#     -> Đã lấy xong nội dung (3158 ký tự).
# --- Đang xử lý bài báo thứ 538 ---
#     -> Đã lấy xong nội dung (4161 ký tự).
# --- Đang xử lý bài báo thứ 539 ---
#     -> Đã lấy xong nội dung (1553 ký tự).
# --- Đang xử lý bài báo thứ 540 ---
#     -> Đã lấy xong nội dung (1052 ký tự).
# --- Đang xử lý bài báo thứ 541 ---
#     -> Đã lấy xong nội dung (3236 ký tự).
# --- Đang xử lý bài báo thứ 542 ---
#     -> Đã lấy xong nội dung (2759 ký tự).
# --- Đang xử lý bài báo thứ 543 ---
#     -> Đã lấy xong nội dung (3909 ký tự).
# --- Đang xử lý bài báo thứ 544 ---
#     -> Đã lấy xong nội dung (13141 ký tự).
# --- Đang xử lý bài báo thứ 545 ---
#     -> Đã lấy xong nội dung (1881 ký tự).
# --- Đang xử lý bài báo thứ 546 ---
#     -> Đã lấy xong nội dung (3807 ký tự).
# --- Đang xử lý bài báo thứ 547 ---
#     -> Đã lấy xong nội dung (5663 ký tự).
# --- Đang xử lý bài báo thứ 548 ---
#     -> Đã lấy xong nội dung (2480 ký tự).
# --- Đang xử lý bài báo thứ 549 ---
#     -> Đã lấy xong nội dung (2727 ký tự).
# --- Đang xử lý bài báo thứ 550 ---
#     -> Đã lấy xong nội dung (3042 ký tự).
# --- Đang xử lý bài báo thứ 551 ---
#     -> Đã lấy xong nội dung (3235 ký tự).
# --- Đang xử lý bài báo thứ 552 ---
#     -> Đã lấy xong nội dung (4777 ký tự).
# --- Đang xử lý bài báo thứ 553 ---
#     -> Đã lấy xong nội dung (4110 ký tự).
# --- Đang xử lý bài báo thứ 554 ---
#     -> Đã lấy xong nội dung (3326 ký tự).
# --- Đang xử lý bài báo thứ 555 ---
#     -> Đã lấy xong nội dung (3564 ký tự).
# --- Đang xử lý bài báo thứ 556 ---
#     -> Đã lấy xong nội dung (3894 ký tự).
# --- Đang xử lý bài báo thứ 557 ---
#     -> Đã lấy xong nội dung (4197 ký tự).
# --- Đang xử lý bài báo thứ 558 ---
#     -> Đã lấy xong nội dung (4038 ký tự).
# --- Đang xử lý bài báo thứ 559 ---
#     -> Đã lấy xong nội dung (8477 ký tự).
# --- Đang xử lý bài báo thứ 560 ---
#     -> Đã lấy xong nội dung (2104 ký tự).
# --- Đang xử lý bài báo thứ 561 ---
#     -> Đã lấy xong nội dung (3713 ký tự).
# --- Đang xử lý bài báo thứ 562 ---
#     -> Đã lấy xong nội dung (5737 ký tự).
# --- Đang xử lý bài báo thứ 563 ---
#     -> Đã lấy xong nội dung (2179 ký tự).
# --- Đang xử lý bài báo thứ 564 ---
#     -> Đã lấy xong nội dung (5889 ký tự).
# --- Đang xử lý bài báo thứ 565 ---
#     -> Đã lấy xong nội dung (1027 ký tự).
# --- Đang xử lý bài báo thứ 566 ---
#     -> Đã lấy xong nội dung (3872 ký tự).
# --- Đang xử lý bài báo thứ 567 ---
#     -> Đã lấy xong nội dung (1585 ký tự).
# --- Đang xử lý bài báo thứ 568 ---
#     -> Đã lấy xong nội dung (2760 ký tự).
# --- Đang xử lý bài báo thứ 569 ---
#     -> Đã lấy xong nội dung (2173 ký tự).
# --- Đang xử lý bài báo thứ 570 ---
#     -> Đã lấy xong nội dung (3132 ký tự).
# --- Đang xử lý bài báo thứ 571 ---
#     -> Đã lấy xong nội dung (2354 ký tự).
# --- Đang xử lý bài báo thứ 572 ---
#     -> Đã lấy xong nội dung (2437 ký tự).
# --- Đang xử lý bài báo thứ 573 ---
#     -> Đã lấy xong nội dung (3032 ký tự).
# --- Đang xử lý bài báo thứ 574 ---
#     -> Đã lấy xong nội dung (8802 ký tự).
# --- Đang xử lý bài báo thứ 575 ---
#     -> Đã lấy xong nội dung (8754 ký tự).
# --- Đang xử lý bài báo thứ 576 ---
#     -> Đã lấy xong nội dung (2290 ký tự).
# --- Đang xử lý bài báo thứ 577 ---
#     -> Đã lấy xong nội dung (3332 ký tự).
# --- Đang xử lý bài báo thứ 578 ---
#     -> Đã lấy xong nội dung (2619 ký tự).
# --- Đang xử lý bài báo thứ 579 ---
#     -> Đã lấy xong nội dung (3111 ký tự).
# --- Đang xử lý bài báo thứ 580 ---
#     -> Đã lấy xong nội dung (7541 ký tự).
# --- Đang xử lý bài báo thứ 581 ---
#     -> Đã lấy xong nội dung (5332 ký tự).
# --- Đang xử lý bài báo thứ 582 ---
#     -> Đã lấy xong nội dung (2435 ký tự).
# --- Đang xử lý bài báo thứ 583 ---
#     -> Đã lấy xong nội dung (3058 ký tự).
# --- Đang xử lý bài báo thứ 584 ---
#     -> Đã lấy xong nội dung (2966 ký tự).
# --- Đang xử lý bài báo thứ 585 ---
#     -> Đã lấy xong nội dung (3563 ký tự).
# --- Đang xử lý bài báo thứ 586 ---
#     -> Đã lấy xong nội dung (2766 ký tự).
# --- Đang xử lý bài báo thứ 587 ---
#     -> Đã lấy xong nội dung (2273 ký tự).
# --- Đang xử lý bài báo thứ 588 ---
#     -> Đã lấy xong nội dung (1002 ký tự).
# --- Đang xử lý bài báo thứ 589 ---
#     -> Đã lấy xong nội dung (3766 ký tự).
# --- Đang xử lý bài báo thứ 590 ---
#     -> Đã lấy xong nội dung (3008 ký tự).
# --- Đang xử lý bài báo thứ 591 ---
#     -> Đã lấy xong nội dung (3277 ký tự).
# --- Đang xử lý bài báo thứ 592 ---
#     -> Đã lấy xong nội dung (1779 ký tự).
# --- Đang xử lý bài báo thứ 593 ---
#     -> Đã lấy xong nội dung (3190 ký tự).
# --- Đang xử lý bài báo thứ 594 ---
#     -> Đã lấy xong nội dung (4701 ký tự).
# --- Đang xử lý bài báo thứ 595 ---
#     -> Đã lấy xong nội dung (2992 ký tự).
# --- Đang xử lý bài báo thứ 596 ---
#     -> Đã lấy xong nội dung (2063 ký tự).
# --- Đang xử lý bài báo thứ 597 ---
#     -> Đã lấy xong nội dung (4288 ký tự).
# --- Đang xử lý bài báo thứ 598 ---
#     -> Đã lấy xong nội dung (3170 ký tự).
# --- Đang xử lý bài báo thứ 599 ---
#     -> Đã lấy xong nội dung (2993 ký tự).
# --- Đang xử lý bài báo thứ 600 ---
#     -> Đã lấy xong nội dung (4629 ký tự).
# --- Đang xử lý bài báo thứ 601 ---
#     -> Đã lấy xong nội dung (2626 ký tự).
# --- Đang xử lý bài báo thứ 602 ---
#     -> Đã lấy xong nội dung (1812 ký tự).
# --- Đang xử lý bài báo thứ 603 ---
#     -> Đã lấy xong nội dung (3367 ký tự).
# --- Đang xử lý bài báo thứ 604 ---
#     -> Đã lấy xong nội dung (4558 ký tự).
# --- Đang xử lý bài báo thứ 605 ---
#     -> Đã lấy xong nội dung (3214 ký tự).
# --- Đang xử lý bài báo thứ 606 ---
#     -> Đã lấy xong nội dung (3400 ký tự).
# --- Đang xử lý bài báo thứ 607 ---
#     -> Đã lấy xong nội dung (2376 ký tự).
# --- Đang xử lý bài báo thứ 608 ---
#     -> Đã lấy xong nội dung (3954 ký tự).
# --- Đang xử lý bài báo thứ 609 ---
#     -> Đã lấy xong nội dung (2796 ký tự).
# --- Đang xử lý bài báo thứ 610 ---
#     -> Đã lấy xong nội dung (5463 ký tự).
# --- Đang xử lý bài báo thứ 611 ---
#     -> Đã lấy xong nội dung (4500 ký tự).
# --- Đang xử lý bài báo thứ 612 ---
#     -> Đã lấy xong nội dung (2513 ký tự).
# --- Đang xử lý bài báo thứ 613 ---
#     -> Đã lấy xong nội dung (3834 ký tự).
# --- Đang xử lý bài báo thứ 614 ---
#     -> Đã lấy xong nội dung (3266 ký tự).
# --- Đang xử lý bài báo thứ 615 ---
#     -> Đã lấy xong nội dung (2351 ký tự).
# --- Đang xử lý bài báo thứ 616 ---
#     -> Đã lấy xong nội dung (3582 ký tự).
# --- Đang xử lý bài báo thứ 617 ---
#     -> Đã lấy xong nội dung (3373 ký tự).
# --- Đang xử lý bài báo thứ 618 ---
#     -> Đã lấy xong nội dung (2222 ký tự).
# --- Đang xử lý bài báo thứ 619 ---
#     -> Đã lấy xong nội dung (2433 ký tự).
# --- Đang xử lý bài báo thứ 620 ---
#     -> Đã lấy xong nội dung (2297 ký tự).
# --- Đang xử lý bài báo thứ 621 ---
#     -> Đã lấy xong nội dung (2834 ký tự).
# --- Đang xử lý bài báo thứ 622 ---
#     -> Đã lấy xong nội dung (2055 ký tự).
# --- Đang xử lý bài báo thứ 623 ---
#     -> Đã lấy xong nội dung (2532 ký tự).
# --- Đang xử lý bài báo thứ 624 ---
#     -> Đã lấy xong nội dung (3071 ký tự).
# ...
# --- Đang xử lý bài báo thứ 701 ---
#     -> Đã lấy xong nội dung (2586 ký tự).
# --- Đang xử lý bài báo thứ 702 ---
#     -> Đã lấy xong nội dung (2230 ký tự).
# --- Đang xử lý bài báo thứ 703 ---
#     -> Đã lấy xong nội dung (3942 ký tự).
# --- Đang xử lý bài báo thứ 704 ---
#     -> Đã lấy xong nội dung (1346 ký tự).
# --- Đang xử lý bài báo thứ 705 ---
#     -> Đã lấy xong nội dung (2141 ký tự).
# --- Đang xử lý bài báo thứ 706 ---
#     -> Đã lấy xong nội dung (4181 ký tự).
# --- Đang xử lý bài báo thứ 707 ---
#     -> Đã lấy xong nội dung (1958 ký tự).
# --- Đang xử lý bài báo thứ 708 ---
#     -> Đã lấy xong nội dung (2363 ký tự).
# --- Đang xử lý bài báo thứ 709 ---
#     -> Đã lấy xong nội dung (2878 ký tự).
# --- Đang xử lý bài báo thứ 710 ---
#     -> Đã lấy xong nội dung (1220 ký tự).
# --- Đang xử lý bài báo thứ 711 ---
#     -> Đã lấy xong nội dung (3062 ký tự).
# --- Đang xử lý bài báo thứ 712 ---
#     -> Đã lấy xong nội dung (1687 ký tự).
# --- Đang xử lý bài báo thứ 713 ---
#     -> Đã lấy xong nội dung (1812 ký tự).
# --- Đang xử lý bài báo thứ 714 ---
#     -> Đã lấy xong nội dung (3829 ký tự).
# --- Đang xử lý bài báo thứ 715 ---
#     -> Đã lấy xong nội dung (4945 ký tự).
# --- Đang xử lý bài báo thứ 716 ---
#     -> Đã lấy xong nội dung (2091 ký tự).
# --- Đang xử lý bài báo thứ 717 ---
#     -> Đã lấy xong nội dung (1018 ký tự).
# --- Đang xử lý bài báo thứ 718 ---
#     -> Đã lấy xong nội dung (2653 ký tự).
# --- Đang xử lý bài báo thứ 719 ---
#     -> Đã lấy xong nội dung (3963 ký tự).
# --- Đang xử lý bài báo thứ 720 ---
#     -> Đã lấy xong nội dung (1619 ký tự).
# --- Đang xử lý bài báo thứ 721 ---
#     -> Đã lấy xong nội dung (2434 ký tự).
# --- Đang xử lý bài báo thứ 722 ---
#     -> Đã lấy xong nội dung (5848 ký tự).
# --- Đang xử lý bài báo thứ 723 ---
#     -> Đã lấy xong nội dung (3301 ký tự).
# --- Đang xử lý bài báo thứ 724 ---
#     -> Đã lấy xong nội dung (2854 ký tự).
# --- Đang xử lý bài báo thứ 725 ---
#     -> Đã lấy xong nội dung (4809 ký tự).
# --- Đang xử lý bài báo thứ 726 ---
#     -> Đã lấy xong nội dung (4318 ký tự).
# --- Đang xử lý bài báo thứ 727 ---
#     -> Đã lấy xong nội dung (2842 ký tự).
# --- Đang xử lý bài báo thứ 728 ---
#     -> Đã lấy xong nội dung (5047 ký tự).
# --- Đang xử lý bài báo thứ 729 ---
#     -> Đã lấy xong nội dung (3199 ký tự).
# --- Đang xử lý bài báo thứ 730 ---
#     -> Đã lấy xong nội dung (4324 ký tự).
# --- Đang xử lý bài báo thứ 731 ---
#     -> Đã lấy xong nội dung (4042 ký tự).
# --- Đang xử lý bài báo thứ 732 ---
#     -> Đã lấy xong nội dung (2811 ký tự).
# --- Đang xử lý bài báo thứ 733 ---
#     -> Đã lấy xong nội dung (4324 ký tự).
# --- Đang xử lý bài báo thứ 734 ---
#     -> Đã lấy xong nội dung (2735 ký tự).
# --- Đang xử lý bài báo thứ 735 ---
#     -> Đã lấy xong nội dung (4888 ký tự).
# --- Đang xử lý bài báo thứ 736 ---
#     -> Đã lấy xong nội dung (5905 ký tự).
# --- Đang xử lý bài báo thứ 737 ---
#     -> Đã lấy xong nội dung (1983 ký tự).
# --- Đang xử lý bài báo thứ 738 ---
#     -> Đã lấy xong nội dung (1876 ký tự).
# --- Đang xử lý bài báo thứ 739 ---
#     -> Đã lấy xong nội dung (5180 ký tự).
# --- Đang xử lý bài báo thứ 740 ---
#     -> Đã lấy xong nội dung (2736 ký tự).
# --- Đang xử lý bài báo thứ 741 ---
#     -> Đã lấy xong nội dung (2725 ký tự).
# --- Đang xử lý bài báo thứ 742 ---
#     -> Đã lấy xong nội dung (1211 ký tự).
# --- Đang xử lý bài báo thứ 743 ---
#     -> Đã lấy xong nội dung (3083 ký tự).
# --- Đang xử lý bài báo thứ 744 ---
#     -> Đã lấy xong nội dung (1539 ký tự).
# --- Đang xử lý bài báo thứ 745 ---
#     -> Đã lấy xong nội dung (5028 ký tự).
# --- Đang xử lý bài báo thứ 746 ---
#     -> Đã lấy xong nội dung (4772 ký tự).
# --- Đang xử lý bài báo thứ 747 ---
#     -> Đã lấy xong nội dung (2982 ký tự).
# --- Đang xử lý bài báo thứ 748 ---
#     -> Đã lấy xong nội dung (2651 ký tự).
# --- Đang xử lý bài báo thứ 749 ---
#     -> Đã lấy xong nội dung (5749 ký tự).
# --- Đang xử lý bài báo thứ 750 ---
#     -> Đã lấy xong nội dung (3655 ký tự).
# --- Đang xử lý bài báo thứ 751 ---
#     -> Đã lấy xong nội dung (5164 ký tự).
# --- Đang xử lý bài báo thứ 752 ---
#     -> Đã lấy xong nội dung (3899 ký tự).
# --- Đang xử lý bài báo thứ 753 ---
#     -> Đã lấy xong nội dung (2809 ký tự).
# --- Đang xử lý bài báo thứ 754 ---
#     -> Đã lấy xong nội dung (2106 ký tự).
# --- Đang xử lý bài báo thứ 755 ---
#     -> Đã lấy xong nội dung (2149 ký tự).
# --- Đang xử lý bài báo thứ 756 ---
#     -> Đã lấy xong nội dung (1865 ký tự).
# --- Đang xử lý bài báo thứ 757 ---
#     -> Đã lấy xong nội dung (4367 ký tự).
# --- Đang xử lý bài báo thứ 758 ---
#     -> Đã lấy xong nội dung (1120 ký tự).
# --- Đang xử lý bài báo thứ 759 ---
#     -> Đã lấy xong nội dung (3845 ký tự).
# --- Đang xử lý bài báo thứ 760 ---
#     -> Đã lấy xong nội dung (2714 ký tự).
# --- Đang xử lý bài báo thứ 761 ---
#     -> Đã lấy xong nội dung (4841 ký tự).
# --- Đang xử lý bài báo thứ 762 ---
#     -> Đã lấy xong nội dung (1956 ký tự).
# --- Đang xử lý bài báo thứ 763 ---
#     -> Đã lấy xong nội dung (4563 ký tự).
# --- Đang xử lý bài báo thứ 764 ---
#     -> Đã lấy xong nội dung (5957 ký tự).
# --- Đang xử lý bài báo thứ 765 ---
#     -> Đã lấy xong nội dung (4173 ký tự).
# --- Đang xử lý bài báo thứ 766 ---
#     -> Đã lấy xong nội dung (4499 ký tự).
# --- Đang xử lý bài báo thứ 767 ---
#     -> Đã lấy xong nội dung (2331 ký tự).
# --- Đang xử lý bài báo thứ 768 ---
#     -> Đã lấy xong nội dung (2132 ký tự).
# --- Đang xử lý bài báo thứ 769 ---
#     -> Đã lấy xong nội dung (4297 ký tự).
# --- Đang xử lý bài báo thứ 770 ---
#     -> Đã lấy xong nội dung (3866 ký tự).
# --- Đang xử lý bài báo thứ 771 ---
#     -> Đã lấy xong nội dung (3011 ký tự).
# --- Đang xử lý bài báo thứ 772 ---
#     -> Đã lấy xong nội dung (4167 ký tự).
# --- Đang xử lý bài báo thứ 773 ---
#     -> Đã lấy xong nội dung (2271 ký tự).
# --- Đang xử lý bài báo thứ 774 ---
#     -> Đã lấy xong nội dung (1915 ký tự).
# --- Đang xử lý bài báo thứ 775 ---
#     -> Đã lấy xong nội dung (3993 ký tự).
# --- Đang xử lý bài báo thứ 776 ---
#     -> Đã lấy xong nội dung (2422 ký tự).
# --- Đang xử lý bài báo thứ 777 ---
#     -> Đã lấy xong nội dung (1653 ký tự).
# --- Đang xử lý bài báo thứ 778 ---
#     -> Đã lấy xong nội dung (1798 ký tự).
# --- Đang xử lý bài báo thứ 779 ---
#     -> Đã lấy xong nội dung (1908 ký tự).
# --- Đang xử lý bài báo thứ 780 ---
#     -> Đã lấy xong nội dung (1012 ký tự).
# --- Đang xử lý bài báo thứ 781 ---
#     -> Đã lấy xong nội dung (3514 ký tự).
# --- Đang xử lý bài báo thứ 782 ---
#     -> Đã lấy xong nội dung (2122 ký tự).
# --- Đang xử lý bài báo thứ 783 ---
#     -> Đã lấy xong nội dung (3547 ký tự).
# --- Đang xử lý bài báo thứ 784 ---
#     -> Đã lấy xong nội dung (1503 ký tự).
# --- Đang xử lý bài báo thứ 785 ---
#     -> Đã lấy xong nội dung (5097 ký tự).
# --- Đang xử lý bài báo thứ 786 ---
#     -> Đã lấy xong nội dung (6922 ký tự).
# --- Đang xử lý bài báo thứ 787 ---
#     -> CẢNH BÁO: Quá 3 phút không lấy được nội dung bài 787. Để trống content.
# --- Đang xử lý bài báo thứ 788 ---
#     -> Đã lấy xong nội dung (3163 ký tự).
# --- Đang xử lý bài báo thứ 789 ---
#     -> Đã lấy xong nội dung (940 ký tự).
# --- Đang xử lý bài báo thứ 790 ---
#     -> Đã lấy xong nội dung (10751 ký tự).
# --- Đang xử lý bài báo thứ 791 ---
#     -> Đã lấy xong nội dung (2613 ký tự).
# --- Đang xử lý bài báo thứ 792 ---
#     -> Đã lấy xong nội dung (1697 ký tự).
# --- Đang xử lý bài báo thứ 793 ---
#     -> Đã lấy xong nội dung (3309 ký tự).
# --- Đang xử lý bài báo thứ 794 ---
#     -> Đã lấy xong nội dung (2790 ký tự).
# --- Đang xử lý bài báo thứ 795 ---
#     -> Đã lấy xong nội dung (6049 ký tự).
# --- Đang xử lý bài báo thứ 796 ---
#     -> Đã lấy xong nội dung (3378 ký tự).
# --- Đang xử lý bài báo thứ 797 ---
#     -> Đã lấy xong nội dung (2555 ký tự).
# --- Đang xử lý bài báo thứ 798 ---
#     -> Đã lấy xong nội dung (5285 ký tự).
# --- Đang xử lý bài báo thứ 799 ---
#     -> Đã lấy xong nội dung (2322 ký tự).
# --- Đang xử lý bài báo thứ 800 ---
#     -> Đã lấy xong nội dung (1621 ký tự).
# --- Đang xử lý bài báo thứ 801 ---
#     -> Đã lấy xong nội dung (3862 ký tự).
# --- Đang xử lý bài báo thứ 802 ---
#     -> Đã lấy xong nội dung (6307 ký tự).
# --- Đang xử lý bài báo thứ 803 ---
#     -> Đã lấy xong nội dung (2894 ký tự).
# --- Đang xử lý bài báo thứ 804 ---
#     -> Đã lấy xong nội dung (3122 ký tự).
# --- Đang xử lý bài báo thứ 805 ---
#     -> Đã lấy xong nội dung (2172 ký tự).
# --- Đang xử lý bài báo thứ 806 ---
#     -> Đã lấy xong nội dung (2156 ký tự).
# --- Đang xử lý bài báo thứ 807 ---
#     -> Đã lấy xong nội dung (995 ký tự).
# --- Đang xử lý bài báo thứ 808 ---
#     -> Đã lấy xong nội dung (5989 ký tự).
# --- Đang xử lý bài báo thứ 809 ---
#     -> Đã lấy xong nội dung (3115 ký tự).
# --- Đang xử lý bài báo thứ 810 ---
#     -> Đã lấy xong nội dung (5452 ký tự).
# --- Đang xử lý bài báo thứ 811 ---
#     -> Đã lấy xong nội dung (1934 ký tự).
# --- Đang xử lý bài báo thứ 812 ---
#     -> Đã lấy xong nội dung (4978 ký tự).
# --- Đang xử lý bài báo thứ 813 ---
#     -> Đã lấy xong nội dung (1715 ký tự).
# --- Đang xử lý bài báo thứ 814 ---
#     -> Đã lấy xong nội dung (4654 ký tự).
# --- Đang xử lý bài báo thứ 815 ---
#     -> Đã lấy xong nội dung (2436 ký tự).
# --- Đang xử lý bài báo thứ 816 ---
#     -> Đã lấy xong nội dung (2610 ký tự).
# --- Đang xử lý bài báo thứ 817 ---
#     -> Đã lấy xong nội dung (2672 ký tự).
# --- Đang xử lý bài báo thứ 818 ---
#     -> Đã lấy xong nội dung (3447 ký tự).
# --- Đang xử lý bài báo thứ 819 ---
#     -> Đã lấy xong nội dung (3290 ký tự).
# --- Đang xử lý bài báo thứ 820 ---
#     -> Đã lấy xong nội dung (2914 ký tự).
# --- Đang xử lý bài báo thứ 821 ---
#     -> Đã lấy xong nội dung (4015 ký tự).
# --- Đang xử lý bài báo thứ 822 ---
#     -> Đã lấy xong nội dung (5407 ký tự).
# --- Đang xử lý bài báo thứ 823 ---
#     -> Đã lấy xong nội dung (2364 ký tự).
# --- Đang xử lý bài báo thứ 824 ---
#     -> Đã lấy xong nội dung (1761 ký tự).
# --- Đang xử lý bài báo thứ 825 ---
#     -> Đã lấy xong nội dung (2382 ký tự).
# --- Đang xử lý bài báo thứ 826 ---
#     -> Đã lấy xong nội dung (3680 ký tự).
# --- Đang xử lý bài báo thứ 827 ---
#     -> Đã lấy xong nội dung (973 ký tự).
# --- Đang xử lý bài báo thứ 828 ---
#     -> Đã lấy xong nội dung (1609 ký tự).
# --- Đang xử lý bài báo thứ 829 ---
#     -> Đã lấy xong nội dung (2333 ký tự).
# --- Đang xử lý bài báo thứ 830 ---
#     -> Đã lấy xong nội dung (2073 ký tự).
# --- Đang xử lý bài báo thứ 831 ---
#     -> Đã lấy xong nội dung (1882 ký tự).
# --- Đang xử lý bài báo thứ 832 ---
#     -> Đã lấy xong nội dung (4352 ký tự).
# --- Đang xử lý bài báo thứ 833 ---
#     -> Đã lấy xong nội dung (12869 ký tự).
# --- Đang xử lý bài báo thứ 834 ---
#     -> Đã lấy xong nội dung (9819 ký tự).
# --- Đang xử lý bài báo thứ 835 ---
#     -> Đã lấy xong nội dung (4605 ký tự).
# --- Đang xử lý bài báo thứ 836 ---
#     -> Đã lấy xong nội dung (2298 ký tự).
# --- Đang xử lý bài báo thứ 837 ---
#     -> Đã lấy xong nội dung (2306 ký tự).
# --- Đang xử lý bài báo thứ 838 ---
#     -> Đã lấy xong nội dung (6811 ký tự).
# --- Đang xử lý bài báo thứ 839 ---
#     -> Đã lấy xong nội dung (2871 ký tự).
# --- Đang xử lý bài báo thứ 840 ---
#     -> Đã lấy xong nội dung (2085 ký tự).
# --- Đang xử lý bài báo thứ 841 ---
#     -> Đã lấy xong nội dung (4433 ký tự).
# --- Đang xử lý bài báo thứ 842 ---
#     -> Đã lấy xong nội dung (2601 ký tự).
# --- Đang xử lý bài báo thứ 843 ---
#     -> Đã lấy xong nội dung (3322 ký tự).
# --- Đang xử lý bài báo thứ 844 ---
#     -> Đã lấy xong nội dung (2217 ký tự).
# --- Đang xử lý bài báo thứ 845 ---
#     -> Đã lấy xong nội dung (3869 ký tự).
# --- Đang xử lý bài báo thứ 846 ---
#     -> Đã lấy xong nội dung (2241 ký tự).
# --- Đang xử lý bài báo thứ 847 ---
#     -> Đã lấy xong nội dung (2747 ký tự).
# --- Đang xử lý bài báo thứ 848 ---
#     -> Đã lấy xong nội dung (1673 ký tự).
# --- Đang xử lý bài báo thứ 849 ---
#     -> Đã lấy xong nội dung (937 ký tự).
# --- Đang xử lý bài báo thứ 850 ---
#     -> Đã lấy xong nội dung (3488 ký tự).
# --- Đang xử lý bài báo thứ 851 ---
#     -> Đã lấy xong nội dung (3877 ký tự).
# --- Đang xử lý bài báo thứ 852 ---
#     -> Đã lấy xong nội dung (2435 ký tự).
# --- Đang xử lý bài báo thứ 853 ---
#     -> Đã lấy xong nội dung (1867 ký tự).
# --- Đang xử lý bài báo thứ 854 ---
#     -> Đã lấy xong nội dung (1796 ký tự).
# --- Đang xử lý bài báo thứ 855 ---
#     -> Đã lấy xong nội dung (5317 ký tự).
# --- Đang xử lý bài báo thứ 856 ---
#     -> Đã lấy xong nội dung (3347 ký tự).
# --- Đang xử lý bài báo thứ 857 ---
#     -> Đã lấy xong nội dung (1876 ký tự).
# --- Đang xử lý bài báo thứ 858 ---
#     -> Đã lấy xong nội dung (2555 ký tự).
# --- Đang xử lý bài báo thứ 859 ---
#     -> Đã lấy xong nội dung (2549 ký tự).
# --- Đang xử lý bài báo thứ 860 ---
#     -> Đã lấy xong nội dung (3186 ký tự).
# --- Đang xử lý bài báo thứ 861 ---
#     -> Đã lấy xong nội dung (1977 ký tự).
# --- Đang xử lý bài báo thứ 862 ---
#     -> Đã lấy xong nội dung (4571 ký tự).
# --- Đang xử lý bài báo thứ 863 ---
#     -> Đã lấy xong nội dung (2191 ký tự).
# --- Đang xử lý bài báo thứ 864 ---
#     -> Đã lấy xong nội dung (4008 ký tự).
# --- Đang xử lý bài báo thứ 865 ---
#     -> Đã lấy xong nội dung (2565 ký tự).
# --- Đang xử lý bài báo thứ 866 ---
#     -> Đã lấy xong nội dung (3855 ký tự).
# --- Đang xử lý bài báo thứ 867 ---
#     -> Đã lấy xong nội dung (2621 ký tự).
# --- Đang xử lý bài báo thứ 868 ---
#     -> Đã lấy xong nội dung (5273 ký tự).
# --- Đang xử lý bài báo thứ 869 ---
#     -> Đã lấy xong nội dung (3965 ký tự).
# --- Đang xử lý bài báo thứ 870 ---
#     -> Đã lấy xong nội dung (2157 ký tự).
# --- Đang xử lý bài báo thứ 871 ---
#     -> Đã lấy xong nội dung (2464 ký tự).
# --- Đang xử lý bài báo thứ 872 ---
#     -> Đã lấy xong nội dung (8556 ký tự).
# --- Đang xử lý bài báo thứ 873 ---
#     -> Đã lấy xong nội dung (3666 ký tự).
# --- Đang xử lý bài báo thứ 874 ---
#     -> Đã lấy xong nội dung (5589 ký tự).
# --- Đang xử lý bài báo thứ 875 ---
#     -> Đã lấy xong nội dung (2401 ký tự).
# --- Đang xử lý bài báo thứ 876 ---
#     -> Đã lấy xong nội dung (3584 ký tự).
# --- Đang xử lý bài báo thứ 877 ---
#     -> Đã lấy xong nội dung (5646 ký tự).
# --- Đang xử lý bài báo thứ 878 ---
#     -> Đã lấy xong nội dung (1534 ký tự).
# --- Đang xử lý bài báo thứ 879 ---
#     -> Đã lấy xong nội dung (2461 ký tự).
# --- Đang xử lý bài báo thứ 880 ---
#     -> Đã lấy xong nội dung (2411 ký tự).
# --- Đang xử lý bài báo thứ 881 ---
#     -> Đã lấy xong nội dung (3245 ký tự).
# --- Đang xử lý bài báo thứ 882 ---
#     -> Đã lấy xong nội dung (2957 ký tự).
# --- Đang xử lý bài báo thứ 883 ---
#     -> Đã lấy xong nội dung (2165 ký tự).
# --- Đang xử lý bài báo thứ 884 ---
#     -> Đã lấy xong nội dung (3165 ký tự).
# --- Đang xử lý bài báo thứ 885 ---
#     -> Đã lấy xong nội dung (4659 ký tự).
# --- Đang xử lý bài báo thứ 886 ---
#     -> Đã lấy xong nội dung (2292 ký tự).
# --- Đang xử lý bài báo thứ 887 ---
#     -> Đã lấy xong nội dung (1997 ký tự).
# --- Đang xử lý bài báo thứ 888 ---
#     -> Đã lấy xong nội dung (5858 ký tự).
# --- Đang xử lý bài báo thứ 889 ---
#     -> Đã lấy xong nội dung (3962 ký tự).
# --- Đang xử lý bài báo thứ 890 ---
#     -> Đã lấy xong nội dung (2148 ký tự).
# --- Đang xử lý bài báo thứ 891 ---
#     -> Đã lấy xong nội dung (2074 ký tự).
# --- Đang xử lý bài báo thứ 892 ---
#     -> Đã lấy xong nội dung (3456 ký tự).
# --- Đang xử lý bài báo thứ 893 ---
#     -> Đã lấy xong nội dung (2710 ký tự).
# --- Đang xử lý bài báo thứ 894 ---
#     -> Đã lấy xong nội dung (3424 ký tự).
# --- Đang xử lý bài báo thứ 895 ---
#     -> Đã lấy xong nội dung (3567 ký tự).
# --- Đang xử lý bài báo thứ 896 ---
#     -> Đã lấy xong nội dung (996 ký tự).
# --- Đang xử lý bài báo thứ 897 ---
#     -> Đã lấy xong nội dung (2352 ký tự).
# --- Đang xử lý bài báo thứ 898 ---
#     -> Đã lấy xong nội dung (3001 ký tự).
# --- Đang xử lý bài báo thứ 899 ---
#     -> Đã lấy xong nội dung (2087 ký tự).
# --- Đang xử lý bài báo thứ 900 ---
#     -> Đã lấy xong nội dung (1528 ký tự).
# --- Đang xử lý bài báo thứ 901 ---
#     -> Đã lấy xong nội dung (4075 ký tự).
# --- Đang xử lý bài báo thứ 902 ---
#     -> Đã lấy xong nội dung (7146 ký tự).
# --- Đang xử lý bài báo thứ 903 ---
#     -> Đã lấy xong nội dung (2869 ký tự).
# --- Đang xử lý bài báo thứ 904 ---
#     -> Đã lấy xong nội dung (3618 ký tự).
# --- Đang xử lý bài báo thứ 905 ---
#     -> Đã lấy xong nội dung (2624 ký tự).
# --- Đang xử lý bài báo thứ 906 ---
#     -> Đã lấy xong nội dung (2658 ký tự).
# --- Đang xử lý bài báo thứ 907 ---
#     -> Đã lấy xong nội dung (1704 ký tự).
